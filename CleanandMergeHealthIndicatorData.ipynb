# %% [markdown]
# <a href="https://colab.research.google.com/github/jesme00/jesme00.github.io/blob/main/CleanandMergeHealthIndicatorData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Various indicators of health and deprivation is available on the Government's 'Fingertips' Public Health data website: https://fingertips.phe.org.uk/profile/health-profiles.
#
# After trying and failing to scrape this with Beautiful Soup, and finding downloading CSV data and cleaning it in Excel a very manual task, I looked into using Fingertip's API: https://fingertips.phe.org.uk/api
#
# I struggled to call data on all the variables I wanted into one comprehensive JSON (given through the API's generated URLs). I found that using Fingertip's own Python package (fingertips_py), which connects to their API from within the notebook environment, was the best solution to this problem. It has templates already built that included all the variables I was interested in available through the API.
#
# I used the beginners guide and annex linked on their website (https://fingertips.phe.org.uk/profile/guidance/supporting-information/api) to work out how to do this.
#
# This notebook uses the PHE fingertips API to download data on over 300 indicators of health and wider outcomes, following on from my inital notebook solely looking at the obesity data from this API. After downloading it, I wrote my commands in Excel (https://github.com/jesme00/jesme00.github.io/blob/main/HealthIndicatorDataCodesAvailableatLALevel2.xlsx) before copying them in here, relying on CONCATENATE to speed up the cleaning process.

# %%
pip install fingertips_py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fingertips_py: filename=fingertips_py-0.2.2-py3-none-any.whl size=9774 sha256=c2edc44c6d1982a89cdb22dbaf7fd5480fc98d923841556b7c166c7b6902e1ce
#   Stored in directory: /root/.cache/pip/wheels/40/1c/9f/c6d113478bcb197541e469281d9bdebfe3975f447d66072f15
# Successfully built fingertips_py
# ...

# %%
import fingertips_py as ftp
import pandas as pd

# %% [markdown]
# Step 1 : retrieve data for all health indicators that are matched to 2021 LA areas, by searching with 'area_type_id=401'

# %%
df1=ftp.retrieve_data.get_all_data_for_indicators(108, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df362=ftp.retrieve_data.get_all_data_for_indicators(212, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df723=ftp.retrieve_data.get_all_data_for_indicators(219, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df1084=ftp.retrieve_data.get_all_data_for_indicators(273, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df1445=ftp.retrieve_data.get_all_data_for_indicators(848, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df1806=ftp.retrieve_data.get_all_data_for_indicators(1203, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df2167=ftp.retrieve_data.get_all_data_for_indicators(1204, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df2528=ftp.retrieve_data.get_all_data_for_indicators(1205, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df2889=ftp.retrieve_data.get_all_data_for_indicators(1206, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df3250=ftp.retrieve_data.get_all_data_for_indicators(1208, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df3611=ftp.retrieve_data.get_all_data_for_indicators(1730, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df3972=ftp.retrieve_data.get_all_data_for_indicators(10101, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df4333=ftp.retrieve_data.get_all_data_for_indicators(10301, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df4694=ftp.retrieve_data.get_all_data_for_indicators(11001, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df5055=ftp.retrieve_data.get_all_data_for_indicators(11201, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df5416=ftp.retrieve_data.get_all_data_for_indicators(11202, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df5777=ftp.retrieve_data.get_all_data_for_indicators(11401, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df6138=ftp.retrieve_data.get_all_data_for_indicators(11501, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df6499=ftp.retrieve_data.get_all_data_for_indicators(11601, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df6860=ftp.retrieve_data.get_all_data_for_indicators(20101, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df7221=ftp.retrieve_data.get_all_data_for_indicators(20401, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df7582=ftp.retrieve_data.get_all_data_for_indicators(20601, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df7943=ftp.retrieve_data.get_all_data_for_indicators(20602, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df8304=ftp.retrieve_data.get_all_data_for_indicators(21001, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df8665=ftp.retrieve_data.get_all_data_for_indicators(22001, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df9026=ftp.retrieve_data.get_all_data_for_indicators(22401, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df9387=ftp.retrieve_data.get_all_data_for_indicators(22402, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df9748=ftp.retrieve_data.get_all_data_for_indicators(22403, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df10109=ftp.retrieve_data.get_all_data_for_indicators(30101, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df10470=ftp.retrieve_data.get_all_data_for_indicators(40401, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df10831=ftp.retrieve_data.get_all_data_for_indicators(40501, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df11192=ftp.retrieve_data.get_all_data_for_indicators(40601, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df11553=ftp.retrieve_data.get_all_data_for_indicators(40701, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df11914=ftp.retrieve_data.get_all_data_for_indicators(41001, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df12275=ftp.retrieve_data.get_all_data_for_indicators(41101, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df12636=ftp.retrieve_data.get_all_data_for_indicators(41401, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df12997=ftp.retrieve_data.get_all_data_for_indicators(41402, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df13358=ftp.retrieve_data.get_all_data_for_indicators(41403, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df13719=ftp.retrieve_data.get_all_data_for_indicators(90282, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df14080=ftp.retrieve_data.get_all_data_for_indicators(90284, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df14441=ftp.retrieve_data.get_all_data_for_indicators(90285, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df14802=ftp.retrieve_data.get_all_data_for_indicators(90286, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df15163=ftp.retrieve_data.get_all_data_for_indicators(90287, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df15524=ftp.retrieve_data.get_all_data_for_indicators(90290, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df15885=ftp.retrieve_data.get_all_data_for_indicators(90291, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df16246=ftp.retrieve_data.get_all_data_for_indicators(90292, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df16607=ftp.retrieve_data.get_all_data_for_indicators(90312, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df16968=ftp.retrieve_data.get_all_data_for_indicators(90313, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df17329=ftp.retrieve_data.get_all_data_for_indicators(90314, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df17690=ftp.retrieve_data.get_all_data_for_indicators(90315, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df18051=ftp.retrieve_data.get_all_data_for_indicators(90316, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df18412=ftp.retrieve_data.get_all_data_for_indicators(90317, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df18773=ftp.retrieve_data.get_all_data_for_indicators(90319, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df19134=ftp.retrieve_data.get_all_data_for_indicators(90320, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df19495=ftp.retrieve_data.get_all_data_for_indicators(90321, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df19856=ftp.retrieve_data.get_all_data_for_indicators(90323, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df20217=ftp.retrieve_data.get_all_data_for_indicators(90356, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df20578=ftp.retrieve_data.get_all_data_for_indicators(90360, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df20939=ftp.retrieve_data.get_all_data_for_indicators(90361, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df21300=ftp.retrieve_data.get_all_data_for_indicators(90366, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df21661=ftp.retrieve_data.get_all_data_for_indicators(90371, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df22022=ftp.retrieve_data.get_all_data_for_indicators(90411, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df22383=ftp.retrieve_data.get_all_data_for_indicators(90416, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df22744=ftp.retrieve_data.get_all_data_for_indicators(90443, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df23105=ftp.retrieve_data.get_all_data_for_indicators(90630, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df23466=ftp.retrieve_data.get_all_data_for_indicators(90637, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df23827=ftp.retrieve_data.get_all_data_for_indicators(90656, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df24188=ftp.retrieve_data.get_all_data_for_indicators(90729, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df24549=ftp.retrieve_data.get_all_data_for_indicators(90731, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df24910=ftp.retrieve_data.get_all_data_for_indicators(90739, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df25271=ftp.retrieve_data.get_all_data_for_indicators(90740, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df25632=ftp.retrieve_data.get_all_data_for_indicators(90742, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df25993=ftp.retrieve_data.get_all_data_for_indicators(90759, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df26354=ftp.retrieve_data.get_all_data_for_indicators(90776, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df26715=ftp.retrieve_data.get_all_data_for_indicators(90777, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df27076=ftp.retrieve_data.get_all_data_for_indicators(90790, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df27437=ftp.retrieve_data.get_all_data_for_indicators(90791, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df27798=ftp.retrieve_data.get_all_data_for_indicators(90804, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df28159=ftp.retrieve_data.get_all_data_for_indicators(90832, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df28520=ftp.retrieve_data.get_all_data_for_indicators(90851, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df28881=ftp.retrieve_data.get_all_data_for_indicators(90892, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df29242=ftp.retrieve_data.get_all_data_for_indicators(91046, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df29603=ftp.retrieve_data.get_all_data_for_indicators(91048, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df29964=ftp.retrieve_data.get_all_data_for_indicators(91049, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df30325=ftp.retrieve_data.get_all_data_for_indicators(91050, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df30686=ftp.retrieve_data.get_all_data_for_indicators(91102, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df31047=ftp.retrieve_data.get_all_data_for_indicators(91126, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df31408=ftp.retrieve_data.get_all_data_for_indicators(91133, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df31769=ftp.retrieve_data.get_all_data_for_indicators(91143, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df32130=ftp.retrieve_data.get_all_data_for_indicators(91155, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df32491=ftp.retrieve_data.get_all_data_for_indicators(91156, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df32852=ftp.retrieve_data.get_all_data_for_indicators(91163, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df33213=ftp.retrieve_data.get_all_data_for_indicators(91164, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df33574=ftp.retrieve_data.get_all_data_for_indicators(91165, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df33935=ftp.retrieve_data.get_all_data_for_indicators(91166, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df34296=ftp.retrieve_data.get_all_data_for_indicators(91167, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df34657=ftp.retrieve_data.get_all_data_for_indicators(91195, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df35018=ftp.retrieve_data.get_all_data_for_indicators(91269, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df35379=ftp.retrieve_data.get_all_data_for_indicators(91306, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df35740=ftp.retrieve_data.get_all_data_for_indicators(91307, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df36101=ftp.retrieve_data.get_all_data_for_indicators(91308, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df36462=ftp.retrieve_data.get_all_data_for_indicators(91361, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df36823=ftp.retrieve_data.get_all_data_for_indicators(91367, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df37184=ftp.retrieve_data.get_all_data_for_indicators(91380, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df37545=ftp.retrieve_data.get_all_data_for_indicators(91381, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df37906=ftp.retrieve_data.get_all_data_for_indicators(91458, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df38267=ftp.retrieve_data.get_all_data_for_indicators(91493, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df38628=ftp.retrieve_data.get_all_data_for_indicators(91494, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df38989=ftp.retrieve_data.get_all_data_for_indicators(91514, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df39350=ftp.retrieve_data.get_all_data_for_indicators(91521, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df39711=ftp.retrieve_data.get_all_data_for_indicators(91522, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df40072=ftp.retrieve_data.get_all_data_for_indicators(91523, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df40433=ftp.retrieve_data.get_all_data_for_indicators(91525, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df40794=ftp.retrieve_data.get_all_data_for_indicators(91547, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df41155=ftp.retrieve_data.get_all_data_for_indicators(91720, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df41516=ftp.retrieve_data.get_all_data_for_indicators(91743, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df41877=ftp.retrieve_data.get_all_data_for_indicators(91818, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df42238=ftp.retrieve_data.get_all_data_for_indicators(91819, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df42599=ftp.retrieve_data.get_all_data_for_indicators(91872, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df42960=ftp.retrieve_data.get_all_data_for_indicators(92026, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df43321=ftp.retrieve_data.get_all_data_for_indicators(92033, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df43682=ftp.retrieve_data.get_all_data_for_indicators(92196, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df44043=ftp.retrieve_data.get_all_data_for_indicators(92199, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df44404=ftp.retrieve_data.get_all_data_for_indicators(92254, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df44765=ftp.retrieve_data.get_all_data_for_indicators(92255, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df45126=ftp.retrieve_data.get_all_data_for_indicators(92290, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df45487=ftp.retrieve_data.get_all_data_for_indicators(92291, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df45848=ftp.retrieve_data.get_all_data_for_indicators(92292, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df46209=ftp.retrieve_data.get_all_data_for_indicators(92293, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df46570=ftp.retrieve_data.get_all_data_for_indicators(92294, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df46931=ftp.retrieve_data.get_all_data_for_indicators(92302, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df47292=ftp.retrieve_data.get_all_data_for_indicators(92304, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df47653=ftp.retrieve_data.get_all_data_for_indicators(92306, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df48014=ftp.retrieve_data.get_all_data_for_indicators(92308, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df48375=ftp.retrieve_data.get_all_data_for_indicators(92309, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df48736=ftp.retrieve_data.get_all_data_for_indicators(92310, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df49097=ftp.retrieve_data.get_all_data_for_indicators(92313, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df49458=ftp.retrieve_data.get_all_data_for_indicators(92317, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df49819=ftp.retrieve_data.get_all_data_for_indicators(92323, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df50180=ftp.retrieve_data.get_all_data_for_indicators(92326, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df50541=ftp.retrieve_data.get_all_data_for_indicators(92432, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df50902=ftp.retrieve_data.get_all_data_for_indicators(92443, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df51263=ftp.retrieve_data.get_all_data_for_indicators(92445, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df51624=ftp.retrieve_data.get_all_data_for_indicators(92453, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df51985=ftp.retrieve_data.get_all_data_for_indicators(92464, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df52346=ftp.retrieve_data.get_all_data_for_indicators(92465, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df52707=ftp.retrieve_data.get_all_data_for_indicators(92488, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df53068=ftp.retrieve_data.get_all_data_for_indicators(92489, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df53429=ftp.retrieve_data.get_all_data_for_indicators(92490, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df53790=ftp.retrieve_data.get_all_data_for_indicators(92534, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df54151=ftp.retrieve_data.get_all_data_for_indicators(92538, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df54512=ftp.retrieve_data.get_all_data_for_indicators(92635, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df54873=ftp.retrieve_data.get_all_data_for_indicators(92670, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df55234=ftp.retrieve_data.get_all_data_for_indicators(92708, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df55595=ftp.retrieve_data.get_all_data_for_indicators(92718, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df55956=ftp.retrieve_data.get_all_data_for_indicators(92724, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df56317=ftp.retrieve_data.get_all_data_for_indicators(92725, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df56678=ftp.retrieve_data.get_all_data_for_indicators(92763, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df57039=ftp.retrieve_data.get_all_data_for_indicators(92765, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df57400=ftp.retrieve_data.get_all_data_for_indicators(92768, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df57761=ftp.retrieve_data.get_all_data_for_indicators(92770, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df58122=ftp.retrieve_data.get_all_data_for_indicators(92772, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df58483=ftp.retrieve_data.get_all_data_for_indicators(92841, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df58844=ftp.retrieve_data.get_all_data_for_indicators(92860, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df59205=ftp.retrieve_data.get_all_data_for_indicators(92899, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df59566=ftp.retrieve_data.get_all_data_for_indicators(92901, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df59927=ftp.retrieve_data.get_all_data_for_indicators(92904, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df60288=ftp.retrieve_data.get_all_data_for_indicators(92906, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df60649=ftp.retrieve_data.get_all_data_for_indicators(92924, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df61010=ftp.retrieve_data.get_all_data_for_indicators(92937, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df61371=ftp.retrieve_data.get_all_data_for_indicators(92949, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df61732=ftp.retrieve_data.get_all_data_for_indicators(92953, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df62093=ftp.retrieve_data.get_all_data_for_indicators(93014, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df62454=ftp.retrieve_data.get_all_data_for_indicators(93015, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df62815=ftp.retrieve_data.get_all_data_for_indicators(93074, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df63176=ftp.retrieve_data.get_all_data_for_indicators(93077, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df63537=ftp.retrieve_data.get_all_data_for_indicators(93081, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df63898=ftp.retrieve_data.get_all_data_for_indicators(93082, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df64259=ftp.retrieve_data.get_all_data_for_indicators(93083, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df64620=ftp.retrieve_data.get_all_data_for_indicators(93084, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df64981=ftp.retrieve_data.get_all_data_for_indicators(93085, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df65342=ftp.retrieve_data.get_all_data_for_indicators(93086, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df65703=ftp.retrieve_data.get_all_data_for_indicators(93087, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df66064=ftp.retrieve_data.get_all_data_for_indicators(93088, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df66425=ftp.retrieve_data.get_all_data_for_indicators(93089, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df66786=ftp.retrieve_data.get_all_data_for_indicators(93091, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df67147=ftp.retrieve_data.get_all_data_for_indicators(93092, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df67508=ftp.retrieve_data.get_all_data_for_indicators(93093, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df67869=ftp.retrieve_data.get_all_data_for_indicators(93094, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df68230=ftp.retrieve_data.get_all_data_for_indicators(93095, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df68591=ftp.retrieve_data.get_all_data_for_indicators(93096, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df68952=ftp.retrieve_data.get_all_data_for_indicators(93097, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df69313=ftp.retrieve_data.get_all_data_for_indicators(93098, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df69674=ftp.retrieve_data.get_all_data_for_indicators(93103, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df70035=ftp.retrieve_data.get_all_data_for_indicators(93104, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df70396=ftp.retrieve_data.get_all_data_for_indicators(93105, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df70757=ftp.retrieve_data.get_all_data_for_indicators(93106, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df71118=ftp.retrieve_data.get_all_data_for_indicators(93107, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df71479=ftp.retrieve_data.get_all_data_for_indicators(93108, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df71840=ftp.retrieve_data.get_all_data_for_indicators(93111, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df72201=ftp.retrieve_data.get_all_data_for_indicators(93113, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df72562=ftp.retrieve_data.get_all_data_for_indicators(93114, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df72923=ftp.retrieve_data.get_all_data_for_indicators(93115, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df73284=ftp.retrieve_data.get_all_data_for_indicators(93119, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df73645=ftp.retrieve_data.get_all_data_for_indicators(93120, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df74006=ftp.retrieve_data.get_all_data_for_indicators(93124, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df74367=ftp.retrieve_data.get_all_data_for_indicators(93177, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df74728=ftp.retrieve_data.get_all_data_for_indicators(93190, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df75089=ftp.retrieve_data.get_all_data_for_indicators(93194, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df75450=ftp.retrieve_data.get_all_data_for_indicators(93195, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df75811=ftp.retrieve_data.get_all_data_for_indicators(93219, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df76172=ftp.retrieve_data.get_all_data_for_indicators(93224, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df76533=ftp.retrieve_data.get_all_data_for_indicators(93226, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df76894=ftp.retrieve_data.get_all_data_for_indicators(93227, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df77255=ftp.retrieve_data.get_all_data_for_indicators(93229, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df77616=ftp.retrieve_data.get_all_data_for_indicators(93231, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df77977=ftp.retrieve_data.get_all_data_for_indicators(93232, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df78338=ftp.retrieve_data.get_all_data_for_indicators(93233, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df78699=ftp.retrieve_data.get_all_data_for_indicators(93234, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df79060=ftp.retrieve_data.get_all_data_for_indicators(93235, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df79421=ftp.retrieve_data.get_all_data_for_indicators(93236, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df79782=ftp.retrieve_data.get_all_data_for_indicators(93237, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df80143=ftp.retrieve_data.get_all_data_for_indicators(93238, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df80504=ftp.retrieve_data.get_all_data_for_indicators(93239, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df80865=ftp.retrieve_data.get_all_data_for_indicators(93240, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df81226=ftp.retrieve_data.get_all_data_for_indicators(93241, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df81587=ftp.retrieve_data.get_all_data_for_indicators(93250, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df81948=ftp.retrieve_data.get_all_data_for_indicators(93252, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df82309=ftp.retrieve_data.get_all_data_for_indicators(93253, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df82670=ftp.retrieve_data.get_all_data_for_indicators(93254, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df83031=ftp.retrieve_data.get_all_data_for_indicators(93255, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df83392=ftp.retrieve_data.get_all_data_for_indicators(93256, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df83753=ftp.retrieve_data.get_all_data_for_indicators(93257, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df84114=ftp.retrieve_data.get_all_data_for_indicators(93259, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df84475=ftp.retrieve_data.get_all_data_for_indicators(93260, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df84836=ftp.retrieve_data.get_all_data_for_indicators(93267, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df85197=ftp.retrieve_data.get_all_data_for_indicators(93268, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df85558=ftp.retrieve_data.get_all_data_for_indicators(93274, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df85919=ftp.retrieve_data.get_all_data_for_indicators(93275, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df86280=ftp.retrieve_data.get_all_data_for_indicators(93276, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df86641=ftp.retrieve_data.get_all_data_for_indicators(93277, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df87002=ftp.retrieve_data.get_all_data_for_indicators(93279, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df87363=ftp.retrieve_data.get_all_data_for_indicators(93280, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df87724=ftp.retrieve_data.get_all_data_for_indicators(93283, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df88085=ftp.retrieve_data.get_all_data_for_indicators(93311, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df88446=ftp.retrieve_data.get_all_data_for_indicators(93312, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df88807=ftp.retrieve_data.get_all_data_for_indicators(93315, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df89168=ftp.retrieve_data.get_all_data_for_indicators(93316, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df89529=ftp.retrieve_data.get_all_data_for_indicators(93347, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df89890=ftp.retrieve_data.get_all_data_for_indicators(93350, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df90251=ftp.retrieve_data.get_all_data_for_indicators(93351, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df90612=ftp.retrieve_data.get_all_data_for_indicators(93353, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df90973=ftp.retrieve_data.get_all_data_for_indicators(93355, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df91334=ftp.retrieve_data.get_all_data_for_indicators(93356, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df91695=ftp.retrieve_data.get_all_data_for_indicators(93357, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df92056=ftp.retrieve_data.get_all_data_for_indicators(93372, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df92417=ftp.retrieve_data.get_all_data_for_indicators(93375, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df92778=ftp.retrieve_data.get_all_data_for_indicators(93376, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df93139=ftp.retrieve_data.get_all_data_for_indicators(93377, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df93500=ftp.retrieve_data.get_all_data_for_indicators(93378, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df93861=ftp.retrieve_data.get_all_data_for_indicators(93379, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df94222=ftp.retrieve_data.get_all_data_for_indicators(93380, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df94583=ftp.retrieve_data.get_all_data_for_indicators(93382, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df94944=ftp.retrieve_data.get_all_data_for_indicators(93383, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df95305=ftp.retrieve_data.get_all_data_for_indicators(93439, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df95666=ftp.retrieve_data.get_all_data_for_indicators(93440, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df96027=ftp.retrieve_data.get_all_data_for_indicators(93453, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df96388=ftp.retrieve_data.get_all_data_for_indicators(93454, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df96749=ftp.retrieve_data.get_all_data_for_indicators(93455, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df97110=ftp.retrieve_data.get_all_data_for_indicators(93456, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df97471=ftp.retrieve_data.get_all_data_for_indicators(93463, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df97832=ftp.retrieve_data.get_all_data_for_indicators(93465, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df98193=ftp.retrieve_data.get_all_data_for_indicators(93466, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df98554=ftp.retrieve_data.get_all_data_for_indicators(93467, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df98915=ftp.retrieve_data.get_all_data_for_indicators(93474, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df99276=ftp.retrieve_data.get_all_data_for_indicators(93475, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df99637=ftp.retrieve_data.get_all_data_for_indicators(93476, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df99998=ftp.retrieve_data.get_all_data_for_indicators(93477, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df100359=ftp.retrieve_data.get_all_data_for_indicators(93478, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df100720=ftp.retrieve_data.get_all_data_for_indicators(93480, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df101081=ftp.retrieve_data.get_all_data_for_indicators(93488, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df101442=ftp.retrieve_data.get_all_data_for_indicators(93489, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df101803=ftp.retrieve_data.get_all_data_for_indicators(93491, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df102164=ftp.retrieve_data.get_all_data_for_indicators(93495, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df102525=ftp.retrieve_data.get_all_data_for_indicators(93496, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df102886=ftp.retrieve_data.get_all_data_for_indicators(93497, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df103247=ftp.retrieve_data.get_all_data_for_indicators(93498, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df103608=ftp.retrieve_data.get_all_data_for_indicators(93499, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df103969=ftp.retrieve_data.get_all_data_for_indicators(93506, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df104330=ftp.retrieve_data.get_all_data_for_indicators(93507, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df104691=ftp.retrieve_data.get_all_data_for_indicators(93513, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df105052=ftp.retrieve_data.get_all_data_for_indicators(93515, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df105413=ftp.retrieve_data.get_all_data_for_indicators(93546, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df105774=ftp.retrieve_data.get_all_data_for_indicators(93550, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df106135=ftp.retrieve_data.get_all_data_for_indicators(93551, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df106496=ftp.retrieve_data.get_all_data_for_indicators(93553, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df106857=ftp.retrieve_data.get_all_data_for_indicators(93560, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df107218=ftp.retrieve_data.get_all_data_for_indicators(93561, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df107579=ftp.retrieve_data.get_all_data_for_indicators(93563, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df107940=ftp.retrieve_data.get_all_data_for_indicators(93570, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df108301=ftp.retrieve_data.get_all_data_for_indicators(93572, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df108662=ftp.retrieve_data.get_all_data_for_indicators(93580, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df109023=ftp.retrieve_data.get_all_data_for_indicators(93604, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df109384=ftp.retrieve_data.get_all_data_for_indicators(93644, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df109745=ftp.retrieve_data.get_all_data_for_indicators(93670, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df110106=ftp.retrieve_data.get_all_data_for_indicators(93671, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df110467=ftp.retrieve_data.get_all_data_for_indicators(93691, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df110828=ftp.retrieve_data.get_all_data_for_indicators(93700, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df111189=ftp.retrieve_data.get_all_data_for_indicators(93701, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df111550=ftp.retrieve_data.get_all_data_for_indicators(93720, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df111911=ftp.retrieve_data.get_all_data_for_indicators(93721, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df112272=ftp.retrieve_data.get_all_data_for_indicators(93722, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df112633=ftp.retrieve_data.get_all_data_for_indicators(93723, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df112994=ftp.retrieve_data.get_all_data_for_indicators(93724, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df113355=ftp.retrieve_data.get_all_data_for_indicators(93735, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df113716=ftp.retrieve_data.get_all_data_for_indicators(93736, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df114077=ftp.retrieve_data.get_all_data_for_indicators(93737, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df114438=ftp.retrieve_data.get_all_data_for_indicators(93738, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df114799=ftp.retrieve_data.get_all_data_for_indicators(93739, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df115160=ftp.retrieve_data.get_all_data_for_indicators(93742, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df115521=ftp.retrieve_data.get_all_data_for_indicators(93744, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df115882=ftp.retrieve_data.get_all_data_for_indicators(93745, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df116243=ftp.retrieve_data.get_all_data_for_indicators(93746, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df116604=ftp.retrieve_data.get_all_data_for_indicators(93747, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df116965=ftp.retrieve_data.get_all_data_for_indicators(93748, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df117326=ftp.retrieve_data.get_all_data_for_indicators(93750, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df117687=ftp.retrieve_data.get_all_data_for_indicators(93751, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df118048=ftp.retrieve_data.get_all_data_for_indicators(93753, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df118409=ftp.retrieve_data.get_all_data_for_indicators(93754, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df118770=ftp.retrieve_data.get_all_data_for_indicators(93758, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df119131=ftp.retrieve_data.get_all_data_for_indicators(93759, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df119492=ftp.retrieve_data.get_all_data_for_indicators(93760, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df119853=ftp.retrieve_data.get_all_data_for_indicators(93761, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df120214=ftp.retrieve_data.get_all_data_for_indicators(93763, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df120575=ftp.retrieve_data.get_all_data_for_indicators(93764, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df120936=ftp.retrieve_data.get_all_data_for_indicators(93765, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df121297=ftp.retrieve_data.get_all_data_for_indicators(93766, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df121658=ftp.retrieve_data.get_all_data_for_indicators(93767, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df122019=ftp.retrieve_data.get_all_data_for_indicators(93768, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df122380=ftp.retrieve_data.get_all_data_for_indicators(93769, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df122741=ftp.retrieve_data.get_all_data_for_indicators(93770, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df123102=ftp.retrieve_data.get_all_data_for_indicators(93771, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df123463=ftp.retrieve_data.get_all_data_for_indicators(93772, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df123824=ftp.retrieve_data.get_all_data_for_indicators(93773, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df124185=ftp.retrieve_data.get_all_data_for_indicators(93774, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df124546=ftp.retrieve_data.get_all_data_for_indicators(93786, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df124907=ftp.retrieve_data.get_all_data_for_indicators(93787, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df125268=ftp.retrieve_data.get_all_data_for_indicators(93788, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df125629=ftp.retrieve_data.get_all_data_for_indicators(93823, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df125990=ftp.retrieve_data.get_all_data_for_indicators(93827, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df126351=ftp.retrieve_data.get_all_data_for_indicators(93840, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df126712=ftp.retrieve_data.get_all_data_for_indicators(93861, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df127073=ftp.retrieve_data.get_all_data_for_indicators(93863, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df127434=ftp.retrieve_data.get_all_data_for_indicators(93865, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df127795=ftp.retrieve_data.get_all_data_for_indicators(93867, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df128156=ftp.retrieve_data.get_all_data_for_indicators(93880, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df128517=ftp.retrieve_data.get_all_data_for_indicators(93881, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df128878=ftp.retrieve_data.get_all_data_for_indicators(93882, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df129239=ftp.retrieve_data.get_all_data_for_indicators(93884, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df129600=ftp.retrieve_data.get_all_data_for_indicators(93928, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
df129961=ftp.retrieve_data.get_all_data_for_indicators(93929, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
# Out:
# <ipython-input-4-55bc0775ea60>:1: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   df1=ftp.retrieve_data.get_all_data_for_indicators(108, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
# <ipython-input-4-55bc0775ea60>:32: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   df11192=ftp.retrieve_data.get_all_data_for_indicators(40601, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
# <ipython-input-4-55bc0775ea60>:33: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   df11553=ftp.retrieve_data.get_all_data_for_indicators(40701, area_type_id=401, parent_area_type_id=15, filter_by_area_codes=None, is_test=False)
# <ipython-input-4-55bc0775ea60>:60: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
# ...

# %% [markdown]
# Step 2: clean data

# %%
df2=df1.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df363=df362.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df123464=df123463.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df123825=df123824.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df124186=df124185.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df124547=df124546.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df124908=df124907.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df125269=df125268.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df125630=df125629.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df125991=df125990.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df126352=df126351.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df126713=df126712.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df127074=df127073.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df127435=df127434.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df127796=df127795.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df128157=df128156.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df128518=df128517.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df128879=df128878.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df129240=df129239.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df129601=df129600.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)
df129962=df129961.drop(['Area Type','Indicator ID','Compared to percentiles','Parent Code','Parent Name','Category Type','Count','Category','Lower CI 95.0 limit','Time period Sortable','Upper CI 95.0 limit','Lower CI 99.8 limit','Upper CI 99.8 limit','Denominator','Value note','Recent Trend','New data','Compared to goal','Time period range','Compared to England value or percentiles'],axis=1)

# %% [markdown]
# Step 3: remove nation-level data

# %%
df3=df2.loc[df2["Area Name"] != "England" ]
df364=df363.loc[df363["Area Name"] != "England" ]
df725=df724.loc[df724["Area Name"] != "England" ]
df1086=df1085.loc[df1085["Area Name"] != "England" ]
df1447=df1446.loc[df1446["Area Name"] != "England" ]
df1808=df1807.loc[df1807["Area Name"] != "England" ]
df2169=df2168.loc[df2168["Area Name"] != "England" ]
df2530=df2529.loc[df2529["Area Name"] != "England" ]
df2891=df2890.loc[df2890["Area Name"] != "England" ]
df3252=df3251.loc[df3251["Area Name"] != "England" ]
df3613=df3612.loc[df3612["Area Name"] != "England" ]
df3974=df3973.loc[df3973["Area Name"] != "England" ]
df4335=df4334.loc[df4334["Area Name"] != "England" ]
df4696=df4695.loc[df4695["Area Name"] != "England" ]
df5057=df5056.loc[df5056["Area Name"] != "England" ]
df5418=df5417.loc[df5417["Area Name"] != "England" ]
df5779=df5778.loc[df5778["Area Name"] != "England" ]
df6140=df6139.loc[df6139["Area Name"] != "England" ]
df6501=df6500.loc[df6500["Area Name"] != "England" ]
df6862=df6861.loc[df6861["Area Name"] != "England" ]
df7223=df7222.loc[df7222["Area Name"] != "England" ]
df7584=df7583.loc[df7583["Area Name"] != "England" ]
df7945=df7944.loc[df7944["Area Name"] != "England" ]
df8306=df8305.loc[df8305["Area Name"] != "England" ]
df8667=df8666.loc[df8666["Area Name"] != "England" ]
df9028=df9027.loc[df9027["Area Name"] != "England" ]
df9389=df9388.loc[df9388["Area Name"] != "England" ]
df9750=df9749.loc[df9749["Area Name"] != "England" ]
df10111=df10110.loc[df10110["Area Name"] != "England" ]
df10472=df10471.loc[df10471["Area Name"] != "England" ]
df10833=df10832.loc[df10832["Area Name"] != "England" ]
df11194=df11193.loc[df11193["Area Name"] != "England" ]
df11555=df11554.loc[df11554["Area Name"] != "England" ]
df11916=df11915.loc[df11915["Area Name"] != "England" ]
df12277=df12276.loc[df12276["Area Name"] != "England" ]
df12638=df12637.loc[df12637["Area Name"] != "England" ]
df12999=df12998.loc[df12998["Area Name"] != "England" ]
df13360=df13359.loc[df13359["Area Name"] != "England" ]
df13721=df13720.loc[df13720["Area Name"] != "England" ]
df14082=df14081.loc[df14081["Area Name"] != "England" ]
df14443=df14442.loc[df14442["Area Name"] != "England" ]
df14804=df14803.loc[df14803["Area Name"] != "England" ]
df15165=df15164.loc[df15164["Area Name"] != "England" ]
df15526=df15525.loc[df15525["Area Name"] != "England" ]
df15887=df15886.loc[df15886["Area Name"] != "England" ]
df16248=df16247.loc[df16247["Area Name"] != "England" ]
df16609=df16608.loc[df16608["Area Name"] != "England" ]
df16970=df16969.loc[df16969["Area Name"] != "England" ]
df17331=df17330.loc[df17330["Area Name"] != "England" ]
df17692=df17691.loc[df17691["Area Name"] != "England" ]
df18053=df18052.loc[df18052["Area Name"] != "England" ]
df18414=df18413.loc[df18413["Area Name"] != "England" ]
df18775=df18774.loc[df18774["Area Name"] != "England" ]
df19136=df19135.loc[df19135["Area Name"] != "England" ]
df19497=df19496.loc[df19496["Area Name"] != "England" ]
df19858=df19857.loc[df19857["Area Name"] != "England" ]
df20219=df20218.loc[df20218["Area Name"] != "England" ]
df20580=df20579.loc[df20579["Area Name"] != "England" ]
df20941=df20940.loc[df20940["Area Name"] != "England" ]
df21302=df21301.loc[df21301["Area Name"] != "England" ]
df21663=df21662.loc[df21662["Area Name"] != "England" ]
df22024=df22023.loc[df22023["Area Name"] != "England" ]
df22385=df22384.loc[df22384["Area Name"] != "England" ]
df22746=df22745.loc[df22745["Area Name"] != "England" ]
df23107=df23106.loc[df23106["Area Name"] != "England" ]
df23468=df23467.loc[df23467["Area Name"] != "England" ]
df23829=df23828.loc[df23828["Area Name"] != "England" ]
df24190=df24189.loc[df24189["Area Name"] != "England" ]
df24551=df24550.loc[df24550["Area Name"] != "England" ]
df24912=df24911.loc[df24911["Area Name"] != "England" ]
df25273=df25272.loc[df25272["Area Name"] != "England" ]
df25634=df25633.loc[df25633["Area Name"] != "England" ]
df25995=df25994.loc[df25994["Area Name"] != "England" ]
df26356=df26355.loc[df26355["Area Name"] != "England" ]
df26717=df26716.loc[df26716["Area Name"] != "England" ]
df27078=df27077.loc[df27077["Area Name"] != "England" ]
df27439=df27438.loc[df27438["Area Name"] != "England" ]
df27800=df27799.loc[df27799["Area Name"] != "England" ]
df28161=df28160.loc[df28160["Area Name"] != "England" ]
df28522=df28521.loc[df28521["Area Name"] != "England" ]
df28883=df28882.loc[df28882["Area Name"] != "England" ]
df29244=df29243.loc[df29243["Area Name"] != "England" ]
df29605=df29604.loc[df29604["Area Name"] != "England" ]
df29966=df29965.loc[df29965["Area Name"] != "England" ]
df30327=df30326.loc[df30326["Area Name"] != "England" ]
df30688=df30687.loc[df30687["Area Name"] != "England" ]
df31049=df31048.loc[df31048["Area Name"] != "England" ]
df31410=df31409.loc[df31409["Area Name"] != "England" ]
df31771=df31770.loc[df31770["Area Name"] != "England" ]
df32132=df32131.loc[df32131["Area Name"] != "England" ]
df32493=df32492.loc[df32492["Area Name"] != "England" ]
df32854=df32853.loc[df32853["Area Name"] != "England" ]
df33215=df33214.loc[df33214["Area Name"] != "England" ]
df33576=df33575.loc[df33575["Area Name"] != "England" ]
df33937=df33936.loc[df33936["Area Name"] != "England" ]
df34298=df34297.loc[df34297["Area Name"] != "England" ]
df34659=df34658.loc[df34658["Area Name"] != "England" ]
df35020=df35019.loc[df35019["Area Name"] != "England" ]
df35381=df35380.loc[df35380["Area Name"] != "England" ]
df35742=df35741.loc[df35741["Area Name"] != "England" ]
df36103=df36102.loc[df36102["Area Name"] != "England" ]
df36464=df36463.loc[df36463["Area Name"] != "England" ]
df36825=df36824.loc[df36824["Area Name"] != "England" ]
df37186=df37185.loc[df37185["Area Name"] != "England" ]
df37547=df37546.loc[df37546["Area Name"] != "England" ]
df37908=df37907.loc[df37907["Area Name"] != "England" ]
df38269=df38268.loc[df38268["Area Name"] != "England" ]
df38630=df38629.loc[df38629["Area Name"] != "England" ]
df38991=df38990.loc[df38990["Area Name"] != "England" ]
df39352=df39351.loc[df39351["Area Name"] != "England" ]
df39713=df39712.loc[df39712["Area Name"] != "England" ]
df40074=df40073.loc[df40073["Area Name"] != "England" ]
df40435=df40434.loc[df40434["Area Name"] != "England" ]
df40796=df40795.loc[df40795["Area Name"] != "England" ]
df41157=df41156.loc[df41156["Area Name"] != "England" ]
df41518=df41517.loc[df41517["Area Name"] != "England" ]
df41879=df41878.loc[df41878["Area Name"] != "England" ]
df42240=df42239.loc[df42239["Area Name"] != "England" ]
df42601=df42600.loc[df42600["Area Name"] != "England" ]
df42962=df42961.loc[df42961["Area Name"] != "England" ]
df43323=df43322.loc[df43322["Area Name"] != "England" ]
df43684=df43683.loc[df43683["Area Name"] != "England" ]
df44045=df44044.loc[df44044["Area Name"] != "England" ]
df44406=df44405.loc[df44405["Area Name"] != "England" ]
df44767=df44766.loc[df44766["Area Name"] != "England" ]
df45128=df45127.loc[df45127["Area Name"] != "England" ]
df45489=df45488.loc[df45488["Area Name"] != "England" ]
df45850=df45849.loc[df45849["Area Name"] != "England" ]
df46211=df46210.loc[df46210["Area Name"] != "England" ]
df46572=df46571.loc[df46571["Area Name"] != "England" ]
df46933=df46932.loc[df46932["Area Name"] != "England" ]
df47294=df47293.loc[df47293["Area Name"] != "England" ]
df47655=df47654.loc[df47654["Area Name"] != "England" ]
df48016=df48015.loc[df48015["Area Name"] != "England" ]
df48377=df48376.loc[df48376["Area Name"] != "England" ]
df48738=df48737.loc[df48737["Area Name"] != "England" ]
df49099=df49098.loc[df49098["Area Name"] != "England" ]
df49460=df49459.loc[df49459["Area Name"] != "England" ]
df49821=df49820.loc[df49820["Area Name"] != "England" ]
df50182=df50181.loc[df50181["Area Name"] != "England" ]
df50543=df50542.loc[df50542["Area Name"] != "England" ]
df50904=df50903.loc[df50903["Area Name"] != "England" ]
df51265=df51264.loc[df51264["Area Name"] != "England" ]
df51626=df51625.loc[df51625["Area Name"] != "England" ]
df51987=df51986.loc[df51986["Area Name"] != "England" ]
df52348=df52347.loc[df52347["Area Name"] != "England" ]
df52709=df52708.loc[df52708["Area Name"] != "England" ]
df53070=df53069.loc[df53069["Area Name"] != "England" ]
df53431=df53430.loc[df53430["Area Name"] != "England" ]
df53792=df53791.loc[df53791["Area Name"] != "England" ]
df54153=df54152.loc[df54152["Area Name"] != "England" ]
df54514=df54513.loc[df54513["Area Name"] != "England" ]
df54875=df54874.loc[df54874["Area Name"] != "England" ]
df55236=df55235.loc[df55235["Area Name"] != "England" ]
df55597=df55596.loc[df55596["Area Name"] != "England" ]
df55958=df55957.loc[df55957["Area Name"] != "England" ]
df56319=df56318.loc[df56318["Area Name"] != "England" ]
df56680=df56679.loc[df56679["Area Name"] != "England" ]
df57041=df57040.loc[df57040["Area Name"] != "England" ]
df57402=df57401.loc[df57401["Area Name"] != "England" ]
df57763=df57762.loc[df57762["Area Name"] != "England" ]
df58124=df58123.loc[df58123["Area Name"] != "England" ]
df58485=df58484.loc[df58484["Area Name"] != "England" ]
df58846=df58845.loc[df58845["Area Name"] != "England" ]
df59207=df59206.loc[df59206["Area Name"] != "England" ]
df59568=df59567.loc[df59567["Area Name"] != "England" ]
df59929=df59928.loc[df59928["Area Name"] != "England" ]
df60290=df60289.loc[df60289["Area Name"] != "England" ]
df60651=df60650.loc[df60650["Area Name"] != "England" ]
df61012=df61011.loc[df61011["Area Name"] != "England" ]
df61373=df61372.loc[df61372["Area Name"] != "England" ]
df61734=df61733.loc[df61733["Area Name"] != "England" ]
df62095=df62094.loc[df62094["Area Name"] != "England" ]
df62456=df62455.loc[df62455["Area Name"] != "England" ]
df62817=df62816.loc[df62816["Area Name"] != "England" ]
df63178=df63177.loc[df63177["Area Name"] != "England" ]
df63539=df63538.loc[df63538["Area Name"] != "England" ]
df63900=df63899.loc[df63899["Area Name"] != "England" ]
df64261=df64260.loc[df64260["Area Name"] != "England" ]
df64622=df64621.loc[df64621["Area Name"] != "England" ]
df64983=df64982.loc[df64982["Area Name"] != "England" ]
df65344=df65343.loc[df65343["Area Name"] != "England" ]
df65705=df65704.loc[df65704["Area Name"] != "England" ]
df66066=df66065.loc[df66065["Area Name"] != "England" ]
df66427=df66426.loc[df66426["Area Name"] != "England" ]
df66788=df66787.loc[df66787["Area Name"] != "England" ]
df67149=df67148.loc[df67148["Area Name"] != "England" ]
df67510=df67509.loc[df67509["Area Name"] != "England" ]
df67871=df67870.loc[df67870["Area Name"] != "England" ]
df68232=df68231.loc[df68231["Area Name"] != "England" ]
df68593=df68592.loc[df68592["Area Name"] != "England" ]
df68954=df68953.loc[df68953["Area Name"] != "England" ]
df69315=df69314.loc[df69314["Area Name"] != "England" ]
df69676=df69675.loc[df69675["Area Name"] != "England" ]
df70037=df70036.loc[df70036["Area Name"] != "England" ]
df70398=df70397.loc[df70397["Area Name"] != "England" ]
df70759=df70758.loc[df70758["Area Name"] != "England" ]
df71120=df71119.loc[df71119["Area Name"] != "England" ]
df71481=df71480.loc[df71480["Area Name"] != "England" ]
df71842=df71841.loc[df71841["Area Name"] != "England" ]
df72203=df72202.loc[df72202["Area Name"] != "England" ]
df72564=df72563.loc[df72563["Area Name"] != "England" ]
df72925=df72924.loc[df72924["Area Name"] != "England" ]
df73286=df73285.loc[df73285["Area Name"] != "England" ]
df73647=df73646.loc[df73646["Area Name"] != "England" ]
df74008=df74007.loc[df74007["Area Name"] != "England" ]
df74369=df74368.loc[df74368["Area Name"] != "England" ]
df74730=df74729.loc[df74729["Area Name"] != "England" ]
df75091=df75090.loc[df75090["Area Name"] != "England" ]
df75452=df75451.loc[df75451["Area Name"] != "England" ]
df75813=df75812.loc[df75812["Area Name"] != "England" ]
df76174=df76173.loc[df76173["Area Name"] != "England" ]
df76535=df76534.loc[df76534["Area Name"] != "England" ]
df76896=df76895.loc[df76895["Area Name"] != "England" ]
df77257=df77256.loc[df77256["Area Name"] != "England" ]
df77618=df77617.loc[df77617["Area Name"] != "England" ]
df77979=df77978.loc[df77978["Area Name"] != "England" ]
df78340=df78339.loc[df78339["Area Name"] != "England" ]
df78701=df78700.loc[df78700["Area Name"] != "England" ]
df79062=df79061.loc[df79061["Area Name"] != "England" ]
df79423=df79422.loc[df79422["Area Name"] != "England" ]
df79784=df79783.loc[df79783["Area Name"] != "England" ]
df80145=df80144.loc[df80144["Area Name"] != "England" ]
df80506=df80505.loc[df80505["Area Name"] != "England" ]
df80867=df80866.loc[df80866["Area Name"] != "England" ]
df81228=df81227.loc[df81227["Area Name"] != "England" ]
df81589=df81588.loc[df81588["Area Name"] != "England" ]
df81950=df81949.loc[df81949["Area Name"] != "England" ]
df82311=df82310.loc[df82310["Area Name"] != "England" ]
df82672=df82671.loc[df82671["Area Name"] != "England" ]
df83033=df83032.loc[df83032["Area Name"] != "England" ]
df83394=df83393.loc[df83393["Area Name"] != "England" ]
df83755=df83754.loc[df83754["Area Name"] != "England" ]
df84116=df84115.loc[df84115["Area Name"] != "England" ]
df84477=df84476.loc[df84476["Area Name"] != "England" ]
df84838=df84837.loc[df84837["Area Name"] != "England" ]
df85199=df85198.loc[df85198["Area Name"] != "England" ]
df85560=df85559.loc[df85559["Area Name"] != "England" ]
df85921=df85920.loc[df85920["Area Name"] != "England" ]
df86282=df86281.loc[df86281["Area Name"] != "England" ]
df86643=df86642.loc[df86642["Area Name"] != "England" ]
df87004=df87003.loc[df87003["Area Name"] != "England" ]
df87365=df87364.loc[df87364["Area Name"] != "England" ]
df87726=df87725.loc[df87725["Area Name"] != "England" ]
df88087=df88086.loc[df88086["Area Name"] != "England" ]
df88448=df88447.loc[df88447["Area Name"] != "England" ]
df88809=df88808.loc[df88808["Area Name"] != "England" ]
df89170=df89169.loc[df89169["Area Name"] != "England" ]
df89531=df89530.loc[df89530["Area Name"] != "England" ]
df89892=df89891.loc[df89891["Area Name"] != "England" ]
df90253=df90252.loc[df90252["Area Name"] != "England" ]
df90614=df90613.loc[df90613["Area Name"] != "England" ]
df90975=df90974.loc[df90974["Area Name"] != "England" ]
df91336=df91335.loc[df91335["Area Name"] != "England" ]
df91697=df91696.loc[df91696["Area Name"] != "England" ]
df92058=df92057.loc[df92057["Area Name"] != "England" ]
df92419=df92418.loc[df92418["Area Name"] != "England" ]
df92780=df92779.loc[df92779["Area Name"] != "England" ]
df93141=df93140.loc[df93140["Area Name"] != "England" ]
df93502=df93501.loc[df93501["Area Name"] != "England" ]
df93863=df93862.loc[df93862["Area Name"] != "England" ]
df94224=df94223.loc[df94223["Area Name"] != "England" ]
df94585=df94584.loc[df94584["Area Name"] != "England" ]
df94946=df94945.loc[df94945["Area Name"] != "England" ]
df95307=df95306.loc[df95306["Area Name"] != "England" ]
df95668=df95667.loc[df95667["Area Name"] != "England" ]
df96029=df96028.loc[df96028["Area Name"] != "England" ]
df96390=df96389.loc[df96389["Area Name"] != "England" ]
df96751=df96750.loc[df96750["Area Name"] != "England" ]
df97112=df97111.loc[df97111["Area Name"] != "England" ]
df97473=df97472.loc[df97472["Area Name"] != "England" ]
df97834=df97833.loc[df97833["Area Name"] != "England" ]
df98195=df98194.loc[df98194["Area Name"] != "England" ]
df98556=df98555.loc[df98555["Area Name"] != "England" ]
df98917=df98916.loc[df98916["Area Name"] != "England" ]
df99278=df99277.loc[df99277["Area Name"] != "England" ]
df99639=df99638.loc[df99638["Area Name"] != "England" ]
df100000=df99999.loc[df99999["Area Name"] != "England" ]
df100361=df100360.loc[df100360["Area Name"] != "England" ]
df100722=df100721.loc[df100721["Area Name"] != "England" ]
df101083=df101082.loc[df101082["Area Name"] != "England" ]
df101444=df101443.loc[df101443["Area Name"] != "England" ]
df101805=df101804.loc[df101804["Area Name"] != "England" ]
df102166=df102165.loc[df102165["Area Name"] != "England" ]
df102527=df102526.loc[df102526["Area Name"] != "England" ]
df102888=df102887.loc[df102887["Area Name"] != "England" ]
df103249=df103248.loc[df103248["Area Name"] != "England" ]
df103610=df103609.loc[df103609["Area Name"] != "England" ]
df103971=df103970.loc[df103970["Area Name"] != "England" ]
df104332=df104331.loc[df104331["Area Name"] != "England" ]
df104693=df104692.loc[df104692["Area Name"] != "England" ]
df105054=df105053.loc[df105053["Area Name"] != "England" ]
df105415=df105414.loc[df105414["Area Name"] != "England" ]
df105776=df105775.loc[df105775["Area Name"] != "England" ]
df106137=df106136.loc[df106136["Area Name"] != "England" ]
df106498=df106497.loc[df106497["Area Name"] != "England" ]
df106859=df106858.loc[df106858["Area Name"] != "England" ]
df107220=df107219.loc[df107219["Area Name"] != "England" ]
df107581=df107580.loc[df107580["Area Name"] != "England" ]
df107942=df107941.loc[df107941["Area Name"] != "England" ]
df108303=df108302.loc[df108302["Area Name"] != "England" ]
df108664=df108663.loc[df108663["Area Name"] != "England" ]
df109025=df109024.loc[df109024["Area Name"] != "England" ]
df109386=df109385.loc[df109385["Area Name"] != "England" ]
df109747=df109746.loc[df109746["Area Name"] != "England" ]
df110108=df110107.loc[df110107["Area Name"] != "England" ]
df110469=df110468.loc[df110468["Area Name"] != "England" ]
df110830=df110829.loc[df110829["Area Name"] != "England" ]
df111191=df111190.loc[df111190["Area Name"] != "England" ]
df111552=df111551.loc[df111551["Area Name"] != "England" ]
df111913=df111912.loc[df111912["Area Name"] != "England" ]
df112274=df112273.loc[df112273["Area Name"] != "England" ]
df112635=df112634.loc[df112634["Area Name"] != "England" ]
df112996=df112995.loc[df112995["Area Name"] != "England" ]
df113357=df113356.loc[df113356["Area Name"] != "England" ]
df113718=df113717.loc[df113717["Area Name"] != "England" ]
df114079=df114078.loc[df114078["Area Name"] != "England" ]
df114440=df114439.loc[df114439["Area Name"] != "England" ]
df114801=df114800.loc[df114800["Area Name"] != "England" ]
df115162=df115161.loc[df115161["Area Name"] != "England" ]
df115523=df115522.loc[df115522["Area Name"] != "England" ]
df115884=df115883.loc[df115883["Area Name"] != "England" ]
df116245=df116244.loc[df116244["Area Name"] != "England" ]
df116606=df116605.loc[df116605["Area Name"] != "England" ]
df116967=df116966.loc[df116966["Area Name"] != "England" ]
df117328=df117327.loc[df117327["Area Name"] != "England" ]
df117689=df117688.loc[df117688["Area Name"] != "England" ]
df118050=df118049.loc[df118049["Area Name"] != "England" ]
df118411=df118410.loc[df118410["Area Name"] != "England" ]
df118772=df118771.loc[df118771["Area Name"] != "England" ]
df119133=df119132.loc[df119132["Area Name"] != "England" ]
df119494=df119493.loc[df119493["Area Name"] != "England" ]
df119855=df119854.loc[df119854["Area Name"] != "England" ]
df120216=df120215.loc[df120215["Area Name"] != "England" ]
df120577=df120576.loc[df120576["Area Name"] != "England" ]
df120938=df120937.loc[df120937["Area Name"] != "England" ]
df121299=df121298.loc[df121298["Area Name"] != "England" ]
df121660=df121659.loc[df121659["Area Name"] != "England" ]
df122021=df122020.loc[df122020["Area Name"] != "England" ]
df122382=df122381.loc[df122381["Area Name"] != "England" ]
df122743=df122742.loc[df122742["Area Name"] != "England" ]
df123104=df123103.loc[df123103["Area Name"] != "England" ]
df123465=df123464.loc[df123464["Area Name"] != "England" ]
df123826=df123825.loc[df123825["Area Name"] != "England" ]
df124187=df124186.loc[df124186["Area Name"] != "England" ]
df124548=df124547.loc[df124547["Area Name"] != "England" ]
df124909=df124908.loc[df124908["Area Name"] != "England" ]
df125270=df125269.loc[df125269["Area Name"] != "England" ]
df125631=df125630.loc[df125630["Area Name"] != "England" ]
df125992=df125991.loc[df125991["Area Name"] != "England" ]
df126353=df126352.loc[df126352["Area Name"] != "England" ]
df126714=df126713.loc[df126713["Area Name"] != "England" ]
df127075=df127074.loc[df127074["Area Name"] != "England" ]
df127436=df127435.loc[df127435["Area Name"] != "England" ]
df127797=df127796.loc[df127796["Area Name"] != "England" ]
df128158=df128157.loc[df128157["Area Name"] != "England" ]
df128519=df128518.loc[df128518["Area Name"] != "England" ]
df128880=df128879.loc[df128879["Area Name"] != "England" ]
df129241=df129240.loc[df129240["Area Name"] != "England" ]
df129602=df129601.loc[df129601["Area Name"] != "England" ]
df129963=df129962.loc[df129962["Area Name"] != "England" ]

# %% [markdown]
# Step 4: round data to 2 d.p.

# %%
df4=df3.round({"Value":2})
df365=df364.round({"Value":2})
df726=df725.round({"Value":2})
df1087=df1086.round({"Value":2})
df1448=df1447.round({"Value":2})
df1809=df1808.round({"Value":2})
df2170=df2169.round({"Value":2})
df2531=df2530.round({"Value":2})
df2892=df2891.round({"Value":2})
df3253=df3252.round({"Value":2})
df3614=df3613.round({"Value":2})
df3975=df3974.round({"Value":2})
df4336=df4335.round({"Value":2})
df4697=df4696.round({"Value":2})
df5058=df5057.round({"Value":2})
df5419=df5418.round({"Value":2})
df5780=df5779.round({"Value":2})
df6141=df6140.round({"Value":2})
df6502=df6501.round({"Value":2})
df6863=df6862.round({"Value":2})
df7224=df7223.round({"Value":2})
df7585=df7584.round({"Value":2})
df7946=df7945.round({"Value":2})
df8307=df8306.round({"Value":2})
df8668=df8667.round({"Value":2})
df9029=df9028.round({"Value":2})
df9390=df9389.round({"Value":2})
df9751=df9750.round({"Value":2})
df10112=df10111.round({"Value":2})
df10473=df10472.round({"Value":2})
df10834=df10833.round({"Value":2})
df11195=df11194.round({"Value":2})
df11556=df11555.round({"Value":2})
df11917=df11916.round({"Value":2})
df12278=df12277.round({"Value":2})
df12639=df12638.round({"Value":2})
df13000=df12999.round({"Value":2})
df13361=df13360.round({"Value":2})
df13722=df13721.round({"Value":2})
df14083=df14082.round({"Value":2})
df14444=df14443.round({"Value":2})
df14805=df14804.round({"Value":2})
df15166=df15165.round({"Value":2})
df15527=df15526.round({"Value":2})
df15888=df15887.round({"Value":2})
df16249=df16248.round({"Value":2})
df16610=df16609.round({"Value":2})
df16971=df16970.round({"Value":2})
df17332=df17331.round({"Value":2})
df17693=df17692.round({"Value":2})
df18054=df18053.round({"Value":2})
df18415=df18414.round({"Value":2})
df18776=df18775.round({"Value":2})
df19137=df19136.round({"Value":2})
df19498=df19497.round({"Value":2})
df19859=df19858.round({"Value":2})
df20220=df20219.round({"Value":2})
df20581=df20580.round({"Value":2})
df20942=df20941.round({"Value":2})
df21303=df21302.round({"Value":2})
df21664=df21663.round({"Value":2})
df22025=df22024.round({"Value":2})
df22386=df22385.round({"Value":2})
df22747=df22746.round({"Value":2})
df23108=df23107.round({"Value":2})
df23469=df23468.round({"Value":2})
df23830=df23829.round({"Value":2})
df24191=df24190.round({"Value":2})
df24552=df24551.round({"Value":2})
df24913=df24912.round({"Value":2})
df25274=df25273.round({"Value":2})
df25635=df25634.round({"Value":2})
df25996=df25995.round({"Value":2})
df26357=df26356.round({"Value":2})
df26718=df26717.round({"Value":2})
df27079=df27078.round({"Value":2})
df27440=df27439.round({"Value":2})
df27801=df27800.round({"Value":2})
df28162=df28161.round({"Value":2})
df28523=df28522.round({"Value":2})
df28884=df28883.round({"Value":2})
df29245=df29244.round({"Value":2})
df29606=df29605.round({"Value":2})
df29967=df29966.round({"Value":2})
df30328=df30327.round({"Value":2})
df30689=df30688.round({"Value":2})
df31050=df31049.round({"Value":2})
df31411=df31410.round({"Value":2})
df31772=df31771.round({"Value":2})
df32133=df32132.round({"Value":2})
df32494=df32493.round({"Value":2})
df32855=df32854.round({"Value":2})
df33216=df33215.round({"Value":2})
df33577=df33576.round({"Value":2})
df33938=df33937.round({"Value":2})
df34299=df34298.round({"Value":2})
df34660=df34659.round({"Value":2})
df35021=df35020.round({"Value":2})
df35382=df35381.round({"Value":2})
df35743=df35742.round({"Value":2})
df36104=df36103.round({"Value":2})
df36465=df36464.round({"Value":2})
df36826=df36825.round({"Value":2})
df37187=df37186.round({"Value":2})
df37548=df37547.round({"Value":2})
df37909=df37908.round({"Value":2})
df38270=df38269.round({"Value":2})
df38631=df38630.round({"Value":2})
df38992=df38991.round({"Value":2})
df39353=df39352.round({"Value":2})
df39714=df39713.round({"Value":2})
df40075=df40074.round({"Value":2})
df40436=df40435.round({"Value":2})
df40797=df40796.round({"Value":2})
df41158=df41157.round({"Value":2})
df41519=df41518.round({"Value":2})
df41880=df41879.round({"Value":2})
df42241=df42240.round({"Value":2})
df42602=df42601.round({"Value":2})
df42963=df42962.round({"Value":2})
df43324=df43323.round({"Value":2})
df43685=df43684.round({"Value":2})
df44046=df44045.round({"Value":2})
df44407=df44406.round({"Value":2})
df44768=df44767.round({"Value":2})
df45129=df45128.round({"Value":2})
df45490=df45489.round({"Value":2})
df45851=df45850.round({"Value":2})
df46212=df46211.round({"Value":2})
df46573=df46572.round({"Value":2})
df46934=df46933.round({"Value":2})
df47295=df47294.round({"Value":2})
df47656=df47655.round({"Value":2})
df48017=df48016.round({"Value":2})
df48378=df48377.round({"Value":2})
df48739=df48738.round({"Value":2})
df49100=df49099.round({"Value":2})
df49461=df49460.round({"Value":2})
df49822=df49821.round({"Value":2})
df50183=df50182.round({"Value":2})
df50544=df50543.round({"Value":2})
df50905=df50904.round({"Value":2})
df51266=df51265.round({"Value":2})
df51627=df51626.round({"Value":2})
df51988=df51987.round({"Value":2})
df52349=df52348.round({"Value":2})
df52710=df52709.round({"Value":2})
df53071=df53070.round({"Value":2})
df53432=df53431.round({"Value":2})
df53793=df53792.round({"Value":2})
df54154=df54153.round({"Value":2})
df54515=df54514.round({"Value":2})
df54876=df54875.round({"Value":2})
df55237=df55236.round({"Value":2})
df55598=df55597.round({"Value":2})
df55959=df55958.round({"Value":2})
df56320=df56319.round({"Value":2})
df56681=df56680.round({"Value":2})
df57042=df57041.round({"Value":2})
df57403=df57402.round({"Value":2})
df57764=df57763.round({"Value":2})
df58125=df58124.round({"Value":2})
df58486=df58485.round({"Value":2})
df58847=df58846.round({"Value":2})
df59208=df59207.round({"Value":2})
df59569=df59568.round({"Value":2})
df59930=df59929.round({"Value":2})
df60291=df60290.round({"Value":2})
df60652=df60651.round({"Value":2})
df61013=df61012.round({"Value":2})
df61374=df61373.round({"Value":2})
df61735=df61734.round({"Value":2})
df62096=df62095.round({"Value":2})
df62457=df62456.round({"Value":2})
df62818=df62817.round({"Value":2})
df63179=df63178.round({"Value":2})
df63540=df63539.round({"Value":2})
df63901=df63900.round({"Value":2})
df64262=df64261.round({"Value":2})
df64623=df64622.round({"Value":2})
df64984=df64983.round({"Value":2})
df65345=df65344.round({"Value":2})
df65706=df65705.round({"Value":2})
df66067=df66066.round({"Value":2})
df66428=df66427.round({"Value":2})
df66789=df66788.round({"Value":2})
df67150=df67149.round({"Value":2})
df67511=df67510.round({"Value":2})
df67872=df67871.round({"Value":2})
df68233=df68232.round({"Value":2})
df68594=df68593.round({"Value":2})
df68955=df68954.round({"Value":2})
df69316=df69315.round({"Value":2})
df69677=df69676.round({"Value":2})
df70038=df70037.round({"Value":2})
df70399=df70398.round({"Value":2})
df70760=df70759.round({"Value":2})
df71121=df71120.round({"Value":2})
df71482=df71481.round({"Value":2})
df71843=df71842.round({"Value":2})
df72204=df72203.round({"Value":2})
df72565=df72564.round({"Value":2})
df72926=df72925.round({"Value":2})
df73287=df73286.round({"Value":2})
df73648=df73647.round({"Value":2})
df74009=df74008.round({"Value":2})
df74370=df74369.round({"Value":2})
df74731=df74730.round({"Value":2})
df75092=df75091.round({"Value":2})
df75453=df75452.round({"Value":2})
df75814=df75813.round({"Value":2})
df76175=df76174.round({"Value":2})
df76536=df76535.round({"Value":2})
df76897=df76896.round({"Value":2})
df77258=df77257.round({"Value":2})
df77619=df77618.round({"Value":2})
df77980=df77979.round({"Value":2})
df78341=df78340.round({"Value":2})
df78702=df78701.round({"Value":2})
df79063=df79062.round({"Value":2})
df79424=df79423.round({"Value":2})
df79785=df79784.round({"Value":2})
df80146=df80145.round({"Value":2})
df80507=df80506.round({"Value":2})
df80868=df80867.round({"Value":2})
df81229=df81228.round({"Value":2})
df81590=df81589.round({"Value":2})
df81951=df81950.round({"Value":2})
df82312=df82311.round({"Value":2})
df82673=df82672.round({"Value":2})
df83034=df83033.round({"Value":2})
df83395=df83394.round({"Value":2})
df83756=df83755.round({"Value":2})
df84117=df84116.round({"Value":2})
df84478=df84477.round({"Value":2})
df84839=df84838.round({"Value":2})
df85200=df85199.round({"Value":2})
df85561=df85560.round({"Value":2})
df85922=df85921.round({"Value":2})
df86283=df86282.round({"Value":2})
df86644=df86643.round({"Value":2})
df87005=df87004.round({"Value":2})
df87366=df87365.round({"Value":2})
df87727=df87726.round({"Value":2})
df88088=df88087.round({"Value":2})
df88449=df88448.round({"Value":2})
df88810=df88809.round({"Value":2})
df89171=df89170.round({"Value":2})
df89532=df89531.round({"Value":2})
df89893=df89892.round({"Value":2})
df90254=df90253.round({"Value":2})
df90615=df90614.round({"Value":2})
df90976=df90975.round({"Value":2})
df91337=df91336.round({"Value":2})
df91698=df91697.round({"Value":2})
df92059=df92058.round({"Value":2})
df92420=df92419.round({"Value":2})
df92781=df92780.round({"Value":2})
df93142=df93141.round({"Value":2})
df93503=df93502.round({"Value":2})
df93864=df93863.round({"Value":2})
df94225=df94224.round({"Value":2})
df94586=df94585.round({"Value":2})
df94947=df94946.round({"Value":2})
df95308=df95307.round({"Value":2})
df95669=df95668.round({"Value":2})
df96030=df96029.round({"Value":2})
df96391=df96390.round({"Value":2})
df96752=df96751.round({"Value":2})
df97113=df97112.round({"Value":2})
df97474=df97473.round({"Value":2})
df97835=df97834.round({"Value":2})
df98196=df98195.round({"Value":2})
df98557=df98556.round({"Value":2})
df98918=df98917.round({"Value":2})
df99279=df99278.round({"Value":2})
df99640=df99639.round({"Value":2})
df100001=df100000.round({"Value":2})
df100362=df100361.round({"Value":2})
df100723=df100722.round({"Value":2})
df101084=df101083.round({"Value":2})
df101445=df101444.round({"Value":2})
df101806=df101805.round({"Value":2})
df102167=df102166.round({"Value":2})
df102528=df102527.round({"Value":2})
df102889=df102888.round({"Value":2})
df103250=df103249.round({"Value":2})
df103611=df103610.round({"Value":2})
df103972=df103971.round({"Value":2})
df104333=df104332.round({"Value":2})
df104694=df104693.round({"Value":2})
df105055=df105054.round({"Value":2})
df105416=df105415.round({"Value":2})
df105777=df105776.round({"Value":2})
df106138=df106137.round({"Value":2})
df106499=df106498.round({"Value":2})
df106860=df106859.round({"Value":2})
df107221=df107220.round({"Value":2})
df107582=df107581.round({"Value":2})
df107943=df107942.round({"Value":2})
df108304=df108303.round({"Value":2})
df108665=df108664.round({"Value":2})
df109026=df109025.round({"Value":2})
df109387=df109386.round({"Value":2})
df109748=df109747.round({"Value":2})
df110109=df110108.round({"Value":2})
df110470=df110469.round({"Value":2})
df110831=df110830.round({"Value":2})
df111192=df111191.round({"Value":2})
df111553=df111552.round({"Value":2})
df111914=df111913.round({"Value":2})
df112275=df112274.round({"Value":2})
df112636=df112635.round({"Value":2})
df112997=df112996.round({"Value":2})
df113358=df113357.round({"Value":2})
df113719=df113718.round({"Value":2})
df114080=df114079.round({"Value":2})
df114441=df114440.round({"Value":2})
df114802=df114801.round({"Value":2})
df115163=df115162.round({"Value":2})
df115524=df115523.round({"Value":2})
df115885=df115884.round({"Value":2})
df116246=df116245.round({"Value":2})
df116607=df116606.round({"Value":2})
df116968=df116967.round({"Value":2})
df117329=df117328.round({"Value":2})
df117690=df117689.round({"Value":2})
df118051=df118050.round({"Value":2})
df118412=df118411.round({"Value":2})
df118773=df118772.round({"Value":2})
df119134=df119133.round({"Value":2})
df119495=df119494.round({"Value":2})
df119856=df119855.round({"Value":2})
df120217=df120216.round({"Value":2})
df120578=df120577.round({"Value":2})
df120939=df120938.round({"Value":2})
df121300=df121299.round({"Value":2})
df121661=df121660.round({"Value":2})
df122022=df122021.round({"Value":2})
df122383=df122382.round({"Value":2})
df122744=df122743.round({"Value":2})
df123105=df123104.round({"Value":2})
df123466=df123465.round({"Value":2})
df123827=df123826.round({"Value":2})
df124188=df124187.round({"Value":2})
df124549=df124548.round({"Value":2})
df124910=df124909.round({"Value":2})
df125271=df125270.round({"Value":2})
df125632=df125631.round({"Value":2})
df125993=df125992.round({"Value":2})
df126354=df126353.round({"Value":2})
df126715=df126714.round({"Value":2})
df127076=df127075.round({"Value":2})
df127437=df127436.round({"Value":2})
df127798=df127797.round({"Value":2})
df128159=df128158.round({"Value":2})
df128520=df128519.round({"Value":2})
df128881=df128880.round({"Value":2})
df129242=df129241.round({"Value":2})
df129603=df129602.round({"Value":2})
df129964=df129963.round({"Value":2})

# %% [markdown]
# Step 5: save DFs as CSVs now that they are cleaner.

# %%
df4.to_csv("df4.csv")
df365.to_csv("df365.csv")
df726.to_csv("df726.csv")
df1087.to_csv("df1087.csv")
df1448.to_csv("df1448.csv")
df1809.to_csv("df1809.csv")
df2170.to_csv("df2170.csv")
df2531.to_csv("df2531.csv")
df2892.to_csv("df2892.csv")
df3253.to_csv("df3253.csv")
df3614.to_csv("df3614.csv")
df3975.to_csv("df3975.csv")
df4336.to_csv("df4336.csv")
df4697.to_csv("df4697.csv")
df5058.to_csv("df5058.csv")
df5419.to_csv("df5419.csv")
df5780.to_csv("df5780.csv")
df6141.to_csv("df6141.csv")
df6502.to_csv("df6502.csv")
df6863.to_csv("df6863.csv")
df7224.to_csv("df7224.csv")
df7585.to_csv("df7585.csv")
df7946.to_csv("df7946.csv")
df8307.to_csv("df8307.csv")
df8668.to_csv("df8668.csv")
df9029.to_csv("df9029.csv")
df9390.to_csv("df9390.csv")
df9751.to_csv("df9751.csv")
df10112.to_csv("df10112.csv")
df10473.to_csv("df10473.csv")
df10834.to_csv("df10834.csv")
df11195.to_csv("df11195.csv")
df11556.to_csv("df11556.csv")
df11917.to_csv("df11917.csv")
df12278.to_csv("df12278.csv")
df12639.to_csv("df12639.csv")
df13000.to_csv("df13000.csv")
df13361.to_csv("df13361.csv")
df13722.to_csv("df13722.csv")
df14083.to_csv("df14083.csv")
df14444.to_csv("df14444.csv")
df14805.to_csv("df14805.csv")
df15166.to_csv("df15166.csv")
df15527.to_csv("df15527.csv")
df15888.to_csv("df15888.csv")
df16249.to_csv("df16249.csv")
df16610.to_csv("df16610.csv")
df16971.to_csv("df16971.csv")
df17332.to_csv("df17332.csv")
df17693.to_csv("df17693.csv")
df18054.to_csv("df18054.csv")
df18415.to_csv("df18415.csv")
df18776.to_csv("df18776.csv")
df19137.to_csv("df19137.csv")
df19498.to_csv("df19498.csv")
df19859.to_csv("df19859.csv")
df20220.to_csv("df20220.csv")
df20581.to_csv("df20581.csv")
df20942.to_csv("df20942.csv")
df21303.to_csv("df21303.csv")
df21664.to_csv("df21664.csv")
df22025.to_csv("df22025.csv")
df22386.to_csv("df22386.csv")
df22747.to_csv("df22747.csv")
df23108.to_csv("df23108.csv")
df23469.to_csv("df23469.csv")
df23830.to_csv("df23830.csv")
df24191.to_csv("df24191.csv")
df24552.to_csv("df24552.csv")
df24913.to_csv("df24913.csv")
df25274.to_csv("df25274.csv")
df25635.to_csv("df25635.csv")
df25996.to_csv("df25996.csv")
df26357.to_csv("df26357.csv")
df26718.to_csv("df26718.csv")
df27079.to_csv("df27079.csv")
df27440.to_csv("df27440.csv")
df27801.to_csv("df27801.csv")
df28162.to_csv("df28162.csv")
df28523.to_csv("df28523.csv")
df28884.to_csv("df28884.csv")
df29245.to_csv("df29245.csv")
df29606.to_csv("df29606.csv")
df29967.to_csv("df29967.csv")
df30328.to_csv("df30328.csv")
df30689.to_csv("df30689.csv")
df31050.to_csv("df31050.csv")
df31411.to_csv("df31411.csv")
df31772.to_csv("df31772.csv")
df32133.to_csv("df32133.csv")
df32494.to_csv("df32494.csv")
df32855.to_csv("df32855.csv")
df33216.to_csv("df33216.csv")
df33577.to_csv("df33577.csv")
df33938.to_csv("df33938.csv")
df34299.to_csv("df34299.csv")
df34660.to_csv("df34660.csv")
df35021.to_csv("df35021.csv")
df35382.to_csv("df35382.csv")
df35743.to_csv("df35743.csv")
df36104.to_csv("df36104.csv")
df36465.to_csv("df36465.csv")
df36826.to_csv("df36826.csv")
df37187.to_csv("df37187.csv")
df37548.to_csv("df37548.csv")
df37909.to_csv("df37909.csv")
df38270.to_csv("df38270.csv")
df38631.to_csv("df38631.csv")
df38992.to_csv("df38992.csv")
df39353.to_csv("df39353.csv")
df39714.to_csv("df39714.csv")
df40075.to_csv("df40075.csv")
df40436.to_csv("df40436.csv")
df40797.to_csv("df40797.csv")
df41158.to_csv("df41158.csv")
df41519.to_csv("df41519.csv")
df41880.to_csv("df41880.csv")
df42241.to_csv("df42241.csv")
df42602.to_csv("df42602.csv")
df42963.to_csv("df42963.csv")
df43324.to_csv("df43324.csv")
df43685.to_csv("df43685.csv")
df44046.to_csv("df44046.csv")
df44407.to_csv("df44407.csv")
df44768.to_csv("df44768.csv")
df45129.to_csv("df45129.csv")
df45490.to_csv("df45490.csv")
df45851.to_csv("df45851.csv")
df46212.to_csv("df46212.csv")
df46573.to_csv("df46573.csv")
df46934.to_csv("df46934.csv")
df47295.to_csv("df47295.csv")
df47656.to_csv("df47656.csv")
df48017.to_csv("df48017.csv")
df48378.to_csv("df48378.csv")
df48739.to_csv("df48739.csv")
df49100.to_csv("df49100.csv")
df49461.to_csv("df49461.csv")
df49822.to_csv("df49822.csv")
df50183.to_csv("df50183.csv")
df50544.to_csv("df50544.csv")
df50905.to_csv("df50905.csv")
df51266.to_csv("df51266.csv")
df51627.to_csv("df51627.csv")
df51988.to_csv("df51988.csv")
df52349.to_csv("df52349.csv")
df52710.to_csv("df52710.csv")
df53071.to_csv("df53071.csv")
df53432.to_csv("df53432.csv")
df53793.to_csv("df53793.csv")
df54154.to_csv("df54154.csv")
df54515.to_csv("df54515.csv")
df54876.to_csv("df54876.csv")
df55237.to_csv("df55237.csv")
df55598.to_csv("df55598.csv")
df55959.to_csv("df55959.csv")
df56320.to_csv("df56320.csv")
df56681.to_csv("df56681.csv")
df57042.to_csv("df57042.csv")
df57403.to_csv("df57403.csv")
df57764.to_csv("df57764.csv")
df58125.to_csv("df58125.csv")
df58486.to_csv("df58486.csv")
df58847.to_csv("df58847.csv")
df59208.to_csv("df59208.csv")
df59569.to_csv("df59569.csv")
df59930.to_csv("df59930.csv")
df60291.to_csv("df60291.csv")
df60652.to_csv("df60652.csv")
df61013.to_csv("df61013.csv")
df61374.to_csv("df61374.csv")
df61735.to_csv("df61735.csv")
df62096.to_csv("df62096.csv")
df62457.to_csv("df62457.csv")
df62818.to_csv("df62818.csv")
df63179.to_csv("df63179.csv")
df63540.to_csv("df63540.csv")
df63901.to_csv("df63901.csv")
df64262.to_csv("df64262.csv")
df64623.to_csv("df64623.csv")
df64984.to_csv("df64984.csv")
df65345.to_csv("df65345.csv")
df65706.to_csv("df65706.csv")
df66067.to_csv("df66067.csv")
df66428.to_csv("df66428.csv")
df66789.to_csv("df66789.csv")
df67150.to_csv("df67150.csv")
df67511.to_csv("df67511.csv")
df67872.to_csv("df67872.csv")
df68233.to_csv("df68233.csv")
df68594.to_csv("df68594.csv")
df68955.to_csv("df68955.csv")
df69316.to_csv("df69316.csv")
df69677.to_csv("df69677.csv")
df70038.to_csv("df70038.csv")
df70399.to_csv("df70399.csv")
df70760.to_csv("df70760.csv")
df71121.to_csv("df71121.csv")
df71482.to_csv("df71482.csv")
df71843.to_csv("df71843.csv")
df72204.to_csv("df72204.csv")
df72565.to_csv("df72565.csv")
df72926.to_csv("df72926.csv")
df73287.to_csv("df73287.csv")
df73648.to_csv("df73648.csv")
df74009.to_csv("df74009.csv")
df74370.to_csv("df74370.csv")
df74731.to_csv("df74731.csv")
df75092.to_csv("df75092.csv")
df75453.to_csv("df75453.csv")
df75814.to_csv("df75814.csv")
df76175.to_csv("df76175.csv")
df76536.to_csv("df76536.csv")
df76897.to_csv("df76897.csv")
df77258.to_csv("df77258.csv")
df77619.to_csv("df77619.csv")
df77980.to_csv("df77980.csv")
df78341.to_csv("df78341.csv")
df78702.to_csv("df78702.csv")
df79063.to_csv("df79063.csv")
df79424.to_csv("df79424.csv")
df79785.to_csv("df79785.csv")
df80146.to_csv("df80146.csv")
df80507.to_csv("df80507.csv")
df80868.to_csv("df80868.csv")
df81229.to_csv("df81229.csv")
df81590.to_csv("df81590.csv")
df81951.to_csv("df81951.csv")
df82312.to_csv("df82312.csv")
df82673.to_csv("df82673.csv")
df83034.to_csv("df83034.csv")
df83395.to_csv("df83395.csv")
df83756.to_csv("df83756.csv")
df84117.to_csv("df84117.csv")
df84478.to_csv("df84478.csv")
df84839.to_csv("df84839.csv")
df85200.to_csv("df85200.csv")
df85561.to_csv("df85561.csv")
df85922.to_csv("df85922.csv")
df86283.to_csv("df86283.csv")
df86644.to_csv("df86644.csv")
df87005.to_csv("df87005.csv")
df87366.to_csv("df87366.csv")
df87727.to_csv("df87727.csv")
df88088.to_csv("df88088.csv")
df88449.to_csv("df88449.csv")
df88810.to_csv("df88810.csv")
df89171.to_csv("df89171.csv")
df89532.to_csv("df89532.csv")
df89893.to_csv("df89893.csv")
df90254.to_csv("df90254.csv")
df90615.to_csv("df90615.csv")
df90976.to_csv("df90976.csv")
df91337.to_csv("df91337.csv")
df91698.to_csv("df91698.csv")
df92059.to_csv("df92059.csv")
df92420.to_csv("df92420.csv")
df92781.to_csv("df92781.csv")
df93142.to_csv("df93142.csv")
df93503.to_csv("df93503.csv")
df93864.to_csv("df93864.csv")
df94225.to_csv("df94225.csv")
df94586.to_csv("df94586.csv")
df94947.to_csv("df94947.csv")
df95308.to_csv("df95308.csv")
df95669.to_csv("df95669.csv")
df96030.to_csv("df96030.csv")
df96391.to_csv("df96391.csv")
df96752.to_csv("df96752.csv")
df97113.to_csv("df97113.csv")
df97474.to_csv("df97474.csv")
df97835.to_csv("df97835.csv")
df98196.to_csv("df98196.csv")
df98557.to_csv("df98557.csv")
df98918.to_csv("df98918.csv")
df99279.to_csv("df99279.csv")
df99640.to_csv("df99640.csv")
df100001.to_csv("df100001.csv")
df100362.to_csv("df100362.csv")
df100723.to_csv("df100723.csv")
df101084.to_csv("df101084.csv")
df101445.to_csv("df101445.csv")
df101806.to_csv("df101806.csv")
df102167.to_csv("df102167.csv")
df102528.to_csv("df102528.csv")
df102889.to_csv("df102889.csv")
df103250.to_csv("df103250.csv")
df103611.to_csv("df103611.csv")
df103972.to_csv("df103972.csv")
df104333.to_csv("df104333.csv")
df104694.to_csv("df104694.csv")
df105055.to_csv("df105055.csv")
df105416.to_csv("df105416.csv")
df105777.to_csv("df105777.csv")
df106138.to_csv("df106138.csv")
df106499.to_csv("df106499.csv")
df106860.to_csv("df106860.csv")
df107221.to_csv("df107221.csv")
df107582.to_csv("df107582.csv")
df107943.to_csv("df107943.csv")
df108304.to_csv("df108304.csv")
df108665.to_csv("df108665.csv")
df109026.to_csv("df109026.csv")
df109387.to_csv("df109387.csv")
df109748.to_csv("df109748.csv")
df110109.to_csv("df110109.csv")
df110470.to_csv("df110470.csv")
df110831.to_csv("df110831.csv")
df111192.to_csv("df111192.csv")
df111553.to_csv("df111553.csv")
df111914.to_csv("df111914.csv")
df112275.to_csv("df112275.csv")
df112636.to_csv("df112636.csv")
df112997.to_csv("df112997.csv")
df113358.to_csv("df113358.csv")
df113719.to_csv("df113719.csv")
df114080.to_csv("df114080.csv")
df114441.to_csv("df114441.csv")
df114802.to_csv("df114802.csv")
df115163.to_csv("df115163.csv")
df115524.to_csv("df115524.csv")
df115885.to_csv("df115885.csv")
df116246.to_csv("df116246.csv")
df116607.to_csv("df116607.csv")
df116968.to_csv("df116968.csv")
df117329.to_csv("df117329.csv")
df117690.to_csv("df117690.csv")
df118051.to_csv("df118051.csv")
df118412.to_csv("df118412.csv")
df118773.to_csv("df118773.csv")
df119134.to_csv("df119134.csv")
df119495.to_csv("df119495.csv")
df119856.to_csv("df119856.csv")
df120217.to_csv("df120217.csv")
df120578.to_csv("df120578.csv")
df120939.to_csv("df120939.csv")
df121300.to_csv("df121300.csv")
df121661.to_csv("df121661.csv")
df122022.to_csv("df122022.csv")
df122383.to_csv("df122383.csv")
df122744.to_csv("df122744.csv")
df123105.to_csv("df123105.csv")
df123466.to_csv("df123466.csv")
df123827.to_csv("df123827.csv")
df124188.to_csv("df124188.csv")
df124549.to_csv("df124549.csv")
df124910.to_csv("df124910.csv")
df125271.to_csv("df125271.csv")
df125632.to_csv("df125632.csv")
df125993.to_csv("df125993.csv")
df126354.to_csv("df126354.csv")
df126715.to_csv("df126715.csv")
df127076.to_csv("df127076.csv")
df127437.to_csv("df127437.csv")
df127798.to_csv("df127798.csv")
df128159.to_csv("df128159.csv")
df128520.to_csv("df128520.csv")
df128881.to_csv("df128881.csv")
df129242.to_csv("df129242.csv")
df129603.to_csv("df129603.csv")
df129964.to_csv("df129964.csv")

# %%
# Make sure you have authorized Colab to access your Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Create a folder in your Google Drive to store the CSVs
# !mkdir '/content/drive/My Drive/Step5RAWHealthIndicators'

# Copy the CSVs from the Colab file system to the folder in your Google Drive
# !cp '/content.csv' '/content/drive/My Drive/Step5RAWHealthIndicators'

# Create a zip file containing all of the CSVs
# !zip -r content.zip '/content'

# Download the zip file to your local machine
from google.colab import files
files.download('content.zip')
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/Step5RAWHealthIndicators’: File exists
# cp: cannot stat '/content.csv': No such file or directory
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2023.01.09/ (stored 0%)
#   adding: content/.config/logs/2023.01.09/14.36.13.391200.log (deflated 54%)
#   adding: content/.config/logs/2023.01.09/14.34.27.508072.log (deflated 91%)
#   adding: content/.config/logs/2023.01.09/14.35.41.921526.log (deflated 53%)
#   adding: content/.config/logs/2023.01.09/14.34.57.728355.log (deflated 53%)
#   adding: content/.config/logs/2023.01.09/14.36.14.314176.log (deflated 54%)
#   adding: content/.config/logs/2023.01.09/14.35.26.879372.log (deflated 86%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
# ...

# %% [markdown]
# Step 6: load saved clean data from the CSVs if restarting notebook. This is a much faster method than rerunning the fingertips API package, but the data is still raw enough to manipulate

# %%
df4=pd.read_csv('df4.csv')
df365=pd.read_csv('df365.csv')
df726=pd.read_csv('df726.csv')
df1087=pd.read_csv('df1087.csv')
df1448=pd.read_csv('df1448.csv')
df1809=pd.read_csv('df1809.csv')
df2170=pd.read_csv('df2170.csv')
df2531=pd.read_csv('df2531.csv')
df2892=pd.read_csv('df2892.csv')
df3253=pd.read_csv('df3253.csv')
df3614=pd.read_csv('df3614.csv')
df3975=pd.read_csv('df3975.csv')
df4336=pd.read_csv('df4336.csv')
df4697=pd.read_csv('df4697.csv')
df5058=pd.read_csv('df5058.csv')
df5419=pd.read_csv('df5419.csv')
df5780=pd.read_csv('df5780.csv')
df6141=pd.read_csv('df6141.csv')
df6502=pd.read_csv('df6502.csv')
df6863=pd.read_csv('df6863.csv')
df7224=pd.read_csv('df7224.csv')
df7585=pd.read_csv('df7585.csv')
df7946=pd.read_csv('df7946.csv')
df8307=pd.read_csv('df8307.csv')
df8668=pd.read_csv('df8668.csv')
df9029=pd.read_csv('df9029.csv')
df9390=pd.read_csv('df9390.csv')
df9751=pd.read_csv('df9751.csv')
df10112=pd.read_csv('df10112.csv')
df10473=pd.read_csv('df10473.csv')
df10834=pd.read_csv('df10834.csv')
df11195=pd.read_csv('df11195.csv')
df11556=pd.read_csv('df11556.csv')
df11917=pd.read_csv('df11917.csv')
df12278=pd.read_csv('df12278.csv')
df12639=pd.read_csv('df12639.csv')
df13000=pd.read_csv('df13000.csv')
df13361=pd.read_csv('df13361.csv')
df13722=pd.read_csv('df13722.csv')
df14083=pd.read_csv('df14083.csv')
df14444=pd.read_csv('df14444.csv')
df14805=pd.read_csv('df14805.csv')
df15166=pd.read_csv('df15166.csv')
df15527=pd.read_csv('df15527.csv')
df15888=pd.read_csv('df15888.csv')
df16249=pd.read_csv('df16249.csv')
df16610=pd.read_csv('df16610.csv')
df16971=pd.read_csv('df16971.csv')
df17332=pd.read_csv('df17332.csv')
df17693=pd.read_csv('df17693.csv')
df18054=pd.read_csv('df18054.csv')
df18415=pd.read_csv('df18415.csv')
df18776=pd.read_csv('df18776.csv')
df19137=pd.read_csv('df19137.csv')
df125272=df125271[df125271['Sex'].isin(['Persons','Not applicable'])]
df125633=df125632[df125632['Sex'].isin(['Persons','Not applicable'])]
df125994=df125993[df125993['Sex'].isin(['Persons','Not applicable'])]
df126355=df126354[df126354['Sex'].isin(['Persons','Not applicable'])]
df126716=df126715[df126715['Sex'].isin(['Persons','Not applicable'])]
df127077=df127076[df127076['Sex'].isin(['Persons','Not applicable'])]
df127438=df127437[df127437['Sex'].isin(['Persons','Not applicable'])]
df127799=df127798[df127798['Sex'].isin(['Persons','Not applicable'])]
df128160=df128159[df128159['Sex'].isin(['Persons','Not applicable'])]
df128521=df128520[df128520['Sex'].isin(['Persons','Not applicable'])]
df128882=df128881[df128881['Sex'].isin(['Persons','Not applicable'])]
df129243=df129242[df129242['Sex'].isin(['Persons','Not applicable'])]
df129604=df129603[df129603['Sex'].isin(['Persons','Not applicable'])]
df129965=df129964[df129964['Sex'].isin(['Persons','Not applicable'])]

# %%
print(dfSEXLOOKUP["Indicator Name"].value_counts().head(20))
# Out:
# Life expectancy at birth                                                                         78690
# Life expectancy at 65                                                                            78690
# Resident population                                                                              37080
# Under 75 mortality rate from all causes                                                          35226
# Mortality rate from all causes, all ages                                                         35226
# Under 75 mortality rate from all cardiovascular diseases                                         34299
# Under 75 mortality rate from liver disease                                                       34299
# Under 75 mortality rate from respiratory disease                                                 34299
# Under 75 mortality rate from respiratory disease considered preventable (2019 definition)        34299
# ...

# %%
print(dfSEXLOOKUP["Indicator Name"].value_counts().tail(60))
# Out:
# Emergency hospital admissions for stroke, standardised admission ratio                                       309
# Emergency hospital admissions for coronary heart disease, standardised admission ratio                       309
# Emergency hospital admissions for all causes, all ages, standardised admission ratio                         309
# Percentage of the total resident population aged 85 and over                                                 309
# Emergency hospital admissions for injuries in 15 to 24 years old, crude rate                                 309
# Emergency hospital admissions for injuries in under 15 years old, crude rate                                 309
# Emergency hospital admissions in under 5 years old, crude rate                                               309
# Emergency hospital admissions for injuries in under 5 years old, crude rate                                  309
# ...

# %%
dfAGELOOKUP = pd.concat([df5,	df366,	df727,	df1088,	df1449,	df1810,	df2171,	df2532,	df2893,	df3254,	df3615,	df3976,	df4337,	df4698,	df5059,	df5420,	df5781,	df6142,	df6503,	df6864,	df7225,	df7586,	df7947,	df8308,	df8669,	df9030,	df9391,	df9752,	df10113,	df10474,	df10835,	df11196,	df11557,	df11918,	df12279,	df12640,	df13001,	df13362,	df13723,	df14084,	df14445,	df14806,	df15167,	df15528,	df15889,	df16250,	df16611,	df16972,	df17333,	df17694,	df18055,	df18416,	df18777,	df19138,	df19499,	df19860,	df20221,	df20582,	df20943,	df21304,	df21665,	df22026,	df22387,	df22748,	df23109,	df23470,	df23831,	df24192,	df24553,	df24914,	df25275,	df25636,	df25997,	df26358,	df26719,	df27080,	df27441,	df27802,	df28163,	df28524,	df28885,	df29246,	df29607,	df29968,	df30329,	df30690,	df31051,	df31412,	df31773,	df32134,	df32495,	df32856,	df33217,	df33578,	df33939,	df34300,	df34661,	df35022,	df35383,	df35744,	df36105,	
# 34899      39687  Under 75 mortality rate from all causes  E06000001
# 34900      39688  Under 75 mortality rate from all causes  E06000002
# 34901      39689  Under 75 mortality rate from all causes  E06000003
# 34902      39690  Under 75 mortality rate from all causes  E06000004
# 34903      39691  Under 75 mortality rate from all causes  E06000005
# ...          ...                                      ...        ...
# 304          406                    Determining PrEP need  E06000062
# 305          407                    Determining PrEP need  E09000030
# 306          408                    Determining PrEP need  E09000031
# 307          409                    Determining PrEP need  E09000032
# 308          410                    Determining PrEP need  E09000033
#
#                    Area Name      Sex       Age Time period   Value
# 34899             Hartlepool  Persons   <75 yrs        2020  460.80
# ...

# %%
print(dfGROUPED["Time period"].value_counts())
# Out:
# 2021                   14523
# 2020/21                14202
# 2020                   10311
# 2021/22                10197
# 2017 - 19               4757
# 2016/17 - 20/21         4017
# 2016 - 20               3399
# 2017                    3345
# 2020                    3037
# 2019/20                 2594
# 2014                    2449
# 2019                    2290
# 2018 - 20               2289
# 2011                    2158
# 2018                    2141
# 2016/17                 1641
# 2012                    1520
# 2019/20 - 21/22         1236
# 2016                    1050
# 2019 - 21                927
# 2015 - 19                927
# 2014 - 18                923
# Aug 2019 - Jul 2020      618
# 2018/19 - 20/21          618
# 2017/18 - 21/22          618
# 2015                     611
# 2018/19                  432
# Jul 2020 - Jun 2021      309
# 2022                     309
# 2016 - 18                307
# 2012 - 16                306
# 2013/14                  306
# ...

# %% [markdown]
# It looks like taking the most recent time period has worked to ensure just 1 value per indicator entry per local authority

# %% [markdown]
# None of this data is too old to include: there may still be some interesting patterns. I will now drop the 'Time period' column and any other unecessary ones. I can go back and check these later if I think it's important in my conclusions.

# %% [markdown]
# Step 9: clean data

# %%
df6=df5.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df367=df366.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df728=df727.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df1089=df1088.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df1450=df1449.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df1811=df1810.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df2172=df2171.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df2533=df2532.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df2894=df2893.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df3255=df3254.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df3616=df3615.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df3977=df3976.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df4338=df4337.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df4699=df4698.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df5060=df5059.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df5421=df5420.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df5782=df5781.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df6143=df6142.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df6504=df6503.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df6865=df6864.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df7226=df7225.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df7587=df7586.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df7948=df7947.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df8309=df8308.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df8670=df8669.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df9031=df9030.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df9392=df9391.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df9753=df9752.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df10114=df10113.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df10475=df10474.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df10836=df10835.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df11197=df11196.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df11558=df11557.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df11919=df11918.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df12280=df12279.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df12641=df12640.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df13002=df13001.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df13363=df13362.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df13724=df13723.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df14085=df14084.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df14446=df14445.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df14807=df14806.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df15168=df15167.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df15529=df15528.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df15890=df15889.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df16251=df16250.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df16612=df16611.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df16973=df16972.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df17334=df17333.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df17695=df17694.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df18056=df18055.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df18417=df18416.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df18778=df18777.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df19139=df19138.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df19500=df19499.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df19861=df19860.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df20222=df20221.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df20583=df20582.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df20944=df20943.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df21305=df21304.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df21666=df21665.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df22027=df22026.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df22388=df22387.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df22749=df22748.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df23110=df23109.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df23471=df23470.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df23832=df23831.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df24193=df24192.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df24554=df24553.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df24915=df24914.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df25276=df25275.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df25637=df25636.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df25998=df25997.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df26359=df26358.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
df26720=df26719.drop(['Unnamed: 0','Area Code','Sex','Age','Time period'],axis=1)
# Step 10: save in this format with indicator name as its own column. Before doing this, I changed the names of indicators with a '/' in their name by searching the list in Excel (because this symbol is not allowed) and replacing it with 'per' or manually

# %%
df6.to_csv("Under 75 mortality rate from all causes.csv")
df367.to_csv("Stroke: QOF prevalence (all ages).csv")
df728.to_csv("Hypertension: QOF prevalence (all ages).csv")
df1089.to_csv("CHD: QOF prevalence (all ages).csv")
df1450.to_csv("Depression: QOF prevalence (18+ yrs).csv")
df1811.to_csv("Mortality rate from lung cancer.csv")
df2172.to_csv("Mortality rate from chronic obstructive pulmonary disease.csv")
df2533.to_csv("Lung cancer registrations.csv")
df2894.to_csv("Oral cancer registrations.csv")
df3255.to_csv("Cost per capita of smoking attributable hospital admissions.csv")
df3616.to_csv("Percentage people living in 20% most deprived areas in England.csv")
df3977.to_csv("Children in low income families (under 16s).csv")
df4338.to_csv("Pupil absence.csv")
df4699.to_csv("Killed and seriously injured (KSI) casualties on Englands roads (historic data).csv")
df5060.to_csv("Violent crime - hospital admissions for violence (including sexual violence).csv")
df5421.to_csv("Violent crime - violence offences per 1,000 population.csv")
df5782.to_csv("The rate of complaints about noise.csv")
df6143.to_csv("Statutory homelessness: rate per 1,000 households.csv")
df6504.to_csv("Utilisation of outdoor space for exercise or health reasons.csv")
df6865.to_csv("Low birth weight of term babies.csv")
df7226.to_csv("Under 18s conception rate per 1,000.csv")
df7587.to_csv("Reception: Prevalence of overweight (including obesity).csv")
df7948.to_csv("Year 6: Prevalence of overweight (including obesity).csv")
df8309.to_csv("Emergency Hospital Admissions for Intentional Self-Harm.csv")
df8670.to_csv("Cancer screening coverage: breast cancer.csv")
df9031.to_csv("Emergency hospital admissions due to falls in people aged 65 and over.csv")
df9392.to_csv("Emergency hospital admissions due to falls in people aged 65-79.csv")
df9753.to_csv("Emergency hospital admissions due to falls in people aged 80+.csv")
df10114.to_csv("Fraction of mortality attributable to particulate air pollution (old method).csv")
df10475.to_csv("Under 75 mortality rate from all cardiovascular diseases.csv")
df10836.to_csv("Under 75 mortality rate from cancer.csv")
df11197.to_csv("Under 75 mortality rate from liver disease.csv")
df11558.to_csv("Under 75 mortality rate from respiratory disease.csv")
df11919.to_csv("Suicide rate.csv")
df12280.to_csv("Emergency readmissions within 30 days of discharge from hospital.csv")
df12641.to_csv("Hip fractures in people aged 65 and over.csv")
df13002.to_csv("Hip fractures in people aged 65-79.csv")
df13363.to_csv("Hip fractures in people aged 80+.csv")
df13724.to_csv("Gap in the employment rate between those with a physical or mental long term health condition (aged 16 to 64) and the overall employment rate.csv")
df14085.to_csv("Hospital admissions caused by unintentional and deliberate injuries in children (aged 0-14 years).csv")
df14446.to_csv("Hospital admissions caused by unintentional and deliberate injuries in young people (aged 15-24 years).csv")
df14807.to_csv("Sickness absence - the percentage of employees who had at least one day off in the previous week.csv")
df15168.to_csv("Sickness absence - the percentage of working days lost due to sickness absence.csv")
df15529.to_csv("Participation rate: Reception.csv")
df15890.to_csv("Participation rate: Year 6.csv")
df16251.to_csv("Participation rate: Total.csv")
df16612.to_csv("Records with valid ethnicity code.csv")
df16973.to_csv("Records with valid child postcode.csv")
df17334.to_csv("Records with height rounded to X.0 or X.5.csv")
df17695.to_csv("Records with weight rounded to X.0 or X.5.csv")
df18056.to_csv("Reception: Prevalence of underweight.csv")
df18417.to_csv("Reception: Prevalence of healthy weight.csv")
df18778.to_csv("Reception: Prevalence of obesity (including severe obesity).csv")
df19139.to_csv("Year 6: Prevalence of underweight.csv")
df19500.to_csv("Year 6: Prevalence of healthy weight.csv")
df19861.to_csv("Year 6: Prevalence of obesity (including severe obesity).csv")
df20222.to_csv("Fuel poverty (low income, high cost methodology).csv")
df20583.to_csv("Excess winter deaths index.csv")
df20944.to_csv("Excess winter deaths index (age 85+).csv")
df21305.to_csv("Life expectancy at birth.csv")
df21666.to_csv("New cases of psychosis: estimated incidence rate per 100,000 population aged 16-64.csv")
df22027.to_csv("Unpaid carers.csv")
df22388.to_csv("Overcrowded households.csv")
df22749.to_csv("Osteoporosis: QOF prevalence (50+ yrs).csv")
df23110.to_csv("Children in low income families (all dependent children under 20).csv")
df23471.to_csv("Violent crime - sexual offences per 1,000 population.csv")
df23832.to_csv("Migrant GP registrations: rate per 1,000 population.csv")
df24193.to_csv("Genital warts diagnostic rate per 100,000.csv")
df24554.to_csv("Under 18s conceptions leading to abortion (%).csv")
df24915.to_csv("Pelvic inflammatory disease (PID) admissions rate per 100,000.csv")
df25276.to_csv("Ectopic pregnancy admissions rate per 100,000.csv")
df25637.to_csv("Syphilis diagnostic rate per 100,000.csv")
df25998.to_csv("Gonorrhoea diagnostic rate per 100,000.csv")
df26359.to_csv("Chlamydia detection rate per 100,000 aged 15 to 24.csv")
df26720.to_csv("Chlamydia proportion aged 15 to 24 screened.csv")
df27081.to_csv("HIV diagnosed prevalence rate per 1,000 aged 15 to 59.csv")
df27442.to_csv("HIV late diagnosis in people first diagnosed with HIV in the UK.csv")
df27803.to_csv("Children killed and seriously injured (KSI) on Englands roads.csv")
df28164.to_csv("Hospital admissions caused by unintentional and deliberate injuries in children (aged 0-4 years).csv")
df28525.to_csv("The percentage of people resident in the area living in each national deprivation quintile.csv")
df28886.to_csv("Hospital admission rate due to liver disease.csv")
df29247.to_csv("Genital herpes diagnosis rate per 100,000.csv")
df29608.to_csv("HIV testing coverage, women.csv")
df29969.to_csv("HIV testing coverage, gay, bisexual and other men who have sex with men.csv")
df30330.to_csv("HIV testing coverage, men.csv")
df30691.to_csv("Life expectancy at 65.csv")
df31052.to_csv("Unemployment (model-based).csv")
df31413.to_csv("Long term claimants of Jobseekers Allowance.csv")
df31774.to_csv("Young people providing 20+ hoursperweek of unpaid care (aged 16-24).csv")
df32135.to_csv("Children providing unpaid care (aged 0-15).csv")
df32496.to_csv("Young people providing unpaid care (aged 16-24).csv")
df32857.to_csv("Under 75 mortality rate from colorectal cancer.csv")
df33218.to_csv("Under 75 mortality rate from breast cancer.csv")
df33579.to_csv("Under 75 mortality rate from injuries.csv")
df33940.to_csv("Under 75 mortality rate from heart disease.csv")
df34301.to_csv("Under 75 mortality rate from stroke.csv")
df34662.to_csv("Health related quality of life for older people.csv")
df35023.to_csv("Rheumatoid Arthritis: QOF prevalence (16+ yrs).csv")
df35384.to_csv("New STI diagnoses (excluding chlamydia aged under 25) per 100,000.csv")
df35745.to_csv("STI testing rate (exclude chlamydia aged under 25) per 100,000.csv")
df36106.to_csv("STI testing positivity (excluding chlamydia aged under 25).csv")
df36467.to_csv("TB incidence (three year average).csv")
df36828.to_csv("Proportion of drug sensitive TB cases who had completed a full course of treatment by 12 months.csv")
df37189.to_csv("Alcohol-specific mortality.csv")
df37550.to_csv("Mortality from chronic liver disease.csv")
df37911.to_csv("Under 18s births rate per 1,000.csv")
df38272.to_csv("Percentage with a mean daily sedentary time in the last week over 7 hours per day at age 15.csv")
df38633.to_csv("Percentage physically active for at least one hour per day seven days a week at age 15.csv")
df38994.to_csv("Chlamydia detection rate per 100,000 aged 15 to 24.csv")
df39355.to_csv("Chlamydia diagnostic rate per 100,000.csv")
df39716.to_csv("Chlamydia diagnostic rate per 100,000 aged 25 years and older.csv")
df40077.to_csv("All new STI diagnoses rate per 100,000.csv")
df40438.to_csv("HIV testing coverage, total.csv")
df40799.to_csv("Smoking prevalence in adults (15+) - current smokers (QOF).csv")
df41160.to_csv("Cancer screening coverage: bowel cancer.csv")
df41521.to_csv("Premature births (less than 37 weeks gestation).csv")
df41882.to_csv("New HIV diagnosis rate per 100,000.csv")
df42243.to_csv("GP prescribed LARC excluding injections rate per 1,000.csv")
df42604.to_csv("Deprivation score (IMD 2015).csv")
df42965.to_csv("Reception: Prevalence of obesity (including severe obesity), 5-years data combined.csv")
df43326.to_csv("Year 6: Prevalence of obesity (including severe obesity), 5-years data combined.csv")
df43687.to_csv("Infant mortality rate.csv")
df44048.to_csv("Educational attainment (5 or more GCSEs): % of all children.csv")
df44409.to_csv("Total prescribed LARC excluding injections rate per 1,000.csv")
df44770.to_csv("SRH Services prescribed LARC excluding injections rate per 1,000.csv")
df45131.to_csv("Women choose injections at SRH Services (%).csv")
df45492.to_csv("Women choose user-dependent methods at SRH Services (%).csv")
df45853.to_csv("Women choose hormonal short-acting contraceptives at SRH Services (%).csv")
df46214.to_csv("Under 25s choose LARC excluding injections at SRH Services (%).csv")
df46575.to_csv("Over 25s  choose LARC excluding injections at SRH Services (%).csv")
df46936.to_csv("Emergency hospital admissions for COPD.csv")
df47297.to_csv("Smoking prevalence in adults (18+) - current smokers (GPPS).csv")
df47658.to_csv("Smoking prevalence in adults (18+) - ex smoker (GPPS).csv")
df48019.to_csv("Smoking prevalence in adults (18+) - never smoked (GPPS).csv")
df48380.to_csv("Supporting information - % population aged under 18.csv")
df48741.to_csv("Supporting information - % population aged 65+.csv")
df49102.to_csv("Percentage of people in employment.csv")
df49463.to_csv("Abdominal Aortic Aneurysm Screening Coverage.csv")
df49824.to_csv("Incidence rate of alcohol-related cancer.csv")
df50185.to_csv("Mortality rate from a range of specified communicable diseases, including influenza.csv")
df50546.to_csv("Deaths from drug misuse.csv")
df50907.to_csv("Smoking Prevalence in adults (18+) - current smokers (APS).csv")
df51268.to_csv("Smoking prevalence in adults in routine and manual occupations (18-64) - current smokers (APS).csv")
df51629.to_csv("0.csv")
df51990.to_csv("Reception: Prevalence of overweight.csv")
df52351.to_csv("Year 6: Prevalence of overweight.csv")
df52712.to_csv("Mortality rate from causes considered preventable (2016 definition).csv")
df53073.to_csv("Care home beds per 100 people 75+.csv")
df53434.to_csv("Nursing home beds per 100 people 75+.csv")
df53795.to_csv("Smoking Prevalence in adults (18+) - ex smokers (APS).csv")
df54156.to_csv("Smoking Prevalence in adults (18+) - never smoked (APS).csv")
df54517.to_csv("Crime deprivation: score.csv")
df54878.to_csv("Adjusted antibiotic prescribing in primary care by the NHS.csv")
df55239.to_csv("Resident population.csv")
df55600.to_csv("Mortality rate from all cardiovascular diseases, ages 65+ years.csv")
df55961.to_csv("Mortality rate from cancer, ages 65+ years.csv")
df56322.to_csv("Mortality rate from respiratory disease, ages 65+ years.csv")
df56683.to_csv("Volume of pure alcohol sold through the off-trade: all alcohol sales.csv")
df57044.to_csv("Volume of pure alcohol sold through the off-trade: beer sales.csv")
df57405.to_csv("Volume of pure alcohol sold through the off-trade: wine sales.csv")
df57766.to_csv("Volume of pure alcohol sold through the off-trade: spirit sales.csv")
df58127.to_csv("Number of premises licensed to sell alcohol per square kilometre.csv")
df58488.to_csv("Typhoid & paratyphoid incidence rateper100,000.csv")
df58849.to_csv("Supporting information - % population from ethnic minorities.csv")
df59210.to_csv("Economic inactivity rate.csv")
df59571.to_csv("Inequality in life expectancy at birth.csv")
df59932.to_csv("Admission episodes for alcohol-specific conditions - Under 18s.csv")
df60293.to_csv("Admission episodes for alcohol-specific conditions.csv")
df60654.to_csv("Air pollution: fine particulate matter (historic indicator).csv")
df61015.to_csv("Density of fast food outlets.csv")
df61376.to_csv("Estimated dementia diagnosis rate (aged 65 and over).csv")
df61737.to_csv("Mortality rate from oral cancer.csv")
df62098.to_csv("Percentage of physically active adults.csv")
df62459.to_csv("Percentage of physically inactive adults.csv")
df62820.to_csv("Access to Healthy Assets & Hazards Index.csv")
df63181.to_csv("Proportion of the population meeting the recommended 5-a-day on a usual day (adults).csv")
df63542.to_csv("Percentage of the total resident population who are 65 and over.csv")
df63903.to_csv("Percentage of the total resident population who are 25 to 64 years of age.csv")
df64264.to_csv("Percentage of the total resident population who are 16 to 24 years of age.csv")
df64625.to_csv("Percentage of the total resident population who are 0 to 15 years of age.csv")
df64986.to_csv("Smoking status at time of delivery.csv")
df65347.to_csv("Back pain prevalence in people of all ages.csv")
df65708.to_csv("Percentage of population whose ethnicity is not White UK.csv")
df66069.to_csv("Percentage of adults (aged 18+) classified as overweight or obese.csv")
df66430.to_csv("General fertility rate: live births per 1,000 women aged 15-44 years. five year pooled.csv")
df66791.to_csv("Prevalence of severe hip osteoarthritis in people aged  45 and over.csv")
df67152.to_csv("Low birth weight of live babies, five year pooled.csv")
df67513.to_csv("Prevalence of hip osteoarthritis in people aged  45 and over.csv")
df67874.to_csv("Child Poverty, Income deprivation affecting children index (IDACI).csv")
df68235.to_csv("Prevalence of severe knee osteoarthritis in people aged  45 and over.csv")
df68596.to_csv("Prevalence of knee osteoarthritis in people aged  45 and over.csv")
df68957.to_csv("Unemployment (Percentage of the working age population claiming out of work benefit).csv")
df69318.to_csv("Long-Term Unemployment- rate per 1,000 working age population.csv")
df69679.to_csv("Older people living alone, % of people aged 65 and over who are living alone.csv")
df70040.to_csv("Employment and Support Allowance claimants.csv")
df70401.to_csv("Reception: Prevalence of obesity (including severe obesity), 3-years data combined.csv")
df70762.to_csv("Reception: Prevalence of overweight (including obesity), 3-years data combined.csv")
df71123.to_csv("Year 6: Prevalence of obesity (including severe obesity), 3-years data combined.csv")
df71484.to_csv("Year 6: Prevalence of overweight (including obesity), 3-years data combined.csv")
df71845.to_csv("Affordability of home ownership.csv")
df72206.to_csv("Deliveries to teenage mothers.csv")
df72567.to_csv("Emergency hospital admissions for injuries in under 5 years old, crude rate.csv")
df72928.to_csv("Emergency hospital admissions in under 5 years old, crude rate.csv")
df73289.to_csv("Measles incidence rateper100,000.csv")
df73650.to_csv("Measles 5-year incidence rateper100,000.csv")
df74011.to_csv("Acute hepatitis B incidence rateper100,000.csv")
df74372.to_csv("Hepatitis C detection rateper100,000.csv")
df74733.to_csv("Inequality in life expectancy at 65.csv")
df75094.to_csv("Reception: Prevalence of severe obesity.csv")
df75455.to_csv("Year 6: Prevalence of severe obesity.csv")
df75816.to_csv("Emergency hospital admissions for injuries in under 15 years old, crude rate.csv")
df76177.to_csv("Emergency hospital admissions for injuries in 15 to 24 years old, crude rate.csv")
df76538.to_csv("Percentage of the total resident population aged 85 and over.csv")
df76899.to_csv("Emergency hospital admissions for all causes, all ages, standardised admission ratio.csv")
df77260.to_csv("Emergency hospital admissions for coronary heart disease, standardised admission ratio.csv")
df77621.to_csv("Emergency hospital admissions for stroke, standardised admission ratio.csv")
df77982.to_csv("Emergency hospital admissions for Myocardial Infarction (heart attack), standardised admission ratio.csv")
df78343.to_csv("Emergency hospital admissions for Chronic Obstructive Pulmonary Disease (COPD), standardised admission ratio.csv")
df78704.to_csv("Incidence of all cancers, standardised incidence ratio.csv")
df79065.to_csv("Incidence of breast cancer, standardised incidence ratio.csv")
df79426.to_csv("Incidence of colorectal cancer, standardised incidence ratio.csv")
df79787.to_csv("Incidence of lung cancer, standardised incidence ratio.csv")
df80148.to_csv("Incidence of prostate cancer, standardised incidence ratio.csv")
df80509.to_csv("Emergency hospital admissions for intentional self harm, standardised admission ratio.csv")
df80870.to_csv("Hospital admissions for alcohol attributable conditions, (Narrow definition).csv")
df81231.to_csv("Emergency hospital admissions for hip fracture in persons 65 years and over, standardised admission ratio.csv")
df81592.to_csv("Deaths from all causes, all ages, standardised mortality ratio.csv")
df81953.to_csv("Deaths from all causes, under 75 years, standardised mortality ratio.csv")
df82314.to_csv("Deaths from all cancer, all ages, standardised mortality ratio.csv")
df82675.to_csv("Deaths from all cancer, under 75 years, standardised mortality ratio (SMR).csv")
df83036.to_csv("Deaths from circulatory disease, all ages, standardised mortality ratio.csv")
df83397.to_csv("Deaths from circulatory disease, under 75 years, standardised mortality ratio.csv")
df83758.to_csv("Deaths from coronary heart disease, all ages, standardised mortality ratio.csv")
df84119.to_csv("Deaths from stroke, all ages, standardised mortality ratio.csv")
df84480.to_csv("Deaths from respiratory diseases, all ages, standardised mortality ratio.csv")
df84841.to_csv("Percentage of population whose ethnic group is not white.csv")
df85202.to_csv("Income deprivation, English Indices of Deprivation.csv")
df85563.to_csv("The percentage of people that cannot speak English well or at all,  2011.csv")
df85924.to_csv("Index of Multiple Deprivation (IMD) Score.csv")
df86285.to_csv("Percentage of people who reported having a limiting long term illness or disability.csv")
df86646.to_csv("Households with overcrowding based on overall room occupancy levels.csv")
df87007.to_csv("Older people in poverty: Income deprivation affecting older people Index (IDAOPI).csv")
df87368.to_csv("Modelled estimates of the proportion of households in fuel poverty (%).csv")
df87729.to_csv("Life expectancy at birth, (upper age band 90 and over).csv")
df88090.to_csv("Under 25s individuals attend specialist contraceptive services rate per 1000 - Females.csv")
df88451.to_csv("Under 25s individuals attend specialist contraceptive services rate per 1000 - Males.csv")
df88812.to_csv("STEC  (Shiga toxin-producing Escherichia coli) serogroup O157 5-year incidence rateper100,000.csv")
df89173.to_csv("STEC (Shiga toxin-producing Escherichia coli) serogroup O157 incidence rateper100,000.csv")
df89534.to_csv("Estimated diabetes diagnosis rate.csv")
df89895.to_csv("Gender pay gap (by workplace location).csv")
df90256.to_csv("Average weekly earnings.csv")
df90617.to_csv("Job density.csv")
df90978.to_csv("Non-typhoidal Salmonella incidence rateper100,000.csv")
df91339.to_csv("Campylobacter incidence rateper100,000.csv")
df91700.to_csv("Shigella incidence rateper100,000.csv")
df92061.to_csv("% reporting a long term MSK problem who also report depression or anxiety.csv")
df92422.to_csv("Average health related quality of life score for adults who reported having a long term MSK problem..csv")
df92783.to_csv("% reporting depression or anxiety.csv")
df93144.to_csv("Percentage reporting a long-term Musculoskeletal (MSK) problem.csv")
df93505.to_csv("Average Attainment 8 score.csv")
df93866.to_csv("Giardia incidence rateper100,000.csv")
df94227.to_csv("Cryptosporidium incidence rateper100,000.csv")
df94588.to_csv("Odds of current smoking (self-reported) among adults aged 18-64 with a routine and manual occupation (APS).csv")
df94949.to_csv("Oesophageal cancer registrations.csv")
df95310.to_csv("Percentage of adults walking for travel at least three days per week.csv")
df95671.to_csv("Percentage of adults cycling for travel at least three days per week.csv")
df96032.to_csv("Percentage reporting at least two long-term conditions, at least one of which is MSK related.csv")
df96393.to_csv("Smoking prevalence in adults with a long term mental health condition (18+) - current smokers (GPPS).csv")
df96754.to_csv("Smoking prevalence in adults with anxiety or depression (18+) - current smokers (GPPS).csv")
df97115.to_csv("Listeria incidence rateper100,000.csv")
df97476.to_csv("Scarlet fever notification rateper100,000 aged 0-9 yrs.csv")
df97837.to_csv("Hospital admissions for alcohol attributable conditions, (Broad definition).csv")
df98198.to_csv("Mumps incidence rateper100,000.csv")
df98559.to_csv("Mumps 5-year incidence rateper100,000.csv")
df98920.to_csv("Percentage of deaths that occur in hospital.csv")
df99281.to_csv("Percentage of deaths that occur in care homes.csv")
df99642.to_csv("Percentage of deaths that occur at home.csv")
df100003.to_csv("Percentage of deaths that occur in other places.csv")
df100364.to_csv("Percentage of deaths that occur in hospice.csv")
df100725.to_csv("Deaths from causes considered preventable, under 75 years, standardised mortality ratio.csv")
df101086.to_csv("Smoking prevalence at age 15 - regular smokers (modelled estimates).csv")
df101447.to_csv("Smoking prevalence at age 15 - regular or occasional smokers (modelled estimates).csv")
df101808.to_csv("Listeria 5-year incidence rateper100,000.csv")
df102169.to_csv("Estimated prevalence of common mental disorders: % of population aged 16 & over.csv")
df102530.to_csv("Estimated prevalence of common mental disorders: % of population aged 65 & over.csv")
df102891.to_csv("Percentage of deaths with underlying cause Cancer.csv")
df103252.to_csv("Percentage of deaths with underlying cause respiratory disease.csv")
df103613.to_csv("Percentage of deaths with underlying cause circulatory disease.csv")
df103974.to_csv("Percentage of all Deaths.csv")
df104335.to_csv("Mortality Rate.csv")
df104696.to_csv("Re-offending levels - percentage of offenders who re-offend.csv")
df105057.to_csv("Pertussis incidence rateper100,000.csv")
df105418.to_csv("Prompt antiretroviral therapy (ART) initiation in people newly diagnosed with HIV.csv")
df105779.to_csv("Virological success in adults accessing HIV care.csv")
df106140.to_csv("Repeat HIV testing in gay, bisexual and other men who have sex with men.csv")
df106501.to_csv("Deprivation score (IMD 2019).csv")
df106862.to_csv("Cancer screening coverage: cervical cancer (aged 25 to 49 years old).csv")
df107223.to_csv("Cancer screening coverage: cervical cancer (aged 50 to 64 years old).csv")
df107584.to_csv("Percentage of 5 year olds with experience of visually obvious dental decay.csv")
df107945.to_csv("Percentage of physically active children and young people.csv")
df108306.to_csv("Re-offending levels - average number of re-offences per re-offender.csv")
df108667.to_csv("Babys first feed breastmilk.csv")
df109028.to_csv("Invasive Meningococcal Disease (IMD) confirmed cases rateper100,000.csv")
df109389.to_csv("Mortality rate from asthma.csv")
df109750.to_csv("Odds of current smoking (self-reported) among adults aged 18+ diagnosed with a long-term mental health condition.csv")
df110111.to_csv("Percentage of cancers diagnosed at stages 1 and 2.csv")
df110472.to_csv("Population vaccination coverage: Flu (primary school aged children).csv")
df110833.to_csv("Children in relative low income families (under 16s).csv")
df111194.to_csv("Children in absolute low income families (under 16s).csv")
df111555.to_csv("Under 75 mortality rate from liver disease considered preventable (2019 definition).csv")
df111916.to_csv("Under 75 mortality rate from causes considered preventable (2019 definition).csv")
df112277.to_csv("Under 75 mortality rate from cardiovascular diseases considered preventable (2019 definition).csv")
df112638.to_csv("Under 75 mortality rate from cancer considered preventable (2019 definition).csv")
df112999.to_csv("Under 75 mortality rate from respiratory disease considered preventable (2019 definition).csv")
df113360.to_csv("Homelessness - households in temporary accommodation.csv")
df113721.to_csv("Homelessness - households owed a duty under the Homelessness Reduction Act.csv")
df114082.to_csv("Homelessness - households owed a duty under the Homelessness Reduction Act (main applicant 16-24 yrs).csv")
df114443.to_csv("Homelessness - households owed a duty under the Homelessness Reduction Act (main applicant 55+ yrs).csv")
df114804.to_csv("Homelessness - households with dependent children owed a duty under the Homelessness Reduction Act.csv")
df115165.to_csv("Odds ratio of reporting a mental health condition among people with and without an MSK condition.csv")
df115526.to_csv("Percentage of the total resident population who are 0 to 4 years of age.csv")
df115887.to_csv("Percentage of the total resident population who are 5 to 15 years of age.csv")
df116248.to_csv("Percentage of the total resident population who are 50 to 64 years of age.csv")
df116609.to_csv("Population density, people per square kilometre.csv")
df116970.to_csv("Smoking attributable mortality (new method).csv")
df117331.to_csv("Smoking attributable deaths from heart disease (new method).csv")
df117692.to_csv("Smoking attributable deaths from stroke (new method).csv")
df118053.to_csv("Smoking attributable hospital admissions (new method). This indicator uses new set of attributable fractions, and so differ from that originally published..csv")
df118414.to_csv("Killed and seriously injured (KSI) casualties on Englands roads.csv")
df118775.to_csv("Loneliness: Percentage of adults who feel lonely often per always or some of the time.csv")
df119136.to_csv("Fuel poverty (low income, low energy efficiency methodology).csv")
df119497.to_csv("Mycoplasma genitalium diagnostic rate per 100,000.csv")
df119858.to_csv("Trichomoniasis diagnostic rate per 100,000.csv")
df120219.to_csv("Alcohol-related mortality: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv")
df120580.to_csv("Admission episodes for alcohol-related conditions (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv")
df120941.to_csv("Admission episodes for alcohol-related conditions (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv")
df121302.to_csv("Admission episodes for alcohol-related unintentional injuries (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv")
df121663.to_csv("Admission episodes for mental and behavioural disorders due to use of alcohol (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv")
df122024.to_csv("Admission episodes for intentional self-poisoning by and exposure to alcohol (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv")
df122385.to_csv("Admission episodes for alcohol-related cardiovascular disease (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv")
df122746.to_csv("Admission episodes for mental and behavioural disorders due to use of alcohol (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv")
df123107.to_csv("Admission episodes for alcoholic liver disease (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv")
df123468.to_csv("Admission episodes for alcohol-related conditions (Narrow) - Under 40s: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv")
df123829.to_csv("Admission episodes for alcohol-related conditions (Narrow)40 to 64 years: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv")
df124190.to_csv("Admission episodes for alcohol-related conditions (Narrow)65+ years: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv")
df124551.to_csv("HIV diagnosed prevalence rate per 1,000.csv")
df124912.to_csv("New HIV diagnoses among persons first diagnosed in the UK rate per 100,000.csv")
df125273.to_csv("Antiretroviral therapy (ART) coverage in people accessing HIV care.csv")
df125634.to_csv("Mortality rate from all causes, all ages.csv")
df125995.to_csv("Mortality rate for deaths involving COVID-19, all ages.csv")
df126356.to_csv("Mortality rate for deaths involving COVID-19, under 75s.csv")
df126717.to_csv("Fraction of mortality attributable to particulate air pollution (new method).csv")
df127078.to_csv("Acute Lyme disease laboratory confirmed incidence rateper100,000.csv")
df127439.to_csv("Average Attainment 8 Score among children eligible for Free School Meals (FSM).csv")
df127800.to_csv("Air pollution: fine particulate matter (new method - concentrations of total PM2.5).csv")
df128161.to_csv("Potential years of life lost (PYLL) due to alcohol-related conditions.csv")
df128522.to_csv("Percentage of adults (aged 18+) classified as obese.csv")
df128883.to_csv("The percentage of the population with a physical or mental long term health condition in employment (aged 16 to 64).csv")
df129244.to_csv("The percentage of the population who are in receipt of long term support for a learning disability that are in paid employment (aged 18 to 64).csv")
df129605.to_csv("Initiation or continuation of PrEP among those with PrEP need.csv")
df129966.to_csv("Determining PrEP need.csv")

# %%
dfGROUPED.to_csv("GroupedIndicators.csv")

# %%
# Make sure you have authorized Colab to access your Google Drive
from google.colab import drive
drive.mount('/content/drive')

#
,	df97836,	df98197,	df98558,	df98919,	df99280,	df99641,	df100002,	df100363,	df100724,	df101085,	df101446,	df101807,	df102168,	df102529,	df102890,	df103251,	df103612,	df103973,	df104334,	df104695,	df105056,	df105417,	df105778,	df106139,	df106500,	df106861,	df107222,	df107583,	df107944,	df108305,	df108666,	df109027,	df109388,	df109749,	df110110,	df110471,	df110832,	df111193,	df111554,	df111915,	df112276,	df112637,	df112998,	df113359,	df113720,	df114081,	df114442,	df114803,	df115164,	df115525,	df115886,	df116247,	df116608,	df116969,	df117330,	df117691,	df118052,	df118413,	df118774,	df119135,	df119496,	df119857,	df120218,	df120579,	df120940,	df121301,	df121662,	df122023,	df122384,	df122745,	df123106,	df123467,	df123828,	df124189,	df124550,	df124911,	df125272,	df125633,	df125994,	df126355,	df126716,	df127077,	df127438,	df127799,	df128160,	df128521,	df128882,	df129243,	df129604,	df129965]

# %%
for df in df_list:
  rows = df.shape[0]
  print(f"Number of rows in {df}:{rows}")
# Out:
# Streaming output truncated to the last 5000 lines.
# ...           ...                                                ...
# 11923       12841  Admission episodes for alcohol-specific condit...
# 11924       12842  Admission episodes for alcohol-specific condit...
# 11925       12843  Admission episodes for alcohol-specific condit...
# 11926       12844  Admission episodes for alcohol-specific condit...
# 11927       12845  Admission episodes for alcohol-specific condit...
#
#        Area Code              Area Name      Sex       Age Time period   Value
# 11601  E06000001             Hartlepool  Persons  All ages     2020/21  886.53
# 11602  E06000002          Middlesbrough  Persons  All ages     2020/21  866.45
# 11603  E06000003   Redcar and Cleveland  Persons  All ages     2020/21  680.38
# 11604  E06000004       Stockton-on-Tees  Persons  All ages     2020/21  775.89
# 11605  E06000005             Darlington  Persons  All ages     2020/21  775.55
# ...

# %%
print(dfGROUPED["Indicator Name"].value_counts().head(10))
# Out:
# Under 75 mortality rate from all causes                                                                         309
# Deaths from all cancer, all ages, standardised mortality ratio                                                  309
# Deaths from respiratory diseases, all ages, standardised mortality ratio                                        309
# Deaths from stroke, all ages, standardised mortality ratio                                                      309
# Deaths from coronary heart disease, all ages, standardised mortality ratio                                      309
# Deaths from circulatory disease, under 75 years, standardised mortality ratio                                   309
# Deaths from circulatory disease, all ages, standardised mortality ratio                                         309
# Deaths from all cancer, under 75 years, standardised mortality ratio (SMR)                                      309
# ...

# %%
 print(dfGROUPED["Indicator Name"].value_counts().tail(25))
# Out:
# Crime deprivation: score                                                                                                                                       302
# Number of premises licensed to sell alcohol per square kilometre                                                                                               302
# Hepatitis C detection rate/100,000                                                                                                                             302
# Migrant GP registrations: rate per 1,000 population                                                                                                            302
# Deprivation score (IMD 2015)                                                                                                                                   302
# Campylobacter incidence rate/100,000                                                                                                                           302
# ...

# %% [markdown]
# Seems 309 rows per indicator besides last few (i.e. the number of local authorities in england)...thumbs up!

# %%
print(dfGROUPED["Age"].value_counts().head(60))
# Out:
# All ages                               35728
# <75 yrs                                 5871
# 18+ yrs                                 5818
# 16+ yrs                                 5050
# 65+ yrs                                 4003
# Not applicable                          3380
# 10-11 yrs                               3090
# <65 yrs                                 3090
# 4-5 yrs                                 3090
# 16-64 yrs                               1856
# <16 yrs                                 1671
# 0-4 yrs                                 1545
# 15-24 yrs                               1236
# 45+ yrs                                 1216
# 35+ yrs                                 1115
# 18-64 yrs                                927
# 15 yrs                                   866
# 75+ yrs                                  618
# 15-16 yrs                                618
# <18 yrs                                  618
# 19+ yrs                                  618
# ...

# %%
df_row_counts = [df.shape[0] for df in df_list]
df_row_counts
# Out:
# [309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  304,
#  309,
#  307,
#  309,
#  0,
#  309,
#  309,
#  309,
#  0,
#  124,
#  309,
#  0,
#  309,
#  309,
#  309,
#  0,
#  309,
#  309,
#  309,
#  307,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  0,
#  309,
#  309,
#  0,
#  304,
#  0,
#  0,
#  309,
#  307,
#  309,
#  302,
#  309,
#  0,
#  306,
#  0,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  128,
#  309,
#  307,
#  309,
#  309,
#  0,
#  0,
#  0,
#  0,
#  309,
#  309,
#  0,
#  0,
#  0,
#  309,
#  0,
#  309,
#  309,
#  309,
#  302,
#  309,
#  309,
#  309,
#  309,
#  307,
#  126,
#  309,
#  309,
#  0,
#  124,
#  124,
#  0,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  0,
#  302,
#  309,
#  309,
#  309,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  307,
#  307,
# ...

# %% [markdown]
# Most data remains, those lost (those returning '0' in print) likely to just have had England-wide data

# %% [markdown]
# Step 11: load cleaned CSVs if reopening notebook.

# %%
df7= pd.read_csv('Under 75 mortality rate from all causes.csv')
df368= pd.read_csv('Stroke: QOF prevalence (all ages).csv')
df729= pd.read_csv('Hypertension: QOF prevalence (all ages).csv')
df1090= pd.read_csv('CHD: QOF prevalence (all ages).csv')
df1451= pd.read_csv('Depression: QOF prevalence (18+ yrs).csv')
df1812= pd.read_csv('Mortality rate from lung cancer.csv')
df2173= pd.read_csv('Mortality rate from chronic obstructive pulmonary disease.csv')
df2534= pd.read_csv('Lung cancer registrations.csv')
df2895= pd.read_csv('Oral cancer registrations.csv')
df3256= pd.read_csv('Cost per capita of smoking attributable hospital admissions.csv')
df3617= pd.read_csv('Percentage people living in 20% most deprived areas in England.csv')
df3978= pd.read_csv('Children in low income families (under 16s).csv')
df4339= pd.read_csv('Pupil absence.csv')
df4700= pd.read_csv('Killed and seriously injured (KSI) casualties on Englands roads (historic data).csv')
df5061= pd.read_csv('Violent crime - hospital admissions for violence (including sexual violence).csv')
df5422= pd.read_csv('Violent crime - violence offences per 1,000 population.csv')
df5783= pd.read_csv('The rate of complaints about noise.csv')
df6144= pd.read_csv('Statutory homelessness: rate per 1,000 households.csv')
df6505= pd.read_csv('Utilisation of outdoor space for exercise or health reasons.csv')
df6866= pd.read_csv('Low birth weight of term babies.csv')
df7227= pd.read_csv('Under 18s conception rate per 1,000.csv')
df7588= pd.read_csv('Reception: Prevalence of overweight (including obesity).csv')
df7949= pd.read_csv('Year 6: Prevalence of overweight (including obesity).csv')
df8310= pd.read_csv('Emergency Hospital Admissions for Intentional Self-Harm.csv')
df8671= pd.read_csv('Cancer screening coverage: breast cancer.csv')
df9032= pd.read_csv('Emergency hospital admissions due to falls in people aged 65 and over.csv')
df9393= pd.read_csv('Emergency hospital admissions due to falls in people aged 65-79.csv')
df9754= pd.read_csv('Emergency hospital admissions due to falls in people aged 80+.csv')
df10115= pd.read_csv('Fraction of mortality attributable to particulate air pollution (old method).csv')
df10476= pd.read_csv('Under 75 mortality rate from all cardiovascular diseases.csv')
df10837= pd.read_csv('Under 75 mortality rate from cancer.csv')
df11198= pd.read_csv('Under 75 mortality rate from liver disease.csv')
df11559= pd.read_csv('Under 75 mortality rate from respiratory disease.csv')
df11920= pd.read_csv('Suicide rate.csv')
df12281= pd.read_csv('Emergency readmissions within 30 days of discharge from hospital.csv')
df12642= pd.read_csv('Hip fractures in people aged 65 and over.csv')
df13003= pd.read_csv('Hip fractures in people aged 65-79.csv')
df13364= pd.read_csv('Hip fractures in people aged 80+.csv')
df13725= pd.read_csv('Gap in the employment rate between those with a physical or mental long term health condition (aged 16 to 64) and the overall employment rate.csv')
df14086= pd.read_csv('Hospital admissions caused by unintentional and deliberate injuries in children (aged 0-14 years).csv')
df14447= pd.read_csv('Hospital admissions caused by unintentional and deliberate injuries in young people (aged 15-24 years).csv')
df14808= pd.read_csv('Sickness absence - the percentage of employees who had at least one day off in the previous week.csv')
df15169= pd.read_csv('Sickness absence - the percentage of working days lost due to sickness absence.csv')
df15530= pd.read_csv('Participation rate: Reception.csv')
df15891= pd.read_csv('Participation rate: Year 6.csv')
df16252= pd.read_csv('Participation rate: Total.csv')
df16613= pd.read_csv('Records with valid ethnicity code.csv')
df16974= pd.read_csv('Records with valid child postcode.csv')
df17335= pd.read_csv('Records with height rounded to X.0 or X.5.csv')
df17696= pd.read_csv('Records with weight rounded to X.0 or X.5.csv')
df18057= pd.read_csv('Reception: Prevalence of underweight.csv')
df18418= pd.read_csv('Reception: Prevalence of healthy weight.csv')
df18779= pd.read_csv('Reception: Prevalence of obesity (including severe obesity).csv')
df19140= pd.read_csv('Year 6: Prevalence of underweight.csv')
df19501= pd.read_csv('Year 6: Prevalence of healthy weight.csv')
df19862= pd.read_csv('Year 6: Prevalence of obesity (including severe obesity).csv')
df20223= pd.read_csv('Fuel poverty (low income, high cost methodology).csv')
df20584= pd.read_csv('Excess winter deaths index.csv')
df20945= pd.read_csv('Excess winter deaths index (age 85+).csv')
df21306= pd.read_csv('Life expectancy at birth.csv')
df21667= pd.read_csv('New cases of psychosis: estimated incidence rate per 100,000 population aged 16-64.csv')
df22028= pd.read_csv('Unpaid carers.csv')
df22389= pd.read_csv('Overcrowded households.csv')
df22750= pd.read_csv('Osteoporosis: QOF prevalence (50+ yrs).csv')
df23111= pd.read_csv('Children in low income families (all dependent children under 20).csv')
df23472= pd.read_csv('Violent crime - sexual offences per 1,000 population.csv')
df23833= pd.read_csv('Migrant GP registrations: rate per 1,000 population.csv')
df24194= pd.read_csv('Genital warts diagnostic rate per 100,000.csv')
df24555= pd.read_csv('Under 18s conceptions leading to abortion (%).csv')
df24916= pd.read_csv('Pelvic inflammatory disease (PID) admissions rate per 100,000.csv')
df25277= pd.read_csv('Ectopic pregnancy admissions rate per 100,000.csv')
df25638= pd.read_csv('Syphilis diagnostic rate per 100,000.csv')
df25999= pd.read_csv('Gonorrhoea diagnostic rate per 100,000.csv')
df26360= pd.read_csv('Chlamydia detection rate per 100,000 aged 15 to 24.csv')
df26721= pd.read_csv('Chlamydia proportion aged 15 to 24 screened.csv')
df27082= pd.read_csv('HIV diagnosed prevalence rate per 1,000 aged 15 to 59.csv')
df27443= pd.read_csv('HIV late diagnosis in people first diagnosed with HIV in the UK.csv')
df27804= pd.read_csv('Children killed and seriously injured (KSI) on Englands roads.csv')
df28165= pd.read_csv('Hospital admissions caused by unintentional and deliberate injuries in children (aged 0-4 years).csv')
df28526= pd.read_csv('The percentage of people resident in the area living in each national deprivation quintile.csv')
df28887= pd.read_csv('Hospital admission rate due to liver disease.csv')
df29248= pd.read_csv('Genital herpes diagnosis rate per 100,000.csv')
df29609= pd.read_csv('HIV testing coverage, women.csv')
df29970= pd.read_csv('HIV testing coverage, gay, bisexual and other men who have sex with men.csv')
df30331= pd.read_csv('HIV testing coverage, men.csv')
df30692= pd.read_csv('Life expectancy at 65.csv')
df31053= pd.read_csv('Unemployment (model-based).csv')
df31414= pd.read_csv('Long term claimants of Jobseekers Allowance.csv')
df31775= pd.read_csv('Young people providing 20+ hoursperweek of unpaid care (aged 16-24).csv')
df32136= pd.read_csv('Children providing unpaid care (aged 0-15).csv')
df32497= pd.read_csv('Young people providing unpaid care (aged 16-24).csv')
df32858= pd.read_csv('Under 75 mortality rate from colorectal cancer.csv')
df33219= pd.read_csv('Under 75 mortality rate from breast cancer.csv')
df33580= pd.read_csv('Under 75 mortality rate from injuries.csv')
df33941= pd.read_csv('Under 75 mortality rate from heart disease.csv')
df34302= pd.read_csv('Under 75 mortality rate from stroke.csv')
df34663= pd.read_csv('Health related quality of life for older people.csv')
df35024= pd.read_csv('Rheumatoid Arthritis: QOF prevalence (16+ yrs).csv')
df35385= pd.read_csv('New STI diagnoses (excluding chlamydia aged under 25) per 100,000.csv')
df35746= pd.read_csv('STI testing rate (exclude chlamydia aged under 25) per 100,000.csv')
df36107= pd.read_csv('STI testing positivity (excluding chlamydia aged under 25).csv')
df36468= pd.read_csv('TB incidence (three year average).csv')
df36829= pd.read_csv('Proportion of drug sensitive TB cases who had completed a full course of treatment by 12 months.csv')
df37190= pd.read_csv('Alcohol-specific mortality.csv')
df37551= pd.read_csv('Mortality from chronic liver disease.csv')
df37912= pd.read_csv('Under 18s births rate per 1,000.csv')
df38273= pd.read_csv('Percentage with a mean daily sedentary time in the last week over 7 hours per day at age 15.csv')
df38634= pd.read_csv('Percentage physically active for at least one hour per day seven days a week at age 15.csv')
df38995= pd.read_csv('Chlamydia detection rate per 100,000 aged 15 to 24.csv')
df39356= pd.read_csv('Chlamydia diagnostic rate per 100,000.csv')
df39717= pd.read_csv('Chlamydia diagnostic rate per 100,000 aged 25 years and older.csv')
df40078= pd.read_csv('All new STI diagnoses rate per 100,000.csv')
df40439= pd.read_csv('HIV testing coverage, total.csv')
df40800= pd.read_csv('Smoking prevalence in adults (15+) - current smokers (QOF).csv')
df41161= pd.read_csv('Cancer screening coverage: bowel cancer.csv')
df41522= pd.read_csv('Premature births (less than 37 weeks gestation).csv')
df41883= pd.read_csv('New HIV diagnosis rate per 100,000.csv')
df42244= pd.read_csv('GP prescribed LARC excluding injections rate per 1,000.csv')
df42605= pd.read_csv('Deprivation score (IMD 2015).csv')
df42966= pd.read_csv('Reception: Prevalence of obesity (including severe obesity), 5-years data combined.csv')
df43327= pd.read_csv('Year 6: Prevalence of obesity (including severe obesity), 5-years data combined.csv')
df43688= pd.read_csv('Infant mortality rate.csv')
df44049= pd.read_csv('Educational attainment (5 or more GCSEs): % of all children.csv')
df44410= pd.read_csv('Total prescribed LARC excluding injections rate per 1,000.csv')
df44771= pd.read_csv('SRH Services prescribed LARC excluding injections rate per 1,000.csv')
df45132= pd.read_csv('Women choose injections at SRH Services (%).csv')
df45493= pd.read_csv('Women choose user-dependent methods at SRH Services (%).csv')
df45854= pd.read_csv('Women choose hormonal short-acting contraceptives at SRH Services (%).csv')
df46215= pd.read_csv('Under 25s choose LARC excluding injections at SRH Services (%).csv')
df46576= pd.read_csv('Over 25s  choose LARC excluding injections at SRH Services (%).csv')
df46937= pd.read_csv('Emergency hospital admissions for COPD.csv')
df47298= pd.read_csv('Smoking prevalence in adults (18+) - current smokers (GPPS).csv')
df47659= pd.read_csv('Smoking prevalence in adults (18+) - ex smoker (GPPS).csv')
df48020= pd.read_csv('Smoking prevalence in adults (18+) - never smoked (GPPS).csv')
df48381= pd.read_csv('Supporting information - % population aged under 18.csv')
df48742= pd.read_csv('Supporting information - % population aged 65+.csv')
df49103= pd.read_csv('Percentage of people in employment.csv')
df49464= pd.read_csv('Abdominal Aortic Aneurysm Screening Coverage.csv')
df49825= pd.read_csv('Incidence rate of alcohol-related cancer.csv')
df50186= pd.read_csv('Mortality rate from a range of specified communicable diseases, including influenza.csv')
df50547= pd.read_csv('Deaths from drug misuse.csv')
df50908= pd.read_csv('Smoking Prevalence in adults (18+) - current smokers (APS).csv')
df51269= pd.read_csv('Smoking prevalence in adults in routine and manual occupations (18-64) - current smokers (APS).csv')
df51630= pd.read_csv('0.csv')
df51991= pd.read_csv('Reception: Prevalence of overweight.csv')
df52352= pd.read_csv('Year 6: Prevalence of overweight.csv')
df52713= pd.read_csv('Mortality rate from causes considered preventable (2016 definition).csv')
df53074= pd.read_csv('Care home beds per 100 people 75+.csv')
df53435= pd.read_csv('Nursing home beds per 100 people 75+.csv')
df53796= pd.read_csv('Smoking Prevalence in adults (18+) - ex smokers (APS).csv')
df54157= pd.read_csv('Smoking Prevalence in adults (18+) - never smoked (APS).csv')
df54518= pd.read_csv('Crime deprivation: score.csv')
df54879= pd.read_csv('Adjusted antibiotic prescribing in primary care by the NHS.csv')
df55240= pd.read_csv('Resident population.csv')
df55601= pd.read_csv('Mortality rate from all cardiovascular diseases, ages 65+ years.csv')
df55962= pd.read_csv('Mortality rate from cancer, ages 65+ years.csv')
df56323= pd.read_csv('Mortality rate from respiratory disease, ages 65+ years.csv')
df56684= pd.read_csv('Volume of pure alcohol sold through the off-trade: all alcohol sales.csv')
df57045= pd.read_csv('Volume of pure alcohol sold through the off-trade: beer sales.csv')
df57406= pd.read_csv('Volume of pure alcohol sold through the off-trade: wine sales.csv')
df57767= pd.read_csv('Volume of pure alcohol sold through the off-trade: spirit sales.csv')
df58128= pd.read_csv('Number of premises licensed to sell alcohol per square kilometre.csv')
df58489= pd.read_csv('Typhoid & paratyphoid incidence rateper100,000.csv')
df58850= pd.read_csv('Supporting information - % population from ethnic minorities.csv')
df59211= pd.read_csv('Economic inactivity rate.csv')
df59572= pd.read_csv('Inequality in life expectancy at birth.csv')
df59933= pd.read_csv('Admission episodes for alcohol-specific conditions - Under 18s.csv')
df60294= pd.read_csv('Admission episodes for alcohol-specific conditions.csv')
df60655= pd.read_csv('Air pollution: fine particulate matter (historic indicator).csv')
df61016= pd.read_csv('Density of fast food outlets.csv')
df61377= pd.read_csv('Estimated dementia diagnosis rate (aged 65 and over).csv')
df61738= pd.read_csv('Mortality rate from oral cancer.csv')
df62099= pd.read_csv('Percentage of physically active adults.csv')
df62460= pd.read_csv('Percentage of physically inactive adults.csv')
df62821= pd.read_csv('Access to Healthy Assets & Hazards Index.csv')
df63182= pd.read_csv('Proportion of the population meeting the recommended 5-a-day on a usual day (adults).csv')
df63543= pd.read_csv('Percentage of the total resident population who are 65 and over.csv')
df63904= pd.read_csv('Percentage of the total resident population who are 25 to 64 years of age.csv')
df64265= pd.read_csv('Percentage of the total resident population who are 16 to 24 years of age.csv')
df64626= pd.read_csv('Percentage of the total resident population who are 0 to 15 years of age.csv')
df64987= pd.read_csv('Smoking status at time of delivery.csv')
df65348= pd.read_csv('Back pain prevalence in people of all ages.csv')
df65709= pd.read_csv('Percentage of population whose ethnicity is not White UK.csv')
df66070= pd.read_csv('Percentage of adults (aged 18+) classified as overweight or obese.csv')
df66431= pd.read_csv('General fertility rate: live births per 1,000 women aged 15-44 years. five year pooled.csv')
df66792= pd.read_csv('Prevalence of severe hip osteoarthritis in people aged  45 and over.csv')
df67153= pd.read_csv('Low birth weight of live babies, five year pooled.csv')
df67514= pd.read_csv('Prevalence of hip osteoarthritis in people aged  45 and over.csv')
df67875= pd.read_csv('Child Poverty, Income deprivation affecting children index (IDACI).csv')
df68236= pd.read_csv('Prevalence of severe knee osteoarthritis in people aged  45 and over.csv')
df68597= pd.read_csv('Prevalence of knee osteoarthritis in people aged  45 and over.csv')
df68958= pd.read_csv('Unemployment (Percentage of the working age population claiming out of work benefit).csv')
df69319= pd.read_csv('Long-Term Unemployment- rate per 1,000 working age population.csv')
df69680= pd.read_csv('Older people living alone, % of people aged 65 and over who are living alone.csv')
df70041= pd.read_csv('Employment and Support Allowance claimants.csv')
df70402= pd.read_csv('Reception: Prevalence of obesity (including severe obesity), 3-years data combined.csv')
df70763= pd.read_csv('Reception: Prevalence of overweight (including obesity), 3-years data combined.csv')
df71124= pd.read_csv('Year 6: Prevalence of obesity (including severe obesity), 3-years data combined.csv')
df71485= pd.read_csv('Year 6: Prevalence of overweight (including obesity), 3-years data combined.csv')
df71846= pd.read_csv('Affordability of home ownership.csv')
df72207= pd.read_csv('Deliveries to teenage mothers.csv')
df72568= pd.read_csv('Emergency hospital admissions for injuries in under 5 years old, crude rate.csv')
df72929= pd.read_csv('Emergency hospital admissions in under 5 years old, crude rate.csv')
df73290= pd.read_csv('Measles incidence rateper100,000.csv')
df73651= pd.read_csv('Measles 5-year incidence rateper100,000.csv')
df74012= pd.read_csv('Acute hepatitis B incidence rateper100,000.csv')
df74373= pd.read_csv('Hepatitis C detection rateper100,000.csv')
df74734= pd.read_csv('Inequality in life expectancy at 65.csv')
df75095= pd.read_csv('Reception: Prevalence of severe obesity.csv')
df75456= pd.read_csv('Year 6: Prevalence of severe obesity.csv')
df75817= pd.read_csv('Emergency hospital admissions for injuries in under 15 years old, crude rate.csv')
df76178= pd.read_csv('Emergency hospital admissions for injuries in 15 to 24 years old, crude rate.csv')
df76539= pd.read_csv('Percentage of the total resident population aged 85 and over.csv')
df76900= pd.read_csv('Emergency hospital admissions for all causes, all ages, standardised admission ratio.csv')
df77261= pd.read_csv('Emergency hospital admissions for coronary heart disease, standardised admission ratio.csv')
df77622= pd.read_csv('Emergency hospital admissions for stroke, standardised admission ratio.csv')
df77983= pd.read_csv('Emergency hospital admissions for Myocardial Infarction (heart attack), standardised admission ratio.csv')
df78344= pd.read_csv('Emergency hospital admissions for Chronic Obstructive Pulmonary Disease (COPD), standardised admission ratio.csv')
df78705= pd.read_csv('Incidence of all cancers, standardised incidence ratio.csv')
df79066= pd.read_csv('Incidence of breast cancer, standardised incidence ratio.csv')
df79427= pd.read_csv('Incidence of colorectal cancer, standardised incidence ratio.csv')
df79788= pd.read_csv('Incidence of lung cancer, standardised incidence ratio.csv')
df80149= pd.read_csv('Incidence of prostate cancer, standardised incidence ratio.csv')
df80510= pd.read_csv('Emergency hospital admissions for intentional self harm, standardised admission ratio.csv')
df80871= pd.read_csv('Hospital admissions for alcohol attributable conditions, (Narrow definition).csv')
df81232= pd.read_csv('Emergency hospital admissions for hip fracture in persons 65 years and over, standardised admission ratio.csv')
df81593= pd.read_csv('Deaths from all causes, all ages, standardised mortality ratio.csv')
df81954= pd.read_csv('Deaths from all causes, under 75 years, standardised mortality ratio.csv')
df82315= pd.read_csv('Deaths from all cancer, all ages, standardised mortality ratio.csv')
df82676= pd.read_csv('Deaths from all cancer, under 75 years, standardised mortality ratio (SMR).csv')
df83037= pd.read_csv('Deaths from circulatory disease, all ages, standardised mortality ratio.csv')
df83398= pd.read_csv('Deaths from circulatory disease, under 75 years, standardised mortality ratio.csv')
df83759= pd.read_csv('Deaths from coronary heart disease, all ages, standardised mortality ratio.csv')
df84120= pd.read_csv('Deaths from stroke, all ages, standardised mortality ratio.csv')
df84481= pd.read_csv('Deaths from respiratory diseases, all ages, standardised mortality ratio.csv')
df84842= pd.read_csv('Percentage of population whose ethnic group is not white.csv')
df85203= pd.read_csv('Income deprivation, English Indices of Deprivation.csv')
df85564= pd.read_csv('The percentage of people that cannot speak English well or at all,  2011.csv')
df85925= pd.read_csv('Index of Multiple Deprivation (IMD) Score.csv')
df86286= pd.read_csv('Percentage of people who reported having a limiting long term illness or disability.csv')
df86647= pd.read_csv('Households with overcrowding based on overall room occupancy levels.csv')
df87008= pd.read_csv('Older people in poverty: Income deprivation affecting older people Index (IDAOPI).csv')
df87369= pd.read_csv('Modelled estimates of the proportion of households in fuel poverty (%).csv')
df87730= pd.read_csv('Life expectancy at birth, (upper age band 90 and over).csv')
df88091= pd.read_csv('Under 25s individuals attend specialist contraceptive services rate per 1000 - Females.csv')
df88452= pd.read_csv('Under 25s individuals attend specialist contraceptive services rate per 1000 - Males.csv')
df88813= pd.read_csv('STEC  (Shiga toxin-producing Escherichia coli) serogroup O157 5-year incidence rateper100,000.csv')
df89174= pd.read_csv('STEC (Shiga toxin-producing Escherichia coli) serogroup O157 incidence rateper100,000.csv')
df89535= pd.read_csv('Estimated diabetes diagnosis rate.csv')
df89896= pd.read_csv('Gender pay gap (by workplace location).csv')
df90257= pd.read_csv('Average weekly earnings.csv')
df90618= pd.read_csv('Job density.csv')
df90979= pd.read_csv('Non-typhoidal Salmonella incidence rateper100,000.csv')
df91340= pd.read_csv('Campylobacter incidence rateper100,000.csv')
df91701= pd.read_csv('Shigella incidence rateper100,000.csv')
df92062= pd.read_csv('% reporting a long term MSK problem who also report depression or anxiety.csv')
df92423= pd.read_csv('Average health related quality of life score for adults who reported having a long term MSK problem..csv')
df92784= pd.read_csv('% reporting depression or anxiety.csv')
df93145= pd.read_csv('Percentage reporting a long-term Musculoskeletal (MSK) problem.csv')
df93506= pd.read_csv('Average Attainment 8 score.csv')
df93867= pd.read_csv('Giardia incidence rateper100,000.csv')
df94228= pd.read_csv('Cryptosporidium incidence rateper100,000.csv')
df94589= pd.read_csv('Odds of current smoking (self-reported) among adults aged 18-64 with a routine and manual occupation (APS).csv')
df94950= pd.read_csv('Oesophageal cancer registrations.csv')
df95311= pd.read_csv('Percentage of adults walking for travel at least three days per week.csv')
df95672= pd.read_csv('Percentage of adults cycling for travel at least three days per week.csv')
df96033= pd.read_csv('Percentage reporting at least two long-term conditions, at least one of which is MSK related.csv')
df96394= pd.read_csv('Smoking prevalence in adults with a long term mental health condition (18+) - current smokers (GPPS).csv')
df96755= pd.read_csv('Smoking prevalence in adults with anxiety or depression (18+) - current smokers (GPPS).csv')
df97116= pd.read_csv('Listeria incidence rateper100,000.csv')
df97477= pd.read_csv('Scarlet fever notification rateper100,000 aged 0-9 yrs.csv')
df97838= pd.read_csv('Hospital admissions for alcohol attributable conditions, (Broad definition).csv')
df98199= pd.read_csv('Mumps incidence rateper100,000.csv')
df98560= pd.read_csv('Mumps 5-year incidence rateper100,000.csv')
df98921= pd.read_csv('Percentage of deaths that occur in hospital.csv')
df99282= pd.read_csv('Percentage of deaths that occur in care homes.csv')
df99643= pd.read_csv('Percentage of deaths that occur at home.csv')
df100004= pd.read_csv('Percentage of deaths that occur in other places.csv')
df100365= pd.read_csv('Percentage of deaths that occur in hospice.csv')
df100726= pd.read_csv('Deaths from causes considered preventable, under 75 years, standardised mortality ratio.csv')
df101087= pd.read_csv('Smoking prevalence at age 15 - regular smokers (modelled estimates).csv')
df101448= pd.read_csv('Smoking prevalence at age 15 - regular or occasional smokers (modelled estimates).csv')
df101809= pd.read_csv('Listeria 5-year incidence rateper100,000.csv')
df102170= pd.read_csv('Estimated prevalence of common mental disorders: % of population aged 16 & over.csv')
df102531= pd.read_csv('Estimated prevalence of common mental disorders: % of population aged 65 & over.csv')
df102892= pd.read_csv('Percentage of deaths with underlying cause Cancer.csv')
df103253= pd.read_csv('Percentage of deaths with underlying cause respiratory disease.csv')
df103614= pd.read_csv('Percentage of deaths with underlying cause circulatory disease.csv')
df103975= pd.read_csv('Percentage of all Deaths.csv')
df104336= pd.read_csv('Mortality Rate.csv')
df104697= pd.read_csv('Re-offending levels - percentage of offenders who re-offend.csv')
df105058= pd.read_csv('Pertussis incidence rateper100,000.csv')
df105419= pd.read_csv('Prompt antiretroviral therapy (ART) initiation in people newly diagnosed with HIV.csv')
df105780= pd.read_csv('Virological success in adults accessing HIV care.csv')
df106141= pd.read_csv('Repeat HIV testing in gay, bisexual and other men who have sex with men.csv')
df106502= pd.read_csv('Deprivation score (IMD 2019).csv')
df106863= pd.read_csv('Cancer screening coverage: cervical cancer (aged 25 to 49 years old).csv')
df107224= pd.read_csv('Cancer screening coverage: cervical cancer (aged 50 to 64 years old).csv')
df107585= pd.read_csv('Percentage of 5 year olds with experience of visually obvious dental decay.csv')
df107946= pd.read_csv('Percentage of physically active children and young people.csv')
df108307= pd.read_csv('Re-offending levels - average number of re-offences per re-offender.csv')
df108668= pd.read_csv('Babys first feed breastmilk.csv')
df109029= pd.read_csv('Invasive Meningococcal Disease (IMD) confirmed cases rateper100,000.csv')
df109390= pd.read_csv('Mortality rate from asthma.csv')
df109751= pd.read_csv('Odds of current smoking (self-reported) among adults aged 18+ diagnosed with a long-term mental health condition.csv')
df110112= pd.read_csv('Percentage of cancers diagnosed at stages 1 and 2.csv')
df110473= pd.read_csv('Population vaccination coverage: Flu (primary school aged children).csv')
df110834= pd.read_csv('Children in relative low income families (under 16s).csv')
df111195= pd.read_csv('Children in absolute low income families (under 16s).csv')
df111556= pd.read_csv('Under 75 mortality rate from liver disease considered preventable (2019 definition).csv')
df111917= pd.read_csv('Under 75 mortality rate from causes considered preventable (2019 definition).csv')
df112278= pd.read_csv('Under 75 mortality rate from cardiovascular diseases considered preventable (2019 definition).csv')
df112639= pd.read_csv('Under 75 mortality rate from cancer considered preventable (2019 definition).csv')
df113000= pd.read_csv('Under 75 mortality rate from respiratory disease considered preventable (2019 definition).csv')
df113361= pd.read_csv('Homelessness - households in temporary accommodation.csv')
df113722= pd.read_csv('Homelessness - households owed a duty under the Homelessness Reduction Act.csv')
df114083= pd.read_csv('Homelessness - households owed a duty under the Homelessness Reduction Act (main applicant 16-24 yrs).csv')
df114444= pd.read_csv('Homelessness - households owed a duty under the Homelessness Reduction Act (main applicant 55+ yrs).csv')
df114805= pd.read_csv('Homelessness - households with dependent children owed a duty under the Homelessness Reduction Act.csv')
df115166= pd.read_csv('Odds ratio of reporting a mental health condition among people with and without an MSK condition.csv')
df115527= pd.read_csv('Percentage of the total resident population who are 0 to 4 years of age.csv')
df115888= pd.read_csv('Percentage of the total resident population who are 5 to 15 years of age.csv')
df116249= pd.read_csv('Percentage of the total resident population who are 50 to 64 years of age.csv')
df116610= pd.read_csv('Population density, people per square kilometre.csv')
df116971= pd.read_csv('Smoking attributable mortality (new method).csv')
df117332= pd.read_csv('Smoking attributable deaths from heart disease (new method).csv')
df117693= pd.read_csv('Smoking attributable deaths from stroke (new method).csv')
df118054= pd.read_csv('Smoking attributable hospital admissions (new method). This indicator uses new set of attributable fractions, and so differ from that originally published..csv')
df118415= pd.read_csv('Killed and seriously injured (KSI) casualties on Englands roads.csv')
df118776= pd.read_csv('Loneliness: Percentage of adults who feel lonely often per always or some of the time.csv')
df119137= pd.read_csv('Fuel poverty (low income, low energy efficiency methodology).csv')
df119498= pd.read_csv('Mycoplasma genitalium diagnostic rate per 100,000.csv')
df119859= pd.read_csv('Trichomoniasis diagnostic rate per 100,000.csv')
df120220= pd.read_csv('Alcohol-related mortality: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv')
df120581= pd.read_csv('Admission episodes for alcohol-related conditions (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv')
df120942= pd.read_csv('Admission episodes for alcohol-related conditions (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv')
df121303= pd.read_csv('Admission episodes for alcohol-related unintentional injuries (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv')
df121664= pd.read_csv('Admission episodes for mental and behavioural disorders due to use of alcohol (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv')
df122025= pd.read_csv('Admission episodes for intentional self-poisoning by and exposure to alcohol (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv')
df122386= pd.read_csv('Admission episodes for alcohol-related cardiovascular disease (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv')
df122747= pd.read_csv('Admission episodes for mental and behavioural disorders due to use of alcohol (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv')
df123108= pd.read_csv('Admission episodes for alcoholic liver disease (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv')
df123469= pd.read_csv('Admission episodes for alcohol-related conditions (Narrow) - Under 40s: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv')
df123830= pd.read_csv('Admission episodes for alcohol-related conditions (Narrow)40 to 64 years: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv')
df124191= pd.read_csv('Admission episodes for alcohol-related conditions (Narrow)65+ years: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv')
df124552= pd.read_csv('HIV diagnosed prevalence rate per 1,000.csv')
df124913= pd.read_csv('New HIV diagnoses among persons first diagnosed in the UK rate per 100,000.csv')
df125274= pd.read_csv('Antiretroviral therapy (ART) coverage in people accessing HIV care.csv')
df125635= pd.read_csv('Mortality rate from all causes, all ages.csv')
df125996= pd.read_csv('Mortality rate for deaths involving COVID-19, all ages.csv')
df126357= pd.read_csv('Mortality rate for deaths involving COVID-19, under 75s.csv')
df126718= pd.read_csv('Fraction of mortality attributable to particulate air pollution (new method).csv')
df127079= pd.read_csv('Acute Lyme disease laboratory confirmed incidence rateper100,000.csv')
df127440= pd.read_csv('Average Attainment 8 Score among children eligible for Free School Meals (FSM).csv')
df127801= pd.read_csv('Air pollution: fine particulate matter (new method - concentrations of total PM2.5).csv')
df128162= pd.read_csv('Potential years of life lost (PYLL) due to alcohol-related conditions.csv')
df128523= pd.read_csv('Percentage of adults (aged 18+) classified as obese.csv')
df128884= pd.read_csv('The percentage of the population with a physical or mental long term health condition in employment (aged 16 to 64).csv')
df129245= pd.read_csv('The percentage of the population who are in receipt of long term support for a learning disability that are in paid employment (aged 18 to 64).csv')
df129606= pd.read_csv('Initiation or continuation of PrEP among those with PrEP need.csv')
df129967= pd.read_csv('Determining PrEP need.csv')

# %% [markdown]
# Step 12: removing the indicator column by renaming the value column as the indicator name

# %%
df8=df7.rename(columns={'Value': 'Under 75 mortality rate from all causes'})
df369=df368.rename(columns={'Value': 'Stroke: QOF prevalence (all ages)'})
df730=df729.rename(columns={'Value': 'Hypertension: QOF prevalence (all ages)'})
df1091=df1090.rename(columns={'Value': 'CHD: QOF prevalence (all ages)'})
df1452=df1451.rename(columns={'Value': 'Depression: QOF prevalence (18+ yrs)'})
df1813=df1812.rename(columns={'Value': 'Mortality rate from lung cancer'})
df2174=df2173.rename(columns={'Value': 'Mortality rate from chronic obstructive pulmonary disease'})
df2535=df2534.rename(columns={'Value': 'Lung cancer registrations'})
df2896=df2895.rename(columns={'Value': 'Oral cancer registrations'})
df3257=df3256.rename(columns={'Value': 'Cost per capita of smoking attributable hospital admissions'})
df3618=df3617.rename(columns={'Value': 'Percentage people living in 20% most deprived areas in England'})
df3979=df3978.rename(columns={'Value': 'Children in low income families (under 16s)'})
df4340=df4339.rename(columns={'Value': 'Pupil absence'})
df4701=df4700.rename(columns={'Value': 'Killed and seriously injured (KSI) casualties on Englands roads (historic data)'})
df5062=df5061.rename(columns={'Value': 'Violent crime - hospital admissions for violence (including sexual violence)'})
df5423=df5422.rename(columns={'Value': 'Violent crime - violence offences per 1,000 population'})
df5784=df5783.rename(columns={'Value': 'The rate of complaints about noise'})
df6145=df6144.rename(columns={'Value': 'Statutory homelessness: rate per 1,000 households'})
df6506=df6505.rename(columns={'Value': 'Utilisation of outdoor space for exercise or health reasons'})
df6867=df6866.rename(columns={'Value': 'Low birth weight of term babies'})
df7228=df7227.rename(columns={'Value': 'Under 18s conception rate per 1,000'})
df7589=df7588.rename(columns={'Value': 'Reception: Prevalence of overweight (including obesity)'})
df7950=df7949.rename(columns={'Value': 'Year 6: Prevalence of overweight (including obesity)'})
df8311=df8310.rename(columns={'Value': 'Emergency Hospital Admissions for Intentional Self-Harm'})
df8672=df8671.rename(columns={'Value': 'Cancer screening coverage: breast cancer'})
df9033=df9032.rename(columns={'Value': 'Emergency hospital admissions due to falls in people aged 65 and over'})
df9394=df9393.rename(columns={'Value': 'Emergency hospital admissions due to falls in people aged 65-79'})
df9755=df9754.rename(columns={'Value': 'Emergency hospital admissions due to falls in people aged 80+'})
df10116=df10115.rename(columns={'Value': 'Fraction of mortality attributable to particulate air pollution (old method)'})
df10477=df10476.rename(columns={'Value': 'Under 75 mortality rate from all cardiovascular diseases'})
df10838=df10837.rename(columns={'Value': 'Under 75 mortality rate from cancer'})
df11199=df11198.rename(columns={'Value': 'Under 75 mortality rate from liver disease'})
df11560=df11559.rename(columns={'Value': 'Under 75 mortality rate from respiratory disease'})
df11921=df11920.rename(columns={'Value': 'Suicide rate'})
df12282=df12281.rename(columns={'Value': 'Emergency readmissions within 30 days of discharge from hospital'})
df12643=df12642.rename(columns={'Value': 'Hip fractures in people aged 65 and over'})
df13004=df13003.rename(columns={'Value': 'Hip fractures in people aged 65-79'})
df13365=df13364.rename(columns={'Value': 'Hip fractures in people aged 80+'})
df13726=df13725.rename(columns={'Value': 'Gap in the employment rate between those with a physical or mental long term health condition (aged 16 to 64) and the overall employment rate'})
df14087=df14086.rename(columns={'Value': 'Hospital admissions caused by unintentional and deliberate injuries in children (aged 0-14 years)'})
df14448=df14447.rename(columns={'Value': 'Hospital admissions caused by unintentional and deliberate injuries in young people (aged 15-24 years)'})
df14809=df14808.rename(columns={'Value': 'Sickness absence - the percentage of employees who had at least one day off in the previous week'})
df15170=df15169.rename(columns={'Value': 'Sickness absence - the percentage of working days lost due to sickness absence'})
df15531=df15530.rename(columns={'Value': 'Participation rate: Reception'})
df15892=df15891.rename(columns={'Value': 'Participation rate: Year 6'})
df16253=df16252.rename(columns={'Value': 'Participation rate: Total'})
df16614=df16613.rename(columns={'Value': 'Records with valid ethnicity code'})
df16975=df16974.rename(columns={'Value': 'Records with valid child postcode'})
df17336=df17335.rename(columns={'Value': 'Records with height rounded to X.0 or X.5'})
df17697=df17696.rename(columns={'Value': 'Records with weight rounded to X.0 or X.5'})
df18058=df18057.rename(columns={'Value': 'Reception: Prevalence of underweight'})
df18419=df18418.rename(columns={'Value': 'Reception: Prevalence of healthy weight'})
df18780=df18779.rename(columns={'Value': 'Reception: Prevalence of obesity (including severe obesity)'})
df19141=df19140.rename(columns={'Value': 'Year 6: Prevalence of underweight'})
df19502=df19501.rename(columns={'Value': 'Year 6: Prevalence of healthy weight'})
df19863=df19862.rename(columns={'Value': 'Year 6: Prevalence of obesity (including severe obesity)'})
df20224=df20223.rename(columns={'Value': 'Fuel poverty (low income, high cost methodology)'})
df20585=df20584.rename(columns={'Value': 'Excess winter deaths index'})
df20946=df20945.rename(columns={'Value': 'Excess winter deaths index (age 85+)'})
df21307=df21306.rename(columns={'Value': 'Life expectancy at birth'})
df21668=df21667.rename(columns={'Value': 'New cases of psychosis: estimated incidence rate per 100,000 population aged 16-64'})
df22029=df22028.rename(columns={'Value': 'Unpaid carers'})
df22390=df22389.rename(columns={'Value': 'Overcrowded households'})
df22751=df22750.rename(columns={'Value': 'Osteoporosis: QOF prevalence (50+ yrs)'})
df23112=df23111.rename(columns={'Value': 'Children in low income families (all dependent children under 20)'})
df23473=df23472.rename(columns={'Value': 'Violent crime - sexual offences per 1,000 population'})
df23834=df23833.rename(columns={'Value': 'Migrant GP registrations: rate per 1,000 population'})
df24195=df24194.rename(columns={'Value': 'Genital warts diagnostic rate per 100,000'})
df24556=df24555.rename(columns={'Value': 'Under 18s conceptions leading to abortion (%)'})
df24917=df24916.rename(columns={'Value': 'Pelvic inflammatory disease (PID) admissions rate per 100,000'})
df25278=df25277.rename(columns={'Value': 'Ectopic pregnancy admissions rate per 100,000'})
df25639=df25638.rename(columns={'Value': 'Syphilis diagnostic rate per 100,000'})
df26000=df25999.rename(columns={'Value': 'Gonorrhoea diagnostic rate per 100,000'})
df26361=df26360.rename(columns={'Value': 'Chlamydia detection rate per 100,000 aged 15 to 24'})
df26722=df26721.rename(columns={'Value': 'Chlamydia proportion aged 15 to 24 screened'})
df27083=df27082.rename(columns={'Value': 'HIV diagnosed prevalence rate per 1,000 aged 15 to 59'})
df27444=df27443.rename(columns={'Value': 'HIV late diagnosis in people first diagnosed with HIV in the UK'})
df27805=df27804.rename(columns={'Value': 'Children killed and seriously injured (KSI) on Englands roads'})
df28166=df28165.rename(columns={'Value': 'Hospital admissions caused by unintentional and deliberate injuries in children (aged 0-4 years)'})
df28527=df28526.rename(columns={'Value': 'The percentage of people resident in the area living in each national deprivation quintile'})
df28888=df28887.rename(columns={'Value': 'Hospital admission rate due to liver disease'})
df29249=df29248.rename(columns={'Value': 'Genital herpes diagnosis rate per 100,000'})
df29610=df29609.rename(columns={'Value': 'HIV testing coverage, women'})
df29971=df29970.rename(columns={'Value': 'HIV testing coverage, gay, bisexual and other men who have sex with men'})
df30332=df30331.rename(columns={'Value': 'HIV testing coverage, men'})
df30693=df30692.rename(columns={'Value': 'Life expectancy at 65'})
df31054=df31053.rename(columns={'Value': 'Unemployment (model-based)'})
df31415=df31414.rename(columns={'Value': 'Long term claimants of Jobseekers Allowance'})
df31776=df31775.rename(columns={'Value': 'Young people providing 20+ hoursperweek of unpaid care (aged 16-24)'})
df32137=df32136.rename(columns={'Value': 'Children providing unpaid care (aged 0-15)'})
df32498=df32497.rename(columns={'Value': 'Young people providing unpaid care (aged 16-24)'})
df32859=df32858.rename(columns={'Value': 'Under 75 mortality rate from colorectal cancer'})
df33220=df33219.rename(columns={'Value': 'Under 75 mortality rate from breast cancer'})
df33581=df33580.rename(columns={'Value': 'Under 75 mortality rate from injuries'})
df33942=df33941.rename(columns={'Value': 'Under 75 mortality rate from heart disease'})
df34303=df34302.rename(columns={'Value': 'Under 75 mortality rate from stroke'})
df34664=df34663.rename(columns={'Value': 'Health related quality of life for older people'})
df35025=df35024.rename(columns={'Value': 'Rheumatoid Arthritis: QOF prevalence (16+ yrs)'})
df35386=df35385.rename(columns={'Value': 'New STI diagnoses (excluding chlamydia aged under 25) per 100,000'})
df35747=df35746.rename(columns={'Value': 'STI testing rate (exclude chlamydia aged under 25) per 100,000'})
df36108=df36107.rename(columns={'Value': 'STI testing positivity (excluding chlamydia aged under 25)'})
df36469=df36468.rename(columns={'Value': 'TB incidence (three year average)'})
df36830=df36829.rename(columns={'Value': 'Proportion of drug sensitive TB cases who had completed a full course of treatment by 12 months'})
df37191=df37190.rename(columns={'Value': 'Alcohol-specific mortality'})
df37552=df37551.rename(columns={'Value': 'Mortality from chronic liver disease'})
df37913=df37912.rename(columns={'Value': 'Under 18s births rate per 1,000'})
df38274=df38273.rename(columns={'Value': 'Percentage with a mean daily sedentary time in the last week over 7 hours per day at age 15'})
df38635=df38634.rename(columns={'Value': 'Percentage physically active for at least one hour per day seven days a week at age 15'})
df38996=df38995.rename(columns={'Value': 'Chlamydia detection rate per 100,000 aged 15 to 24'})
df39357=df39356.rename(columns={'Value': 'Chlamydia diagnostic rate per 100,000'})
df39718=df39717.rename(columns={'Value': 'Chlamydia diagnostic rate per 100,000 aged 25 years and older'})
df40079=df40078.rename(columns={'Value': 'All new STI diagnoses rate per 100,000'})
df40440=df40439.rename(columns={'Value': 'HIV testing coverage, total'})
df40801=df40800.rename(columns={'Value': 'Smoking prevalence in adults (15+) - current smokers (QOF)'})
df41162=df41161.rename(columns={'Value': 'Cancer screening coverage: bowel cancer'})
df41523=df41522.rename(columns={'Value': 'Premature births (less than 37 weeks gestation)'})
df41884=df41883.rename(columns={'Value': 'New HIV diagnosis rate per 100,000'})
df42245=df42244.rename(columns={'Value': 'GP prescribed LARC excluding injections rate per 1,000'})
df42606=df42605.rename(columns={'Value': 'Deprivation score (IMD 2015)'})
df42967=df42966.rename(columns={'Value': 'Reception: Prevalence of obesity (including severe obesity), 5-years data combined'})
df43328=df43327.rename(columns={'Value': 'Year 6: Prevalence of obesity (including severe obesity), 5-years data combined'})
df43689=df43688.rename(columns={'Value': 'Infant mortality rate'})
df44050=df44049.rename(columns={'Value': 'Educational attainment (5 or more GCSEs): % of all children'})
df44411=df44410.rename(columns={'Value': 'Total prescribed LARC excluding injections rate per 1,000'})
df44772=df44771.rename(columns={'Value': 'SRH Services prescribed LARC excluding injections rate per 1,000'})
df45133=df45132.rename(columns={'Value': 'Women choose injections at SRH Services (%)'})
df45494=df45493.rename(columns={'Value': 'Women choose user-dependent methods at SRH Services (%)'})
df45855=df45854.rename(columns={'Value': 'Women choose hormonal short-acting contraceptives at SRH Services (%)'})
df46216=df46215.rename(columns={'Value': 'Under 25s choose LARC excluding injections at SRH Services (%)'})
df46577=df46576.rename(columns={'Value': 'Over 25s  choose LARC excluding injections at SRH Services (%)'})
df46938=df46937.rename(columns={'Value': 'Emergency hospital admissions for COPD'})
df47299=df47298.rename(columns={'Value': 'Smoking prevalence in adults (18+) - current smokers (GPPS)'})
df47660=df47659.rename(columns={'Value': 'Smoking prevalence in adults (18+) - ex smoker (GPPS)'})
df48021=df48020.rename(columns={'Value': 'Smoking prevalence in adults (18+) - never smoked (GPPS)'})
df48382=df48381.rename(columns={'Value': 'Supporting information - % population aged under 18'})
df48743=df48742.rename(columns={'Value': 'Supporting information - % population aged 65+'})
df49104=df49103.rename(columns={'Value': 'Percentage of people in employment'})
df49465=df49464.rename(columns={'Value': 'Abdominal Aortic Aneurysm Screening Coverage'})
df49826=df49825.rename(columns={'Value': 'Incidence rate of alcohol-related cancer'})
df50187=df50186.rename(columns={'Value': 'Mortality rate from a range of specified communicable diseases, including influenza'})
df50548=df50547.rename(columns={'Value': 'Deaths from drug misuse'})
df50909=df50908.rename(columns={'Value': 'Smoking Prevalence in adults (18+) - current smokers (APS)'})
df51270=df51269.rename(columns={'Value': 'Smoking prevalence in adults in routine and manual occupations (18-64) - current smokers (APS)'})
df51631=df51630.rename(columns={'Value': '0'})
df51992=df51991.rename(columns={'Value': 'Reception: Prevalence of overweight'})
df52353=df52352.rename(columns={'Value': 'Year 6: Prevalence of overweight'})
df52714=df52713.rename(columns={'Value': 'Mortality rate from causes considered preventable (2016 definition)'})
df53075=df53074.rename(columns={'Value': 'Care home beds per 100 people 75+'})
df53436=df53435.rename(columns={'Value': 'Nursing home beds per 100 people 75+'})
df53797=df53796.rename(columns={'Value': 'Smoking Prevalence in adults (18+) - ex smokers (APS)'})
df54158=df54157.rename(columns={'Value': 'Smoking Prevalence in adults (18+) - never smoked (APS)'})
df54519=df54518.rename(columns={'Value': 'Crime deprivation: score'})
df54880=df54879.rename(columns={'Value': 'Adjusted antibiotic prescribing in primary care by the NHS'})
df55241=df55240.rename(columns={'Value': 'Resident population'})
df55602=df55601.rename(columns={'Value': 'Mortality rate from all cardiovascular diseases, ages 65+ years'})
df55963=df55962.rename(columns={'Value': 'Mortality rate from cancer, ages 65+ years'})
df56324=df56323.rename(columns={'Value': 'Mortality rate from respiratory disease, ages 65+ years'})
df56685=df56684.rename(columns={'Value': 'Volume of pure alcohol sold through the off-trade: all alcohol sales'})
df57046=df57045.rename(columns={'Value': 'Volume of pure alcohol sold through the off-trade: beer sales'})
df57407=df57406.rename(columns={'Value': 'Volume of pure alcohol sold through the off-trade: wine sales'})
df57768=df57767.rename(columns={'Value': 'Volume of pure alcohol sold through the off-trade: spirit sales'})
df58129=df58128.rename(columns={'Value': 'Number of premises licensed to sell alcohol per square kilometre'})
df58490=df58489.rename(columns={'Value': 'Typhoid & paratyphoid incidence rateper100,000'})
df58851=df58850.rename(columns={'Value': 'Supporting information - % population from ethnic minorities'})
df59212=df59211.rename(columns={'Value': 'Economic inactivity rate'})
df59573=df59572.rename(columns={'Value': 'Inequality in life expectancy at birth'})
df59934=df59933.rename(columns={'Value': 'Admission episodes for alcohol-specific conditions - Under 18s'})
df60295=df60294.rename(columns={'Value': 'Admission episodes for alcohol-specific conditions'})
df60656=df60655.rename(columns={'Value': 'Air pollution: fine particulate matter (historic indicator)'})
df61017=df61016.rename(columns={'Value': 'Density of fast food outlets'})
df61378=df61377.rename(columns={'Value': 'Estimated dementia diagnosis rate (aged 65 and over)'})
df61739=df61738.rename(columns={'Value': 'Mortality rate from oral cancer'})
df62100=df62099.rename(columns={'Value': 'Percentage of physically active adults'})
df62461=df62460.rename(columns={'Value': 'Percentage of physically inactive adults'})
df62822=df62821.rename(columns={'Value': 'Access to Healthy Assets & Hazards Index'})
df63183=df63182.rename(columns={'Value': 'Proportion of the population meeting the recommended 5-a-day on a usual day (adults)'})
df63544=df63543.rename(columns={'Value': 'Percentage of the total resident population who are 65 and over'})
df63905=df63904.rename(columns={'Value': 'Percentage of the total resident population who are 25 to 64 years of age'})
df64266=df64265.rename(columns={'Value': 'Percentage of the total resident population who are 16 to 24 years of age'})
df64627=df64626.rename(columns={'Value': 'Percentage of the total resident population who are 0 to 15 years of age'})
df64988=df64987.rename(columns={'Value': 'Smoking status at time of delivery'})
df65349=df65348.rename(columns={'Value': 'Back pain prevalence in people of all ages'})
df65710=df65709.rename(columns={'Value': 'Percentage of population whose ethnicity is not White UK'})
df66071=df66070.rename(columns={'Value': 'Percentage of adults (aged 18+) classified as overweight or obese'})
df66432=df66431.rename(columns={'Value': 'General fertility rate: live births per 1,000 women aged 15-44 years. five year pooled'})
df66793=df66792.rename(columns={'Value': 'Prevalence of severe hip osteoarthritis in people aged  45 and over'})
df67154=df67153.rename(columns={'Value': 'Low birth weight of live babies, five year pooled'})
df67515=df67514.rename(columns={'Value': 'Prevalence of hip osteoarthritis in people aged  45 and over'})
df67876=df67875.rename(columns={'Value': 'Child Poverty, Income deprivation affecting children index (IDACI)'})
df68237=df68236.rename(columns={'Value': 'Prevalence of severe knee osteoarthritis in people aged  45 and over'})
df68598=df68597.rename(columns={'Value': 'Prevalence of knee osteoarthritis in people aged  45 and over'})
df68959=df68958.rename(columns={'Value': 'Unemployment (Percentage of the working age population claiming out of work benefit)'})
df69320=df69319.rename(columns={'Value': 'Long-Term Unemployment- rate per 1,000 working age population'})
df69681=df69680.rename(columns={'Value': 'Older people living alone, % of people aged 65 and over who are living alone'})
df70042=df70041.rename(columns={'Value': 'Employment and Support Allowance claimants'})
df70403=df70402.rename(columns={'Value': 'Reception: Prevalence of obesity (including severe obesity), 3-years data combined'})
df70764=df70763.rename(columns={'Value': 'Reception: Prevalence of overweight (including obesity), 3-years data combined'})
df71125=df71124.rename(columns={'Value': 'Year 6: Prevalence of obesity (including severe obesity), 3-years data combined'})
df71486=df71485.rename(columns={'Value': 'Year 6: Prevalence of overweight (including obesity), 3-years data combined'})
df71847=df71846.rename(columns={'Value': 'Affordability of home ownership'})
df72208=df72207.rename(columns={'Value': 'Deliveries to teenage mothers'})
df72569=df72568.rename(columns={'Value': 'Emergency hospital admissions for injuries in under 5 years old, crude rate'})
df72930=df72929.rename(columns={'Value': 'Emergency hospital admissions in under 5 years old, crude rate'})
df73291=df73290.rename(columns={'Value': 'Measles incidence rateper100,000'})
df73652=df73651.rename(columns={'Value': 'Measles 5-year incidence rateper100,000'})
df74013=df74012.rename(columns={'Value': 'Acute hepatitis B incidence rateper100,000'})
df74374=df74373.rename(columns={'Value': 'Hepatitis C detection rateper100,000'})
df74735=df74734.rename(columns={'Value': 'Inequality in life expectancy at 65'})
df75096=df75095.rename(columns={'Value': 'Reception: Prevalence of severe obesity'})
df75457=df75456.rename(columns={'Value': 'Year 6: Prevalence of severe obesity'})
df75818=df75817.rename(columns={'Value': 'Emergency hospital admissions for injuries in under 15 years old, crude rate'})
df76179=df76178.rename(columns={'Value': 'Emergency hospital admissions for injuries in 15 to 24 years old, crude rate'})
df76540=df76539.rename(columns={'Value': 'Percentage of the total resident population aged 85 and over'})
df76901=df76900.rename(columns={'Value': 'Emergency hospital admissions for all causes, all ages, standardised admission ratio'})
df77262=df77261.rename(columns={'Value': 'Emergency hospital admissions for coronary heart disease, standardised admission ratio'})
df77623=df77622.rename(columns={'Value': 'Emergency hospital admissions for stroke, standardised admission ratio'})
df77984=df77983.rename(columns={'Value': 'Emergency hospital admissions for Myocardial Infarction (heart attack), standardised admission ratio'})
df78345=df78344.rename(columns={'Value': 'Emergency hospital admissions for Chronic Obstructive Pulmonary Disease (COPD), standardised admission ratio'})
df78706=df78705.rename(columns={'Value': 'Incidence of all cancers, standardised incidence ratio'})
df79067=df79066.rename(columns={'Value': 'Incidence of breast cancer, standardised incidence ratio'})
df79428=df79427.rename(columns={'Value': 'Incidence of colorectal cancer, standardised incidence ratio'})
df79789=df79788.rename(columns={'Value': 'Incidence of lung cancer, standardised incidence ratio'})
df80150=df80149.rename(columns={'Value': 'Incidence of prostate cancer, standardised incidence ratio'})
df80511=df80510.rename(columns={'Value': 'Emergency hospital admissions for intentional self harm, standardised admission ratio'})
df80872=df80871.rename(columns={'Value': 'Hospital admissions for alcohol attributable conditions, (Narrow definition)'})
df81233=df81232.rename(columns={'Value': 'Emergency hospital admissions for hip fracture in persons 65 years and over, standardised admission ratio'})
df81594=df81593.rename(columns={'Value': 'Deaths from all causes, all ages, standardised mortality ratio'})
df81955=df81954.rename(columns={'Value': 'Deaths from all causes, under 75 years, standardised mortality ratio'})
df82316=df82315.rename(columns={'Value': 'Deaths from all cancer, all ages, standardised mortality ratio'})
df82677=df82676.rename(columns={'Value': 'Deaths from all cancer, under 75 years, standardised mortality ratio (SMR)'})
df83038=df83037.rename(columns={'Value': 'Deaths from circulatory disease, all ages, standardised mortality ratio'})
df83399=df83398.rename(columns={'Value': 'Deaths from circulatory disease, under 75 years, standardised mortality ratio'})
df83760=df83759.rename(columns={'Value': 'Deaths from coronary heart disease, all ages, standardised mortality ratio'})
df84121=df84120.rename(columns={'Value': 'Deaths from stroke, all ages, standardised mortality ratio'})
df84482=df84481.rename(columns={'Value': 'Deaths from respiratory diseases, all ages, standardised mortality ratio'})
df84843=df84842.rename(columns={'Value': 'Percentage of population whose ethnic group is not white'})
df85204=df85203.rename(columns={'Value': 'Income deprivation, English Indices of Deprivation'})
df85565=df85564.rename(columns={'Value': 'The percentage of people that cannot speak English well or at all,  2011'})
df85926=df85925.rename(columns={'Value': 'Index of Multiple Deprivation (IMD) Score'})
df86287=df86286.rename(columns={'Value': 'Percentage of people who reported having a limiting long term illness or disability'})
df86648=df86647.rename(columns={'Value': 'Households with overcrowding based on overall room occupancy levels'})
df87009=df87008.rename(columns={'Value': 'Older people in poverty: Income deprivation affecting older people Index (IDAOPI)'})
df87370=df87369.rename(columns={'Value': 'Modelled estimates of the proportion of households in fuel poverty (%)'})
df87731=df87730.rename(columns={'Value': 'Life expectancy at birth, (upper age band 90 and over)'})
df88092=df88091.rename(columns={'Value': 'Under 25s individuals attend specialist contraceptive services rate per 1000 - Females'})
df88453=df88452.rename(columns={'Value': 'Under 25s individuals attend specialist contraceptive services rate per 1000 - Males'})
df88814=df88813.rename(columns={'Value': 'STEC  (Shiga toxin-producing Escherichia coli) serogroup O157 5-year incidence rateper100,000'})
df89175=df89174.rename(columns={'Value': 'STEC (Shiga toxin-producing Escherichia coli) serogroup O157 incidence rateper100,000'})
df89536=df89535.rename(columns={'Value': 'Estimated diabetes diagnosis rate'})
df89897=df89896.rename(columns={'Value': 'Gender pay gap (by workplace location)'})
df90258=df90257.rename(columns={'Value': 'Average weekly earnings'})
df90619=df90618.rename(columns={'Value': 'Job density'})
df90980=df90979.rename(columns={'Value': 'Non-typhoidal Salmonella incidence rateper100,000'})
df91341=df91340.rename(columns={'Value': 'Campylobacter incidence rateper100,000'})
df91702=df91701.rename(columns={'Value': 'Shigella incidence rateper100,000'})
df92063=df92062.rename(columns={'Value': '% reporting a long term MSK problem who also report depression or anxiety'})
df92424=df92423.rename(columns={'Value': 'Average health related quality of life score for adults who reported having a long term MSK problem.'})
df92785=df92784.rename(columns={'Value': '% reporting depression or anxiety'})
df93146=df93145.rename(columns={'Value': 'Percentage reporting a long-term Musculoskeletal (MSK) problem'})
df93507=df93506.rename(columns={'Value': 'Average Attainment 8 score'})
df93868=df93867.rename(columns={'Value': 'Giardia incidence rateper100,000'})
df94229=df94228.rename(columns={'Value': 'Cryptosporidium incidence rateper100,000'})
df94590=df94589.rename(columns={'Value': 'Odds of current smoking (self-reported) among adults aged 18-64 with a routine and manual occupation (APS)'})
df94951=df94950.rename(columns={'Value': 'Oesophageal cancer registrations'})
df95312=df95311.rename(columns={'Value': 'Percentage of adults walking for travel at least three days per week'})
df95673=df95672.rename(columns={'Value': 'Percentage of adults cycling for travel at least three days per week'})
df96034=df96033.rename(columns={'Value': 'Percentage reporting at least two long-term conditions, at least one of which is MSK related'})
df96395=df96394.rename(columns={'Value': 'Smoking prevalence in adults with a long term mental health condition (18+) - current smokers (GPPS)'})
df96756=df96755.rename(columns={'Value': 'Smoking prevalence in adults with anxiety or depression (18+) - current smokers (GPPS)'})
df97117=df97116.rename(columns={'Value': 'Listeria incidence rateper100,000'})
df97478=df97477.rename(columns={'Value': 'Scarlet fever notification rateper100,000 aged 0-9 yrs'})
df97839=df97838.rename(columns={'Value': 'Hospital admissions for alcohol attributable conditions, (Broad definition)'})
df98200=df98199.rename(columns={'Value': 'Mumps incidence rateper100,000'})
df98561=df98560.rename(columns={'Value': 'Mumps 5-year incidence rateper100,000'})
df98922=df98921.rename(columns={'Value': 'Percentage of deaths that occur in hospital'})
df99283=df99282.rename(columns={'Value': 'Percentage of deaths that occur in care homes'})
df99644=df99643.rename(columns={'Value': 'Percentage of deaths that occur at home'})
df100005=df100004.rename(columns={'Value': 'Percentage of deaths that occur in other places'})
df100366=df100365.rename(columns={'Value': 'Percentage of deaths that occur in hospice'})
df100727=df100726.rename(columns={'Value': 'Deaths from causes considered preventable, under 75 years, standardised mortality ratio'})
df101088=df101087.rename(columns={'Value': 'Smoking prevalence at age 15 - regular smokers (modelled estimates)'})
df101449=df101448.rename(columns={'Value': 'Smoking prevalence at age 15 - regular or occasional smokers (modelled estimates)'})
df101810=df101809.rename(columns={'Value': 'Listeria 5-year incidence rateper100,000'})
df102171=df102170.rename(columns={'Value': 'Estimated prevalence of common mental disorders: % of population aged 16 & over'})
df102532=df102531.rename(columns={'Value': 'Estimated prevalence of common mental disorders: % of population aged 65 & over'})
df102893=df102892.rename(columns={'Value': 'Percentage of deaths with underlying cause Cancer'})
df103254=df103253.rename(columns={'Value': 'Percentage of deaths with underlying cause respiratory disease'})
df103615=df103614.rename(columns={'Value': 'Percentage of deaths with underlying cause circulatory disease'})
df103976=df103975.rename(columns={'Value': 'Percentage of all Deaths'})
df104337=df104336.rename(columns={'Value': 'Mortality Rate'})
df104698=df104697.rename(columns={'Value': 'Re-offending levels - percentage of offenders who re-offend'})
df105059=df105058.rename(columns={'Value': 'Pertussis incidence rateper100,000'})
df105420=df105419.rename(columns={'Value': 'Prompt antiretroviral therapy (ART) initiation in people newly diagnosed with HIV'})
df105781=df105780.rename(columns={'Value': 'Virological success in adults accessing HIV care'})
df106142=df106141.rename(columns={'Value': 'Repeat HIV testing in gay, bisexual and other men who have sex with men'})
df106503=df106502.rename(columns={'Value': 'Deprivation score (IMD 2019)'})
df106864=df106863.rename(columns={'Value': 'Cancer screening coverage: cervical cancer (aged 25 to 49 years old)'})
df107225=df107224.rename(columns={'Value': 'Cancer screening coverage: cervical cancer (aged 50 to 64 years old)'})
df107586=df107585.rename(columns={'Value': 'Percentage of 5 year olds with experience of visually obvious dental decay'})
df107947=df107946.rename(columns={'Value': 'Percentage of physically active children and young people'})
df108308=df108307.rename(columns={'Value': 'Re-offending levels - average number of re-offences per re-offender'})
df108669=df108668.rename(columns={'Value': 'Babys first feed breastmilk'})
df109030=df109029.rename(columns={'Value': 'Invasive Meningococcal Disease (IMD) confirmed cases rateper100,000'})
df109391=df109390.rename(columns={'Value': 'Mortality rate from asthma'})
df109752=df109751.rename(columns={'Value': 'Odds of current smoking (self-reported) among adults aged 18+ diagnosed with a long-term mental health condition'})
df110113=df110112.rename(columns={'Value': 'Percentage of cancers diagnosed at stages 1 and 2'})
df110474=df110473.rename(columns={'Value': 'Population vaccination coverage: Flu (primary school aged children)'})
df110835=df110834.rename(columns={'Value': 'Children in relative low income families (under 16s)'})
df111196=df111195.rename(columns={'Value': 'Children in absolute low income families (under 16s)'})
df111557=df111556.rename(columns={'Value': 'Under 75 mortality rate from liver disease considered preventable (2019 definition)'})
df111918=df111917.rename(columns={'Value': 'Under 75 mortality rate from causes considered preventable (2019 definition)'})
df112279=df112278.rename(columns={'Value': 'Under 75 mortality rate from cardiovascular diseases considered preventable (2019 definition)'})
df112640=df112639.rename(columns={'Value': 'Under 75 mortality rate from cancer considered preventable (2019 definition)'})
df113001=df113000.rename(columns={'Value': 'Under 75 mortality rate from respiratory disease considered preventable (2019 definition)'})
df113362=df113361.rename(columns={'Value': 'Homelessness - households in temporary accommodation'})
df113723=df113722.rename(columns={'Value': 'Homelessness - households owed a duty under the Homelessness Reduction Act'})
df114084=df114083.rename(columns={'Value': 'Homelessness - households owed a duty under the Homelessness Reduction Act (main applicant 16-24 yrs)'})
df114445=df114444.rename(columns={'Value': 'Homelessness - households owed a duty under the Homelessness Reduction Act (main applicant 55+ yrs)'})
df114806=df114805.rename(columns={'Value': 'Homelessness - households with dependent children owed a duty under the Homelessness Reduction Act'})
df115167=df115166.rename(columns={'Value': 'Odds ratio of reporting a mental health condition among people with and without an MSK condition'})
df115528=df115527.rename(columns={'Value': 'Percentage of the total resident population who are 0 to 4 years of age'})
df115889=df115888.rename(columns={'Value': 'Percentage of the total resident population who are 5 to 15 years of age'})
df116250=df116249.rename(columns={'Value': 'Percentage of the total resident population who are 50 to 64 years of age'})
df116611=df116610.rename(columns={'Value': 'Population density, people per square kilometre'})
df116972=df116971.rename(columns={'Value': 'Smoking attributable mortality (new method)'})
df117333=df117332.rename(columns={'Value': 'Smoking attributable deaths from heart disease (new method)'})
df117694=df117693.rename(columns={'Value': 'Smoking attributable deaths from stroke (new method)'})
df118055=df118054.rename(columns={'Value': 'Smoking attributable hospital admissions (new method). This indicator uses new set of attributable fractions, and so differ from that originally published.'})
df118416=df118415.rename(columns={'Value': 'Killed and seriously injured (KSI) casualties on Englands roads'})
df118777=df118776.rename(columns={'Value': 'Loneliness: Percentage of adults who feel lonely often per always or some of the time'})
df119138=df119137.rename(columns={'Value': 'Fuel poverty (low income, low energy efficiency methodology)'})
df119499=df119498.rename(columns={'Value': 'Mycoplasma genitalium diagnostic rate per 100,000'})
df119860=df119859.rename(columns={'Value': 'Trichomoniasis diagnostic rate per 100,000'})
df120221=df120220.rename(columns={'Value': 'Alcohol-related mortality: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published.'})
df120582=df120581.rename(columns={'Value': 'Admission episodes for alcohol-related conditions (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published.'})
df120943=df120942.rename(columns={'Value': 'Admission episodes for alcohol-related conditions (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published.'})
df121304=df121303.rename(columns={'Value': 'Admission episodes for alcohol-related unintentional injuries (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published.'})
df121665=df121664.rename(columns={'Value': 'Admission episodes for mental and behavioural disorders due to use of alcohol (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published.'})
df122026=df122025.rename(columns={'Value': 'Admission episodes for intentional self-poisoning by and exposure to alcohol (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published.'})
df122387=df122386.rename(columns={'Value': 'Admission episodes for alcohol-related cardiovascular disease (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published.'})
df122748=df122747.rename(columns={'Value': 'Admission episodes for mental and behavioural disorders due to use of alcohol (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published.'})
df123109=df123108.rename(columns={'Value': 'Admission episodes for alcoholic liver disease (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published.'})
df123470=df123469.rename(columns={'Value': 'Admission episodes for alcohol-related conditions (Narrow) - Under 40s: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published.'})
df123831=df123830.rename(columns={'Value': 'Admission episodes for alcohol-related conditions (Narrow)40 to 64 years: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published.'})
df124192=df124191.rename(columns={'Value': 'Admission episodes for alcohol-related conditions (Narrow)65+ years: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published.'})
df124553=df124552.rename(columns={'Value': 'HIV diagnosed prevalence rate per 1,000'})
df124914=df124913.rename(columns={'Value': 'New HIV diagnoses among persons first diagnosed in the UK rate per 100,000'})
df125275=df125274.rename(columns={'Value': 'Antiretroviral therapy (ART) coverage in people accessing HIV care'})
df125636=df125635.rename(columns={'Value': 'Mortality rate from all causes, all ages'})
df125997=df125996.rename(columns={'Value': 'Mortality rate for deaths involving COVID-19, all ages'})
df126358=df126357.rename(columns={'Value': 'Mortality rate for deaths involving COVID-19, under 75s'})
df126719=df126718.rename(columns={'Value': 'Fraction of mortality attributable to particulate air pollution (new method)'})
df127080=df127079.rename(columns={'Value': 'Acute Lyme disease laboratory confirmed incidence rateper100,000'})
df127441=df127440.rename(columns={'Value': 'Average Attainment 8 Score among children eligible for Free School Meals (FSM)'})
df127802=df127801.rename(columns={'Value': 'Air pollution: fine particulate matter (new method - concentrations of total PM2.5)'})
df128163=df128162.rename(columns={'Value': 'Potential years of life lost (PYLL) due to alcohol-related conditions'})
df128524=df128523.rename(columns={'Value': 'Percentage of adults (aged 18+) classified as obese'})
df128885=df128884.rename(columns={'Value': 'The percentage of the population with a physical or mental long term health condition in employment (aged 16 to 64)'})
df129246=df129245.rename(columns={'Value': 'The percentage of the population who are in receipt of long term support for a learning disability that are in paid employment (aged 18 to 64)'})
df129607=df129606.rename(columns={'Value': 'Initiation or continuation of PrEP among those with PrEP need'})
df129968=df129967.rename(columns={'Value': 'Determining PrEP need'})

# %%
df8.head(10)
# Out:
#    Unnamed: 0                           Indicator Name              Area Name  \
# 0       34899  Under 75 mortality rate from all causes             Hartlepool
# 1       34900  Under 75 mortality rate from all causes          Middlesbrough
# 2       34901  Under 75 mortality rate from all causes   Redcar and Cleveland
# 3       34902  Under 75 mortality rate from all causes       Stockton-on-Tees
# 4       34903  Under 75 mortality rate from all causes             Darlington
# 5       34904  Under 75 mortality rate from all causes                 Halton
# 6       34905  Under 75 mortality rate from all causes             Warrington
# 7       34906  Under 75 mortality rate from all causes  Blackburn with Darwen
# 8       34907  Under 75 mortality rate from all causes              Blackpool
# 9       34908  Under 75 mortality rate from all causes     Kingston upon Hull
#
#    Under 75 mortality rate from all causes
# 0                                   460.80
# ...

# %% [markdown]
# Step 13: clean data

# %%
df9=df8.drop(['Indicator Name','Unnamed: 0'],axis=1)
df370=df369.drop(['Indicator Name','Unnamed: 0'],axis=1)
df731=df730.drop(['Indicator Name','Unnamed: 0'],axis=1)
df1092=df1091.drop(['Indicator Name','Unnamed: 0'],axis=1)
df1453=df1452.drop(['Indicator Name','Unnamed: 0'],axis=1)
df1814=df1813.drop(['Indicator Name','Unnamed: 0'],axis=1)
df2175=df2174.drop(['Indicator Name','Unnamed: 0'],axis=1)
df2536=df2535.drop(['Indicator Name','Unnamed: 0'],axis=1)
df2897=df2896.drop(['Indicator Name','Unnamed: 0'],axis=1)
df3258=df3257.drop(['Indicator Name','Unnamed: 0'],axis=1)
df3619=df3618.drop(['Indicator Name','Unnamed: 0'],axis=1)
df3980=df3979.drop(['Indicator Name','Unnamed: 0'],axis=1)
df4341=df4340.drop(['Indicator Name','Unnamed: 0'],axis=1)
df4702=df4701.drop(['Indicator Name','Unnamed: 0'],axis=1)
df5063=df5062.drop(['Indicator Name','Unnamed: 0'],axis=1)
df5424=df5423.drop(['Indicator Name','Unnamed: 0'],axis=1)
df5785=df5784.drop(['Indicator Name','Unnamed: 0'],axis=1)
df6146=df6145.drop(['Indicator Name','Unnamed: 0'],axis=1)
df6507=df6506.drop(['Indicator Name','Unnamed: 0'],axis=1)
df6868=df6867.drop(['Indicator Name','Unnamed: 0'],axis=1)
df7229=df7228.drop(['Indicator Name','Unnamed: 0'],axis=1)
df7590=df7589.drop(['Indicator Name','Unnamed: 0'],axis=1)
df7951=df7950.drop(['Indicator Name','Unnamed: 0'],axis=1)
df8312=df8311.drop(['Indicator Name','Unnamed: 0'],axis=1)
df8673=df8672.drop(['Indicator Name','Unnamed: 0'],axis=1)
df9034=df9033.drop(['Indicator Name','Unnamed: 0'],axis=1)
df9395=df9394.drop(['Indicator Name','Unnamed: 0'],axis=1)
df9756=df9755.drop(['Indicator Name','Unnamed: 0'],axis=1)
df10117=df10116.drop(['Indicator Name','Unnamed: 0'],axis=1)
df10478=df10477.drop(['Indicator Name','Unnamed: 0'],axis=1)
df10839=df10838.drop(['Indicator Name','Unnamed: 0'],axis=1)
df11200=df11199.drop(['Indicator Name','Unnamed: 0'],axis=1)
df11561=df11560.drop(['Indicator Name','Unnamed: 0'],axis=1)
df11922=df11921.drop(['Indicator Name','Unnamed: 0'],axis=1)
df12283=df12282.drop(['Indicator Name','Unnamed: 0'],axis=1)
df12644=df12643.drop(['Indicator Name','Unnamed: 0'],axis=1)
df13005=df13004.drop(['Indicator Name','Unnamed: 0'],axis=1)
df13366=df13365.drop(['Indicator Name','Unnamed: 0'],axis=1)
df13727=df13726.drop(['Indicator Name','Unnamed: 0'],axis=1)
df14088=df14087.drop(['Indicator Name','Unnamed: 0'],axis=1)
df14449=df14448.drop(['Indicator Name','Unnamed: 0'],axis=1)
df14810=df14809.drop(['Indicator Name','Unnamed: 0'],axis=1)
df15171=df15170.drop(['Indicator Name','Unnamed: 0'],axis=1)
df15532=df15531.drop(['Indicator Name','Unnamed: 0'],axis=1)
df15893=df15892.drop(['Indicator Name','Unnamed: 0'],axis=1)
df16254=df16253.drop(['Indicator Name','Unnamed: 0'],axis=1)
df16615=df16614.drop(['Indicator Name','Unnamed: 0'],axis=1)
df16976=df16975.drop(['Indicator Name','Unnamed: 0'],axis=1)
df17337=df17336.drop(['Indicator Name','Unnamed: 0'],axis=1)
df17698=df17697.drop(['Indicator Name','Unnamed: 0'],axis=1)
df18059=df18058.drop(['Indicator Name','Unnamed: 0'],axis=1)
df18420=df18419.drop(['Indicator Name','Unnamed: 0'],axis=1)
df18781=df18780.drop(['Indicator Name','Unnamed: 0'],axis=1)
df19142=df19141.drop(['Indicator Name','Unnamed: 0'],axis=1)
df19503=df19502.drop(['Indicator Name','Unnamed: 0'],axis=1)
df19864=df19863.drop(['Indicator Name','Unnamed: 0'],axis=1)
df20225=df20224.drop(['Indicator Name','Unnamed: 0'],axis=1)
df20586=df20585.drop(['Indicator Name','Unnamed: 0'],axis=1)
df20947=df20946.drop(['Indicator Name','Unnamed: 0'],axis=1)
df21308=df21307.drop(['Indicator Name','Unnamed: 0'],axis=1)
df21669=df21668.drop(['Indicator Name','Unnamed: 0'],axis=1)
df22030=df22029.drop(['Indicator Name','Unnamed: 0'],axis=1)
df22391=df22390.drop(['Indicator Name','Unnamed: 0'],axis=1)
df22752=df22751.drop(['Indicator Name','Unnamed: 0'],axis=1)
df23113=df23112.drop(['Indicator Name','Unnamed: 0'],axis=1)
df23474=df23473.drop(['Indicator Name','Unnamed: 0'],axis=1)
df23835=df23834.drop(['Indicator Name','Unnamed: 0'],axis=1)
df24196=df24195.drop(['Indicator Name','Unnamed: 0'],axis=1)
df24557=df24556.drop(['Indicator Name','Unnamed: 0'],axis=1)
df24918=df24917.drop(['Indicator Name','Unnamed: 0'],axis=1)
df25279=df25278.drop(['Indicator Name','Unnamed: 0'],axis=1)
df25640=df25639.drop(['Indicator Name','Unnamed: 0'],axis=1)
df26001=df26000.drop(['Indicator Name','Unnamed: 0'],axis=1)
df26362=df26361.drop(['Indicator Name','Unnamed: 0'],axis=1)
df26723=df26722.drop(['Indicator Name','Unnamed: 0'],axis=1)
df27084=df27083.drop(['Indicator Name','Unnamed: 0'],axis=1)
df27445=df27444.drop(['Indicator Name','Unnamed: 0'],axis=1)
df27806=df27805.drop(['Indicator Name','Unnamed: 0'],axis=1)
df28167=df28166.drop(['Indicator Name','Unnamed: 0'],axis=1)
df28528=df28527.drop(['Indicator Name','Unnamed: 0'],axis=1)
df28889=df28888.drop(['Indicator Name','Unnamed: 0'],axis=1)
df29250=df29249.drop(['Indicator Name','Unnamed: 0'],axis=1)
df29611=df29610.drop(['Indicator Name','Unnamed: 0'],axis=1)
df29972=df29971.drop(['Indicator Name','Unnamed: 0'],axis=1)
df30333=df30332.drop(['Indicator Name','Unnamed: 0'],axis=1)
df30694=df30693.drop(['Indicator Name','Unnamed: 0'],axis=1)
df31055=df31054.drop(['Indicator Name','Unnamed: 0'],axis=1)
df31416=df31415.drop(['Indicator Name','Unnamed: 0'],axis=1)
df31777=df31776.drop(['Indicator Name','Unnamed: 0'],axis=1)
df32138=df32137.drop(['Indicator Name','Unnamed: 0'],axis=1)
df32499=df32498.drop(['Indicator Name','Unnamed: 0'],axis=1)
df32860=df32859.drop(['Indicator Name','Unnamed: 0'],axis=1)
df33221=df33220.drop(['Indicator Name','Unnamed: 0'],axis=1)
df33582=df33581.drop(['Indicator Name','Unnamed: 0'],axis=1)
df33943=df33942.drop(['Indicator Name','Unnamed: 0'],axis=1)
df34304=df34303.drop(['Indicator Name','Unnamed: 0'],axis=1)
df34665=df34664.drop(['Indicator Name','Unnamed: 0'],axis=1)
df35026=df35025.drop(['Indicator Name','Unnamed: 0'],axis=1)
df35387=df35386.drop(['Indicator Name','Unnamed: 0'],axis=1)
df35748=df35747.drop(['Indicator Name','Unnamed: 0'],axis=1)
df36109=df36108.drop(['Indicator Name','Unnamed: 0'],axis=1)
df36470=df36469.drop(['Indicator Name','Unnamed: 0'],axis=1)
df36831=df36830.drop(['Indicator Name','Unnamed: 0'],axis=1)
df37192=df37191.drop(['Indicator Name','Unnamed: 0'],axis=1)
df37553=df37552.drop(['Indicator Name','Unnamed: 0'],axis=1)
df37914=df37913.drop(['Indicator Name','Unnamed: 0'],axis=1)
df38275=df38274.drop(['Indicator Name','Unnamed: 0'],axis=1)
df38636=df38635.drop(['Indicator Name','Unnamed: 0'],axis=1)
df38997=df38996.drop(['Indicator Name','Unnamed: 0'],axis=1)
df39358=df39357.drop(['Indicator Name','Unnamed: 0'],axis=1)
df39719=df39718.drop(['Indicator Name','Unnamed: 0'],axis=1)
df40080=df40079.drop(['Indicator Name','Unnamed: 0'],axis=1)
df40441=df40440.drop(['Indicator Name','Unnamed: 0'],axis=1)
df40802=df40801.drop(['Indicator Name','Unnamed: 0'],axis=1)
df41163=df41162.drop(['Indicator Name','Unnamed: 0'],axis=1)
df41524=df41523.drop(['Indicator Name','Unnamed: 0'],axis=1)
df41885=df41884.drop(['Indicator Name','Unnamed: 0'],axis=1)
df42246=df42245.drop(['Indicator Name','Unnamed: 0'],axis=1)
df42607=df42606.drop(['Indicator Name','Unnamed: 0'],axis=1)
df42968=df42967.drop(['Indicator Name','Unnamed: 0'],axis=1)
df43329=df43328.drop(['Indicator Name','Unnamed: 0'],axis=1)
df43690=df43689.drop(['Indicator Name','Unnamed: 0'],axis=1)
df44051=df44050.drop(['Indicator Name','Unnamed: 0'],axis=1)
df44412=df44411.drop(['Indicator Name','Unnamed: 0'],axis=1)
df44773=df44772.drop(['Indicator Name','Unnamed: 0'],axis=1)
df45134=df45133.drop(['Indicator Name','Unnamed: 0'],axis=1)
df45495=df45494.drop(['Indicator Name','Unnamed: 0'],axis=1)
df45856=df45855.drop(['Indicator Name','Unnamed: 0'],axis=1)
df46217=df46216.drop(['Indicator Name','Unnamed: 0'],axis=1)
df46578=df46577.drop(['Indicator Name','Unnamed: 0'],axis=1)
df46939=df46938.drop(['Indicator Name','Unnamed: 0'],axis=1)
df47300=df47299.drop(['Indicator Name','Unnamed: 0'],axis=1)
df47661=df47660.drop(['Indicator Name','Unnamed: 0'],axis=1)
df48022=df48021.drop(['Indicator Name','Unnamed: 0'],axis=1)
df48383=df48382.drop(['Indicator Name','Unnamed: 0'],axis=1)
df48744=df48743.drop(['Indicator Name','Unnamed: 0'],axis=1)
df49105=df49104.drop(['Indicator Name','Unnamed: 0'],axis=1)
df49466=df49465.drop(['Indicator Name','Unnamed: 0'],axis=1)
df49827=df49826.drop(['Indicator Name','Unnamed: 0'],axis=1)
df50188=df50187.drop(['Indicator Name','Unnamed: 0'],axis=1)
df50549=df50548.drop(['Indicator Name','Unnamed: 0'],axis=1)
df50910=df50909.drop(['Indicator Name','Unnamed: 0'],axis=1)
df51271=df51270.drop(['Indicator Name','Unnamed: 0'],axis=1)
df51632=df51631.drop(['Indicator Name','Unnamed: 0'],axis=1)
df51993=df51992.drop(['Indicator Name','Unnamed: 0'],axis=1)
df52354=df52353.drop(['Indicator Name','Unnamed: 0'],axis=1)
df52715=df52714.drop(['Indicator Name','Unnamed: 0'],axis=1)
df53076=df53075.drop(['Indicator Name','Unnamed: 0'],axis=1)
df53437=df53436.drop(['Indicator Name','Unnamed: 0'],axis=1)
df53798=df53797.drop(['Indicator Name','Unnamed: 0'],axis=1)
df54159=df54158.drop(['Indicator Name','Unnamed: 0'],axis=1)
df54520=df54519.drop(['Indicator Name','Unnamed: 0'],axis=1)
df54881=df54880.drop(['Indicator Name','Unnamed: 0'],axis=1)
df55242=df55241.drop(['Indicator Name','Unnamed: 0'],axis=1)
df55603=df55602.drop(['Indicator Name','Unnamed: 0'],axis=1)
df55964=df55963.drop(['Indicator Name','Unnamed: 0'],axis=1)
df56325=df56324.drop(['Indicator Name','Unnamed: 0'],axis=1)
df56686=df56685.drop(['Indicator Name','Unnamed: 0'],axis=1)
df57047=df57046.drop(['Indicator Name','Unnamed: 0'],axis=1)
df57408=df57407.drop(['Indicator Name','Unnamed: 0'],axis=1)
df57769=df57768.drop(['Indicator Name','Unnamed: 0'],axis=1)
df58130=df58129.drop(['Indicator Name','Unnamed: 0'],axis=1)
df58491=df58490.drop(['Indicator Name','Unnamed: 0'],axis=1)
df58852=df58851.drop(['Indicator Name','Unnamed: 0'],axis=1)
df59213=df59212.drop(['Indicator Name','Unnamed: 0'],axis=1)
df59574=df59573.drop(['Indicator Name','Unnamed: 0'],axis=1)
df59935=df59934.drop(['Indicator Name','Unnamed: 0'],axis=1)
df60296=df60295.drop(['Indicator Name','Unnamed: 0'],axis=1)
df60657=df60656.drop(['Indicator Name','Unnamed: 0'],axis=1)
df61018=df61017.drop(['Indicator Name','Unnamed: 0'],axis=1)
df61379=df61378.drop(['Indicator Name','Unnamed: 0'],axis=1)
df61740=df61739.drop(['Indicator Name','Unnamed: 0'],axis=1)
df62101=df62100.drop(['Indicator Name','Unnamed: 0'],axis=1)
df62462=df62461.drop(['Indicator Name','Unnamed: 0'],axis=1)
df62823=df62822.drop(['Indicator Name','Unnamed: 0'],axis=1)
df63184=df63183.drop(['Indicator Name','Unnamed: 0'],axis=1)
df63545=df63544.drop(['Indicator Name','Unnamed: 0'],axis=1)
df63906=df63905.drop(['Indicator Name','Unnamed: 0'],axis=1)
df64267=df64266.drop(['Indicator Name','Unnamed: 0'],axis=1)
df64628=df64627.drop(['Indicator Name','Unnamed: 0'],axis=1)
df64989=df64988.drop(['Indicator Name','Unnamed: 0'],axis=1)
df65350=df65349.drop(['Indicator Name','Unnamed: 0'],axis=1)
df65711=df65710.drop(['Indicator Name','Unnamed: 0'],axis=1)
df66072=df66071.drop(['Indicator Name','Unnamed: 0'],axis=1)
df66433=df66432.drop(['Indicator Name','Unnamed: 0'],axis=1)
df66794=df66793.drop(['Indicator Name','Unnamed: 0'],axis=1)
df67155=df67154.drop(['Indicator Name','Unnamed: 0'],axis=1)
df67516=df67515.drop(['Indicator Name','Unnamed: 0'],axis=1)
df67877=df67876.drop(['Indicator Name','Unnamed: 0'],axis=1)
df68238=df68237.drop(['Indicator Name','Unnamed: 0'],axis=1)
df68599=df68598.drop(['Indicator Name','Unnamed: 0'],axis=1)
df68960=df68959.drop(['Indicator Name','Unnamed: 0'],axis=1)
df69321=df69320.drop(['Indicator Name','Unnamed: 0'],axis=1)
df69682=df69681.drop(['Indicator Name','Unnamed: 0'],axis=1)
df70043=df70042.drop(['Indicator Name','Unnamed: 0'],axis=1)
df70404=df70403.drop(['Indicator Name','Unnamed: 0'],axis=1)
df70765=df70764.drop(['Indicator Name','Unnamed: 0'],axis=1)
df71126=df71125.drop(['Indicator Name','Unnamed: 0'],axis=1)
df71487=df71486.drop(['Indicator Name','Unnamed: 0'],axis=1)
df71848=df71847.drop(['Indicator Name','Unnamed: 0'],axis=1)
df72209=df72208.drop(['Indicator Name','Unnamed: 0'],axis=1)
df72570=df72569.drop(['Indicator Name','Unnamed: 0'],axis=1)
df72931=df72930.drop(['Indicator Name','Unnamed: 0'],axis=1)
df73292=df73291.drop(['Indicator Name','Unnamed: 0'],axis=1)
df73653=df73652.drop(['Indicator Name','Unnamed: 0'],axis=1)
df74014=df74013.drop(['Indicator Name','Unnamed: 0'],axis=1)
df74375=df74374.drop(['Indicator Name','Unnamed: 0'],axis=1)
df74736=df74735.drop(['Indicator Name','Unnamed: 0'],axis=1)
df75097=df75096.drop(['Indicator Name','Unnamed: 0'],axis=1)
df75458=df75457.drop(['Indicator Name','Unnamed: 0'],axis=1)
df75819=df75818.drop(['Indicator Name','Unnamed: 0'],axis=1)
df76180=df76179.drop(['Indicator Name','Unnamed: 0'],axis=1)
df76541=df76540.drop(['Indicator Name','Unnamed: 0'],axis=1)
df76902=df76901.drop(['Indicator Name','Unnamed: 0'],axis=1)
df77263=df77262.drop(['Indicator Name','Unnamed: 0'],axis=1)
df77624=df77623.drop(['Indicator Name','Unnamed: 0'],axis=1)
df77985=df77984.drop(['Indicator Name','Unnamed: 0'],axis=1)
df78346=df78345.drop(['Indicator Name','Unnamed: 0'],axis=1)
df78707=df78706.drop(['Indicator Name','Unnamed: 0'],axis=1)
df79068=df79067.drop(['Indicator Name','Unnamed: 0'],axis=1)
df79429=df79428.drop(['Indicator Name','Unnamed: 0'],axis=1)
df79790=df79789.drop(['Indicator Name','Unnamed: 0'],axis=1)
df80151=df80150.drop(['Indicator Name','Unnamed: 0'],axis=1)
df80512=df80511.drop(['Indicator Name','Unnamed: 0'],axis=1)
df80873=df80872.drop(['Indicator Name','Unnamed: 0'],axis=1)
df81234=df81233.drop(['Indicator Name','Unnamed: 0'],axis=1)
df81595=df81594.drop(['Indicator Name','Unnamed: 0'],axis=1)
df81956=df81955.drop(['Indicator Name','Unnamed: 0'],axis=1)
df82317=df82316.drop(['Indicator Name','Unnamed: 0'],axis=1)
df82678=df82677.drop(['Indicator Name','Unnamed: 0'],axis=1)
df83039=df83038.drop(['Indicator Name','Unnamed: 0'],axis=1)
df83400=df83399.drop(['Indicator Name','Unnamed: 0'],axis=1)
df83761=df83760.drop(['Indicator Name','Unnamed: 0'],axis=1)
df84122=df84121.drop(['Indicator Name','Unnamed: 0'],axis=1)
df84483=df84482.drop(['Indicator Name','Unnamed: 0'],axis=1)
df84844=df84843.drop(['Indicator Name','Unnamed: 0'],axis=1)
df85205=df85204.drop(['Indicator Name','Unnamed: 0'],axis=1)
df85566=df85565.drop(['Indicator Name','Unnamed: 0'],axis=1)
df85927=df85926.drop(['Indicator Name','Unnamed: 0'],axis=1)
df86288=df86287.drop(['Indicator Name','Unnamed: 0'],axis=1)
df86649=df86648.drop(['Indicator Name','Unnamed: 0'],axis=1)
df87010=df87009.drop(['Indicator Name','Unnamed: 0'],axis=1)
df87371=df87370.drop(['Indicator Name','Unnamed: 0'],axis=1)
df87732=df87731.drop(['Indicator Name','Unnamed: 0'],axis=1)
df88093=df88092.drop(['Indicator Name','Unnamed: 0'],axis=1)
df88454=df88453.drop(['Indicator Name','Unnamed: 0'],axis=1)
df88815=df88814.drop(['Indicator Name','Unnamed: 0'],axis=1)
df89176=df89175.drop(['Indicator Name','Unnamed: 0'],axis=1)
df89537=df89536.drop(['Indicator Name','Unnamed: 0'],axis=1)
df89898=df89897.drop(['Indicator Name','Unnamed: 0'],axis=1)
df90259=df90258.drop(['Indicator Name','Unnamed: 0'],axis=1)
df90620=df90619.drop(['Indicator Name','Unnamed: 0'],axis=1)
df90981=df90980.drop(['Indicator Name','Unnamed: 0'],axis=1)
df91342=df91341.drop(['Indicator Name','Unnamed: 0'],axis=1)
df91703=df91702.drop(['Indicator Name','Unnamed: 0'],axis=1)
df92064=df92063.drop(['Indicator Name','Unnamed: 0'],axis=1)
df92425=df92424.drop(['Indicator Name','Unnamed: 0'],axis=1)
df92786=df92785.drop(['Indicator Name','Unnamed: 0'],axis=1)
df93147=df93146.drop(['Indicator Name','Unnamed: 0'],axis=1)
df93508=df93507.drop(['Indicator Name','Unnamed: 0'],axis=1)
df93869=df93868.drop(['Indicator Name','Unnamed: 0'],axis=1)
df94230=df94229.drop(['Indicator Name','Unnamed: 0'],axis=1)
df94591=df94590.drop(['Indicator Name','Unnamed: 0'],axis=1)
df94952=df94951.drop(['Indicator Name','Unnamed: 0'],axis=1)
df95313=df95312.drop(['Indicator Name','Unnamed: 0'],axis=1)
df95674=df95673.drop(['Indicator Name','Unnamed: 0'],axis=1)
df96035=df96034.drop(['Indicator Name','Unnamed: 0'],axis=1)
df96396=df96395.drop(['Indicator Name','Unnamed: 0'],axis=1)
df96757=df96756.drop(['Indicator Name','Unnamed: 0'],axis=1)
df97118=df97117.drop(['Indicator Name','Unnamed: 0'],axis=1)
df97479=df97478.drop(['Indicator Name','Unnamed: 0'],axis=1)
df97840=df97839.drop(['Indicator Name','Unnamed: 0'],axis=1)
df98201=df98200.drop(['Indicator Name','Unnamed: 0'],axis=1)
df98562=df98561.drop(['Indicator Name','Unnamed: 0'],axis=1)
df98923=df98922.drop(['Indicator Name','Unnamed: 0'],axis=1)
df99284=df99283.drop(['Indicator Name','Unnamed: 0'],axis=1)
df99645=df99644.drop(['Indicator Name','Unnamed: 0'],axis=1)
df100006=df100005.drop(['Indicator Name','Unnamed: 0'],axis=1)
df100367=df100366.drop(['Indicator Name','Unnamed: 0'],axis=1)
df100728=df100727.drop(['Indicator Name','Unnamed: 0'],axis=1)
df101089=df101088.drop(['Indicator Name','Unnamed: 0'],axis=1)
df101450=df101449.drop(['Indicator Name','Unnamed: 0'],axis=1)
df101811=df101810.drop(['Indicator Name','Unnamed: 0'],axis=1)
df102172=df102171.drop(['Indicator Name','Unnamed: 0'],axis=1)
df102533=df102532.drop(['Indicator Name','Unnamed: 0'],axis=1)
df102894=df102893.drop(['Indicator Name','Unnamed: 0'],axis=1)
df103255=df103254.drop(['Indicator Name','Unnamed: 0'],axis=1)
df103616=df103615.drop(['Indicator Name','Unnamed: 0'],axis=1)
df103977=df103976.drop(['Indicator Name','Unnamed: 0'],axis=1)
df104338=df104337.drop(['Indicator Name','Unnamed: 0'],axis=1)
df104699=df104698.drop(['Indicator Name','Unnamed: 0'],axis=1)
df105060=df105059.drop(['Indicator Name','Unnamed: 0'],axis=1)
df105421=df105420.drop(['Indicator Name','Unnamed: 0'],axis=1)
df105782=df105781.drop(['Indicator Name','Unnamed: 0'],axis=1)
df106143=df106142.drop(['Indicator Name','Unnamed: 0'],axis=1)
df106504=df106503.drop(['Indicator Name','Unnamed: 0'],axis=1)
df106865=df106864.drop(['Indicator Name','Unnamed: 0'],axis=1)
df107226=df107225.drop(['Indicator Name','Unnamed: 0'],axis=1)
df107587=df107586.drop(['Indicator Name','Unnamed: 0'],axis=1)
df107948=df107947.drop(['Indicator Name','Unnamed: 0'],axis=1)
df108309=df108308.drop(['Indicator Name','Unnamed: 0'],axis=1)
df108670=df108669.drop(['Indicator Name','Unnamed: 0'],axis=1)
df109031=df109030.drop(['Indicator Name','Unnamed: 0'],axis=1)
df109392=df109391.drop(['Indicator Name','Unnamed: 0'],axis=1)
df109753=df109752.drop(['Indicator Name','Unnamed: 0'],axis=1)
df110114=df110113.drop(['Indicator Name','Unnamed: 0'],axis=1)
df110475=df110474.drop(['Indicator Name','Unnamed: 0'],axis=1)
df110836=df110835.drop(['Indicator Name','Unnamed: 0'],axis=1)
df111197=df111196.drop(['Indicator Name','Unnamed: 0'],axis=1)
df111558=df111557.drop(['Indicator Name','Unnamed: 0'],axis=1)
df111919=df111918.drop(['Indicator Name','Unnamed: 0'],axis=1)
df112280=df112279.drop(['Indicator Name','Unnamed: 0'],axis=1)
df112641=df112640.drop(['Indicator Name','Unnamed: 0'],axis=1)
df113002=df113001.drop(['Indicator Name','Unnamed: 0'],axis=1)
df113363=df113362.drop(['Indicator Name','Unnamed: 0'],axis=1)
df113724=df113723.drop(['Indicator Name','Unnamed: 0'],axis=1)
df114085=df114084.drop(['Indicator Name','Unnamed: 0'],axis=1)
df114446=df114445.drop(['Indicator Name','Unnamed: 0'],axis=1)
df114807=df114806.drop(['Indicator Name','Unnamed: 0'],axis=1)
df115168=df115167.drop(['Indicator Name','Unnamed: 0'],axis=1)
df115529=df115528.drop(['Indicator Name','Unnamed: 0'],axis=1)
df115890=df115889.drop(['Indicator Name','Unnamed: 0'],axis=1)
df116251=df116250.drop(['Indicator Name','Unnamed: 0'],axis=1)
df116612=df116611.drop(['Indicator Name','Unnamed: 0'],axis=1)
df116973=df116972.drop(['Indicator Name','Unnamed: 0'],axis=1)
df117334=df117333.drop(['Indicator Name','Unnamed: 0'],axis=1)
df117695=df117694.drop(['Indicator Name','Unnamed: 0'],axis=1)
df118056=df118055.drop(['Indicator Name','Unnamed: 0'],axis=1)
df118417=df118416.drop(['Indicator Name','Unnamed: 0'],axis=1)
df118778=df118777.drop(['Indicator Name','Unnamed: 0'],axis=1)
df119139=df119138.drop(['Indicator Name','Unnamed: 0'],axis=1)
df119500=df119499.drop(['Indicator Name','Unnamed: 0'],axis=1)
df119861=df119860.drop(['Indicator Name','Unnamed: 0'],axis=1)
df120222=df120221.drop(['Indicator Name','Unnamed: 0'],axis=1)
df120583=df120582.drop(['Indicator Name','Unnamed: 0'],axis=1)
df120944=df120943.drop(['Indicator Name','Unnamed: 0'],axis=1)
df121305=df121304.drop(['Indicator Name','Unnamed: 0'],axis=1)
df121666=df121665.drop(['Indicator Name','Unnamed: 0'],axis=1)
df122027=df122026.drop(['Indicator Name','Unnamed: 0'],axis=1)
df122388=df122387.drop(['Indicator Name','Unnamed: 0'],axis=1)
df122749=df122748.drop(['Indicator Name','Unnamed: 0'],axis=1)
df123110=df123109.drop(['Indicator Name','Unnamed: 0'],axis=1)
df123471=df123470.drop(['Indicator Name','Unnamed: 0'],axis=1)
df123832=df123831.drop(['Indicator Name','Unnamed: 0'],axis=1)
df124193=df124192.drop(['Indicator Name','Unnamed: 0'],axis=1)
df124554=df124553.drop(['Indicator Name','Unnamed: 0'],axis=1)
df124915=df124914.drop(['Indicator Name','Unnamed: 0'],axis=1)
df125276=df125275.drop(['Indicator Name','Unnamed: 0'],axis=1)
df125637=df125636.drop(['Indicator Name','Unnamed: 0'],axis=1)
df125998=df125997.drop(['Indicator Name','Unnamed: 0'],axis=1)
df126359=df126358.drop(['Indicator Name','Unnamed: 0'],axis=1)
df126720=df126719.drop(['Indicator Name','Unnamed: 0'],axis=1)
df127081=df127080.drop(['Indicator Name','Unnamed: 0'],axis=1)
df127442=df127441.drop(['Indicator Name','Unnamed: 0'],axis=1)
df127803=df127802.drop(['Indicator Name','Unnamed: 0'],axis=1)
df128164=df128163.drop(['Indicator Name','Unnamed: 0'],axis=1)
df128525=df128524.drop(['Indicator Name','Unnamed: 0'],axis=1)
df128886=df128885.drop(['Indicator Name','Unnamed: 0'],axis=1)
df129247=df129246.drop(['Indicator Name','Unnamed: 0'],axis=1)
df129608=df129607.drop(['Indicator Name','Unnamed: 0'],axis=1)
df129969=df129968.drop(['Indicator Name','Unnamed: 0'],axis=1)

# %% [markdown]
# Now reduced to two columns ready for simple merging

# %%
df129608.head(10)
# Out:
#                Area Name  \
# 0             Hartlepool
# 1          Middlesbrough
# 2   Redcar and Cleveland
# 3       Stockton-on-Tees
# 4             Darlington
# 5                 Halton
# 6             Warrington
# 7  Blackburn with Darwen
# 8              Blackpool
# 9     Kingston upon Hull
#
#    Initiation or continuation of PrEP among those with PrEP need
# 0                                              44.78
# 1                                              34.01
# 2                                              46.81
# 3                                              32.89
# 4                                              48.68
# 5                                              73.40
# 6                                              63.89
# 7                                              65.57
# 8                                              54.63
# 9                                              62.33

# %% [markdown]
# Step 14: rename dfs to their indicator codes

# %%
df108=df9
df212=df370
df219=df731
df273=df1092
df848=df1453
df1203=df1814
df1204=df2175
df1205=df2536
df1206=df2897
df1208=df3258
df1730=df3619
df10101=df3980
df10301=df4341
df11001=df4702
df11201=df5063
df11202=df5424
df11401=df5785
df11501=df6146
df11601=df6507
df848.to_csv(os.path.join(folder_name,"Depression: QOF prevalence (18+ yrs).csv"), index=False)
df1203.to_csv(os.path.join(folder_name,"Mortality rate from lung cancer.csv"), index=False)
df1204.to_csv(os.path.join(folder_name,"Mortality rate from chronic obstructive pulmonary disease.csv"), index=False)
df1205.to_csv(os.path.join(folder_name,"Lung cancer registrations.csv"), index=False)
df1206.to_csv(os.path.join(folder_name,"Oral cancer registrations.csv"), index=False)
df1208.to_csv(os.path.join(folder_name,"Cost per capita of smoking attributable hospital admissions.csv"), index=False)
df1730.to_csv(os.path.join(folder_name,"Percentage people living in 20% most deprived areas in England.csv"), index=False)
df10101.to_csv(os.path.join(folder_name,"Children in low income families (under 16s).csv"), index=False)
df10301.to_csv(os.path.join(folder_name,"Pupil absence.csv"), index=False)
df11001.to_csv(os.path.join(folder_name,"Killed and seriously injured (KSI) casualties on Englands roads (historic data).csv"), index=False)
df11201.to_csv(os.path.join(folder_name,"Violent crime - hospital admissions for violence (including sexual violence).csv"), index=False)
df11202.to_csv(os.path.join(folder_name,"Violent crime - violence offences per 1,000 population.csv"), index=False)
df11401.to_csv(os.path.join(folder_name,"The rate of complaints about noise.csv"), index=False)
df11501.to_csv(os.path.join(folder_name,"Statutory homelessness: rate per 1,000 households.csv"), index=False)
df11601.to_csv(os.path.join(folder_name,"Utilisation of outdoor space for exercise or health reasons.csv"), index=False)
df20101.to_csv(os.path.join(folder_name,"Low birth weight of term babies.csv"), index=False)
df20401.to_csv(os.path.join(folder_name,"Under 18s conception rate per 1,000.csv"), index=False)
df20601.to_csv(os.path.join(folder_name,"Reception: Prevalence of overweight (including obesity).csv"), index=False)
df20602.to_csv(os.path.join(folder_name,"Year 6: Prevalence of overweight (including obesity).csv"), index=False)
df21001.to_csv(os.path.join(folder_name,"Emergency Hospital Admissions for Intentional Self-Harm.csv"), index=False)
df22001.to_csv(os.path.join(folder_name,"Cancer screening coverage: breast cancer.csv"), index=False)
df22401.to_csv(os.path.join(folder_name,"Emergency hospital admissions due to falls in people aged 65 and over.csv"), index=False)
df22402.to_csv(os.path.join(folder_name,"Emergency hospital admissions due to falls in people aged 65-79.csv"), index=False)
df22403.to_csv(os.path.join(folder_name,"Emergency hospital admissions due to falls in people aged 80+.csv"), index=False)
df30101.to_csv(os.path.join(folder_name,"Fraction of mortality attributable to particulate air pollution (old method).csv"), index=False)
df40401.to_csv(os.path.join(folder_name,"Under 75 mortality rate from all cardiovascular diseases.csv"), index=False)
df40501.to_csv(os.path.join(folder_name,"Under 75 mortality rate from cancer.csv"), index=False)
df40601.to_csv(os.path.join(folder_name,"Under 75 mortality rate from liver disease.csv"), index=False)
df40701.to_csv(os.path.join(folder_name,"Under 75 mortality rate from respiratory disease.csv"), index=False)
df41001.to_csv(os.path.join(folder_name,"Suicide rate.csv"), index=False)
df41101.to_csv(os.path.join(folder_name,"Emergency readmissions within 30 days of discharge from hospital.csv"), index=False)
df41401.to_csv(os.path.join(folder_name,"Hip fractures in people aged 65 and over.csv"), index=False)
df41402.to_csv(os.path.join(folder_name,"Hip fractures in people aged 65-79.csv"), index=False)
df41403.to_csv(os.path.join(folder_name,"Hip fractures in people aged 80+.csv"), index=False)
df90282.to_csv(os.path.join(folder_name,"Gap in the employment rate between those with a physical or mental long term health condition (aged 16 to 64) and the overall employment rate.csv"), index=False)
df90284.to_csv(os.path.join(folder_name,"Hospital admissions caused by unintentional and deliberate injuries in children (aged 0-14 years).csv"), index=False)
df90285.to_csv(os.path.join(folder_name,"Hospital admissions caused by unintentional and deliberate injuries in young people (aged 15-24 years).csv"), index=False)
df90286.to_csv(os.path.join(folder_name,"Sickness absence - the percentage of employees who had at least one day off in the previous week.csv"), index=False)
df90287.to_csv(os.path.join(folder_name,"Sickness absence - the percentage of working days lost due to sickness absence.csv"), index=False)
df90290.to_csv(os.path.join(folder_name,"Participation rate: Reception.csv"), index=False)
df90291.to_csv(os.path.join(folder_name,"Participation rate: Year 6.csv"), index=False)
df90292.to_csv(os.path.join(folder_name,"Participation rate: Total.csv"), index=False)
df90312.to_csv(os.path.join(folder_name,"Records with valid ethnicity code.csv"), index=False)
df90313.to_csv(os.path.join(folder_name,"Records with valid child postcode.csv"), index=False)
df90314.to_csv(os.path.join(folder_name,"Records with height rounded to X.0 or X.5.csv"), index=False)
df90315.to_csv(os.path.join(folder_name,"Records with weight rounded to X.0 or X.5.csv"), index=False)
df90316.to_csv(os.path.join(folder_name,"Reception: Prevalence of underweight.csv"), index=False)
df90317.to_csv(os.path.join(folder_name,"Reception: Prevalence of healthy weight.csv"), index=False)
df90319.to_csv(os.path.join(folder_name,"Reception: Prevalence of obesity (including severe obesity).csv"), index=False)
df90320.to_csv(os.path.join(folder_name,"Year 6: Prevalence of underweight.csv"), index=False)
df90321.to_csv(os.path.join(folder_name,"Year 6: Prevalence of healthy weight.csv"), index=False)
df90323.to_csv(os.path.join(folder_name,"Year 6: Prevalence of obesity (including severe obesity).csv"), index=False)
df90356.to_csv(os.path.join(folder_name,"Fuel poverty (low income, high cost methodology).csv"), index=False)
df90360.to_csv(os.path.join(folder_name,"Excess winter deaths index.csv"), index=False)
df90361.to_csv(os.path.join(folder_name,"Excess winter deaths index (age 85+).csv"), index=False)
df90366.to_csv(os.path.join(folder_name,"Life expectancy at birth.csv"), index=False)
df90371.to_csv(os.path.join(folder_name,"New cases of psychosis: estimated incidence rate per 100,000 population aged 16-64.csv"), index=False)
df90411.to_csv(os.path.join(folder_name,"Unpaid carers.csv"), index=False)
df90416.to_csv(os.path.join(folder_name,"Overcrowded households.csv"), index=False)
df90443.to_csv(os.path.join(folder_name,"Osteoporosis: QOF prevalence (50+ yrs).csv"), index=False)
df90630.to_csv(os.path.join(folder_name,"Children in low income families (all dependent children under 20).csv"), index=False)
df90637.to_csv(os.path.join(folder_name,"Violent crime - sexual offences per 1,000 population.csv"), index=False)
df90656.to_csv(os.path.join(folder_name,"Migrant GP registrations: rate per 1,000 population.csv"), index=False)
df90729.to_csv(os.path.join(folder_name,"Genital warts diagnostic rate per 100,000.csv"), index=False)
df90731.to_csv(os.path.join(folder_name,"Under 18s conceptions leading to abortion (%).csv"), index=False)
df90739.to_csv(os.path.join(folder_name,"Pelvic inflammatory disease (PID) admissions rate per 100,000.csv"), index=False)
df90740.to_csv(os.path.join(folder_name,"Ectopic pregnancy admissions rate per 100,000.csv"), index=False)
df90742.to_csv(os.path.join(folder_name,"Syphilis diagnostic rate per 100,000.csv"), index=False)
df90759.to_csv(os.path.join(folder_name,"Gonorrhoea diagnostic rate per 100,000.csv"), index=False)
df90776.to_csv(os.path.join(folder_name,"Chlamydia detection rate per 100,000 aged 15 to 24.csv"), index=False)
df90777.to_csv(os.path.join(folder_name,"Chlamydia proportion aged 15 to 24 screened.csv"), index=False)
df90790.to_csv(os.path.join(folder_name,"HIV diagnosed prevalence rate per 1,000 aged 15 to 59.csv"), index=False)
df90791.to_csv(os.path.join(folder_name,"HIV late diagnosis in people first diagnosed with HIV in the UK.csv"), index=False)
df90804.to_csv(os.path.join(folder_name,"Children killed and seriously injured (KSI) on Englands roads.csv"), index=False)
df90832.to_csv(os.path.join(folder_name,"Hospital admissions caused by unintentional and deliberate injuries in children (aged 0-4 years).csv"), index=False)
df90851.to_csv(os.path.join(folder_name,"The percentage of people resident in the area living in each national deprivation quintile.csv"), index=False)
df90892.to_csv(os.path.join(folder_name,"Hospital admission rate due to liver disease.csv"), index=False)
df91046.to_csv(os.path.join(folder_name,"Genital herpes diagnosis rate per 100,000.csv"), index=False)
df91048.to_csv(os.path.join(folder_name,"HIV testing coverage, women.csv"), index=False)
df91049.to_csv(os.path.join(folder_name,"HIV testing coverage, gay, bisexual and other men who have sex with men.csv"), index=False)
df91050.to_csv(os.path.join(folder_name,"HIV testing coverage, men.csv"), index=False)
df91102.to_csv(os.path.join(folder_name,"Life expectancy at 65.csv"), index=False)
df91126.to_csv(os.path.join(folder_name,"Unemployment (model-based).csv"), index=False)
df91133.to_csv(os.path.join(folder_name,"Long term claimants of Jobseekers Allowance.csv"), index=False)
df91143.to_csv(os.path.join(folder_name,"Young people providing 20+ hoursperweek of unpaid care (aged 16-24).csv"), index=False)
df91155.to_csv(os.path.join(folder_name,"Children providing unpaid care (aged 0-15).csv"), index=False)
df91156.to_csv(os.path.join(folder_name,"Young people providing unpaid care (aged 16-24).csv"), index=False)
df91163.to_csv(os.path.join(folder_name,"Under 75 mortality rate from colorectal cancer.csv"), index=False)
df91164.to_csv(os.path.join(folder_name,"Under 75 mortality rate from breast cancer.csv"), index=False)
df91165.to_csv(os.path.join(folder_name,"Under 75 mortality rate from injuries.csv"), index=False)
df91166.to_csv(os.path.join(folder_name,"Under 75 mortality rate from heart disease.csv"), index=False)
df91167.to_csv(os.path.join(folder_name,"Under 75 mortality rate from stroke.csv"), index=False)
df91195.to_csv(os.path.join(folder_name,"Health related quality of life for older people.csv"), index=False)
df91269.to_csv(os.path.join(folder_name,"Rheumatoid Arthritis: QOF prevalence (16+ yrs).csv"), index=False)
df91306.to_csv(os.path.join(folder_name,"New STI diagnoses (excluding chlamydia aged under 25) per 100,000.csv"), index=False)
df91307.to_csv(os.path.join(folder_name,"STI testing rate (exclude chlamydia aged under 25) per 100,000.csv"), index=False)
df91308.to_csv(os.path.join(folder_name,"STI testing positivity (excluding chlamydia aged under 25).csv"), index=False)
df91361.to_csv(os.path.join(folder_name,"TB incidence (three year average).csv"), index=False)
df91367.to_csv(os.path.join(folder_name,"Proportion of drug sensitive TB cases who had completed a full course of treatment by 12 months.csv"), index=False)
df91380.to_csv(os.path.join(folder_name,"Alcohol-specific mortality.csv"), index=False)
df91381.to_csv(os.path.join(folder_name,"Mortality from chronic liver disease.csv"), index=False)
df91458.to_csv(os.path.join(folder_name,"Under 18s births rate per 1,000.csv"), index=False)
df91493.to_csv(os.path.join(folder_name,"Percentage with a mean daily sedentary time in the last week over 7 hours per day at age 15.csv"), index=False)
df91494.to_csv(os.path.join(folder_name,"Percentage physically active for at least one hour per day seven days a week at age 15.csv"), index=False)
df91514.to_csv(os.path.join(folder_name,"Chlamydia detection rate per 100,000 aged 15 to 24.csv"), index=False)
df91521.to_csv(os.path.join(folder_name,"Chlamydia diagnostic rate per 100,000.csv"), index=False)
df91522.to_csv(os.path.join(folder_name,"Chlamydia diagnostic rate per 100,000 aged 25 years and older.csv"), index=False)
df91523.to_csv(os.path.join(folder_name,"All new STI diagnoses rate per 100,000.csv"), index=False)
df91525.to_csv(os.path.join(folder_name,"HIV testing coverage, total.csv"), index=False)
df91547.to_csv(os.path.join(folder_name,"Smoking prevalence in adults (15+) - current smokers (QOF).csv"), index=False)
df91720.to_csv(os.path.join(folder_name,"Cancer screening coverage: bowel cancer.csv"), index=False)
df91743.to_csv(os.path.join(folder_name,"Premature births (less than 37 weeks gestation).csv"), index=False)
df91818.to_csv(os.path.join(folder_name,"New HIV diagnosis rate per 100,000.csv"), index=False)
df91819.to_csv(os.path.join(folder_name,"GP prescribed LARC excluding injections rate per 1,000.csv"), index=False)
df91872.to_csv(os.path.join(folder_name,"Deprivation score (IMD 2015).csv"), index=False)
df92026.to_csv(os.path.join(folder_name,"Reception: Prevalence of obesity (including severe obesity), 5-years data combined.csv"), index=False)
df92033.to_csv(os.path.join(folder_name,"Year 6: Prevalence of obesity (including severe obesity), 5-years data combined.csv"), index=False)
df92196.to_csv(os.path.join(folder_name,"Infant mortality rate.csv"), index=False)
df92199.to_csv(os.path.join(folder_name,"Educational attainment (5 or more GCSEs): % of all children.csv"), index=False)
df92254.to_csv(os.path.join(folder_name,"Total prescribed LARC excluding injections rate per 1,000.csv"), index=False)
df92255.to_csv(os.path.join(folder_name,"SRH Services prescribed LARC excluding injections rate per 1,000.csv"), index=False)
df92290.to_csv(os.path.join(folder_name,"Women choose injections at SRH Services (%).csv"), index=False)
df92291.to_csv(os.path.join(folder_name,"Women choose user-dependent methods at SRH Services (%).csv"), index=False)
df92292.to_csv(os.path.join(folder_name,"Women choose hormonal short-acting contraceptives at SRH Services (%).csv"), index=False)
df92293.to_csv(os.path.join(folder_name,"Under 25s choose LARC excluding injections at SRH Services (%).csv"), index=False)
df92294.to_csv(os.path.join(folder_name,"Over 25s  choose LARC excluding injections at SRH Services (%).csv"), index=False)
df92302.to_csv(os.path.join(folder_name,"Emergency hospital admissions for COPD.csv"), index=False)
df92304.to_csv(os.path.join(folder_name,"Smoking prevalence in adults (18+) - current smokers (GPPS).csv"), index=False)
df92306.to_csv(os.path.join(folder_name,"Smoking prevalence in adults (18+) - ex smoker (GPPS).csv"), index=False)
df92308.to_csv(os.path.join(folder_name,"Smoking prevalence in adults (18+) - never smoked (GPPS).csv"), index=False)
df92309.to_csv(os.path.join(folder_name,"Supporting information - % population aged under 18.csv"), index=False)
df92310.to_csv(os.path.join(folder_name,"Supporting information - % population aged 65+.csv"), index=False)
df92313.to_csv(os.path.join(folder_name,"Percentage of people in employment.csv"), index=False)
df92317.to_csv(os.path.join(folder_name,"Abdominal Aortic Aneurysm Screening Coverage.csv"), index=False)
df92323.to_csv(os.path.join(folder_name,"Incidence rate of alcohol-related cancer.csv"), index=False)
df92326.to_csv(os.path.join(folder_name,"Mortality rate from a range of specified communicable diseases, including influenza.csv"), index=False)
df92432.to_csv(os.path.join(folder_name,"Deaths from drug misuse.csv"), index=False)
df92443.to_csv(os.path.join(folder_name,"Smoking Prevalence in adults (18+) - current smokers (APS).csv"), index=False)
df92445.to_csv(os.path.join(folder_name,"Smoking prevalence in adults in routine and manual occupations (18-64) - current smokers (APS).csv"), index=False)
df92453.to_csv(os.path.join(folder_name,"0.csv"), index=False)
df92464.to_csv(os.path.join(folder_name,"Reception: Prevalence of overweight.csv"), index=False)
df92465.to_csv(os.path.join(folder_name,"Year 6: Prevalence of overweight.csv"), index=False)
df92488.to_csv(os.path.join(folder_name,"Mortality rate from causes considered preventable (2016 definition).csv"), index=False)
df92489.to_csv(os.path.join(folder_name,"Care home beds per 100 people 75+.csv"), index=False)
df92490.to_csv(os.path.join(folder_name,"Nursing home beds per 100 people 75+.csv"), index=False)
df92534.to_csv(os.path.join(folder_name,"Smoking Prevalence in adults (18+) - ex smokers (APS).csv"), index=False)
df92538.to_csv(os.path.join(folder_name,"Smoking Prevalence in adults (18+) - never smoked (APS).csv"), index=False)
df92635.to_csv(os.path.join(folder_name,"Crime deprivation: score.csv"), index=False)
df92670.to_csv(os.path.join(folder_name,"Adjusted antibiotic prescribing in primary care by the NHS.csv"), index=False)
df92708.to_csv(os.path.join(folder_name,"Resident population.csv"), index=False)
df92718.to_csv(os.path.join(folder_name,"Mortality rate from all cardiovascular diseases, ages 65+ years.csv"), index=False)
df92724.to_csv(os.path.join(folder_name,"Mortality rate from cancer, ages 65+ years.csv"), index=False)
df92725.to_csv(os.path.join(folder_name,"Mortality rate from respiratory disease, ages 65+ years.csv"), index=False)
df92763.to_csv(os.path.join(folder_name,"Volume of pure alcohol sold through the off-trade: all alcohol sales.csv"), index=False)
df92765.to_csv(os.path.join(folder_name,"Volume of pure alcohol sold through the off-trade: beer sales.csv"), index=False)
df92768.to_csv(os.path.join(folder_name,"Volume of pure alcohol sold through the off-trade: wine sales.csv"), index=False)
df92770.to_csv(os.path.join(folder_name,"Volume of pure alcohol sold through the off-trade: spirit sales.csv"), index=False)
df92772.to_csv(os.path.join(folder_name,"Number of premises licensed to sell alcohol per square kilometre.csv"), index=False)
df92841.to_csv(os.path.join(folder_name,"Typhoid & paratyphoid incidence rateper100,000.csv"), index=False)
df92860.to_csv(os.path.join(folder_name,"Supporting information - % population from ethnic minorities.csv"), index=False)
df92899.to_csv(os.path.join(folder_name,"Economic inactivity rate.csv"), index=False)
df92901.to_csv(os.path.join(folder_name,"Inequality in life expectancy at birth.csv"), index=False)
df92904.to_csv(os.path.join(folder_name,"Admission episodes for alcohol-specific conditions - Under 18s.csv"), index=False)
df92906.to_csv(os.path.join(folder_name,"Admission episodes for alcohol-specific conditions.csv"), index=False)
df92924.to_csv(os.path.join(folder_name,"Air pollution: fine particulate matter (historic indicator).csv"), index=False)
df92937.to_csv(os.path.join(folder_name,"Density of fast food outlets.csv"), index=False)
df92949.to_csv(os.path.join(folder_name,"Estimated dementia diagnosis rate (aged 65 and over).csv"), index=False)
df92953.to_csv(os.path.join(folder_name,"Mortality rate from oral cancer.csv"), index=False)
df93014.to_csv(os.path.join(folder_name,"Percentage of physically active adults.csv"), index=False)
df93015.to_csv(os.path.join(folder_name,"Percentage of physically inactive adults.csv"), index=False)
df93074.to_csv(os.path.join(folder_name,"Access to Healthy Assets & Hazards Index.csv"), index=False)
df93077.to_csv(os.path.join(folder_name,"Proportion of the population meeting the recommended 5-a-day on a usual day (adults).csv"), index=False)
df93081.to_csv(os.path.join(folder_name,"Percentage of the total resident population who are 65 and over.csv"), index=False)
df93082.to_csv(os.path.join(folder_name,"Percentage of the total resident population who are 25 to 64 years of age.csv"), index=False)
df93083.to_csv(os.path.join(folder_name,"Percentage of the total resident population who are 16 to 24 years of age.csv"), index=False)
df93084.to_csv(os.path.join(folder_name,"Percentage of the total resident population who are 0 to 15 years of age.csv"), index=False)
df93085.to_csv(os.path.join(folder_name,"Smoking status at time of delivery.csv"), index=False)
df93086.to_csv(os.path.join(folder_name,"Back pain prevalence in people of all ages.csv"), index=False)
df93087.to_csv(os.path.join(folder_name,"Percentage of population whose ethnicity is not White UK.csv"), index=False)
df93088.to_csv(os.path.join(folder_name,"Percentage of adults (aged 18+) classified as overweight or obese.csv"), index=False)
df93089.to_csv(os.path.join(folder_name,"General fertility rate: live births per 1,000 women aged 15-44 years. five year pooled.csv"), index=False)
df93091.to_csv(os.path.join(folder_name,"Prevalence of severe hip osteoarthritis in people aged  45 and over.csv"), index=False)
df93092.to_csv(os.path.join(folder_name,"Low birth weight of live babies, five year pooled.csv"), index=False)
df93093.to_csv(os.path.join(folder_name,"Prevalence of hip osteoarthritis in people aged  45 and over.csv"), index=False)
df93094.to_csv(os.path.join(folder_name,"Child Poverty, Income deprivation affecting children index (IDACI).csv"), index=False)
df93095.to_csv(os.path.join(folder_name,"Prevalence of severe knee osteoarthritis in people aged  45 and over.csv"), index=False)
df93096.to_csv(os.path.join(folder_name,"Prevalence of knee osteoarthritis in people aged  45 and over.csv"), index=False)
df93097.to_csv(os.path.join(folder_name,"Unemployment (Percentage of the working age population claiming out of work benefit).csv"), index=False)
df93098.to_csv(os.path.join(folder_name,"Long-Term Unemployment- rate per 1,000 working age population.csv"), index=False)
df93103.to_csv(os.path.join(folder_name,"Older people living alone, % of people aged 65 and over who are living alone.csv"), index=False)
df93104.to_csv(os.path.join(folder_name,"Employment and Support Allowance claimants.csv"), index=False)
df93105.to_csv(os.path.join(folder_name,"Reception: Prevalence of obesity (including severe obesity), 3-years data combined.csv"), index=False)
df93106.to_csv(os.path.join(folder_name,"Reception: Prevalence of overweight (including obesity), 3-years data combined.csv"), index=False)
df93107.to_csv(os.path.join(folder_name,"Year 6: Prevalence of obesity (including severe obesity), 3-years data combined.csv"), index=False)
df93108.to_csv(os.path.join(folder_name,"Year 6: Prevalence of overweight (including obesity), 3-years data combined.csv"), index=False)
df93111.to_csv(os.path.join(folder_name,"Affordability of home ownership.csv"), index=False)
df93113.to_csv(os.path.join(folder_name,"Deliveries to teenage mothers.csv"), index=False)
df93114.to_csv(os.path.join(folder_name,"Emergency hospital admissions for injuries in under 5 years old, crude rate.csv"), index=False)
df93115.to_csv(os.path.join(folder_name,"Emergency hospital admissions in under 5 years old, crude rate.csv"), index=False)
df93119.to_csv(os.path.join(folder_name,"Measles incidence rateper100,000.csv"), index=False)
df93120.to_csv(os.path.join(folder_name,"Measles 5-year incidence rateper100,000.csv"), index=False)
df93124.to_csv(os.path.join(folder_name,"Acute hepatitis B incidence rateper100,000.csv"), index=False)
df93177.to_csv(os.path.join(folder_name,"Hepatitis C detection rateper100,000.csv"), index=False)
df93190.to_csv(os.path.join(folder_name,"Inequality in life expectancy at 65.csv"), index=False)
df93194.to_csv(os.path.join(folder_name,"Reception: Prevalence of severe obesity.csv"), index=False)
df93195.to_csv(os.path.join(folder_name,"Year 6: Prevalence of severe obesity.csv"), index=False)
df93219.to_csv(os.path.join(folder_name,"Emergency hospital admissions for injuries in under 15 years old, crude rate.csv"), index=False)
df93224.to_csv(os.path.join(folder_name,"Emergency hospital admissions for injuries in 15 to 24 years old, crude rate.csv"), index=False)
df93226.to_csv(os.path.join(folder_name,"Percentage of the total resident population aged 85 and over.csv"), index=False)
df93227.to_csv(os.path.join(folder_name,"Emergency hospital admissions for all causes, all ages, standardised admission ratio.csv"), index=False)
df93229.to_csv(os.path.join(folder_name,"Emergency hospital admissions for coronary heart disease, standardised admission ratio.csv"), index=False)
df93231.to_csv(os.path.join(folder_name,"Emergency hospital admissions for stroke, standardised admission ratio.csv"), index=False)
df93232.to_csv(os.path.join(folder_name,"Emergency hospital admissions for Myocardial Infarction (heart attack), standardised admission ratio.csv"), index=False)
df93233.to_csv(os.path.join(folder_name,"Emergency hospital admissions for Chronic Obstructive Pulmonary Disease (COPD), standardised admission ratio.csv"), index=False)
df93234.to_csv(os.path.join(folder_name,"Incidence of all cancers, standardised incidence ratio.csv"), index=False)
df93235.to_csv(os.path.join(folder_name,"Incidence of breast cancer, standardised incidence ratio.csv"), index=False)
df93236.to_csv(os.path.join(folder_name,"Incidence of colorectal cancer, standardised incidence ratio.csv"), index=False)
df93237.to_csv(os.path.join(folder_name,"Incidence of lung cancer, standardised incidence ratio.csv"), index=False)
df93238.to_csv(os.path.join(folder_name,"Incidence of prostate cancer, standardised incidence ratio.csv"), index=False)
df93239.to_csv(os.path.join(folder_name,"Emergency hospital admissions for intentional self harm, standardised admission ratio.csv"), index=False)
df93240.to_csv(os.path.join(folder_name,"Hospital admissions for alcohol attributable conditions, (Narrow definition).csv"), index=False)
df93241.to_csv(os.path.join(folder_name,"Emergency hospital admissions for hip fracture in persons 65 years and over, standardised admission ratio.csv"), index=False)
df93250.to_csv(os.path.join(folder_name,"Deaths from all causes, all ages, standardised mortality ratio.csv"), index=False)
df93252.to_csv(os.path.join(folder_name,"Deaths from all causes, under 75 years, standardised mortality ratio.csv"), index=False)
df93253.to_csv(os.path.join(folder_name,"Deaths from all cancer, all ages, standardised mortality ratio.csv"), index=False)
df93254.to_csv(os.path.join(folder_name,"Deaths from all cancer, under 75 years, standardised mortality ratio (SMR).csv"), index=False)
df93255.to_csv(os.path.join(folder_name,"Deaths from circulatory disease, all ages, standardised mortality ratio.csv"), index=False)
df93256.to_csv(os.path.join(folder_name,"Deaths from circulatory disease, under 75 years, standardised mortality ratio.csv"), index=False)
df93257.to_csv(os.path.join(folder_name,"Deaths from coronary heart disease, all ages, standardised mortality ratio.csv"), index=False)
df93259.to_csv(os.path.join(folder_name,"Deaths from stroke, all ages, standardised mortality ratio.csv"), index=False)
df93260.to_csv(os.path.join(folder_name,"Deaths from respiratory diseases, all ages, standardised mortality ratio.csv"), index=False)
df93267.to_csv(os.path.join(folder_name,"Percentage of population whose ethnic group is not white.csv"), index=False)
df93268.to_csv(os.path.join(folder_name,"Income deprivation, English Indices of Deprivation.csv"), index=False)
df93274.to_csv(os.path.join(folder_name,"The percentage of people that cannot speak English well or at all,  2011.csv"), index=False)
df93275.to_csv(os.path.join(folder_name,"Index of Multiple Deprivation (IMD) Score.csv"), index=False)
df93276.to_csv(os.path.join(folder_name,"Percentage of people who reported having a limiting long term illness or disability.csv"), index=False)
df93277.to_csv(os.path.join(folder_name,"Households with overcrowding based on overall room occupancy levels.csv"), index=False)
df93279.to_csv(os.path.join(folder_name,"Older people in poverty: Income deprivation affecting older people Index (IDAOPI).csv"), index=False)
df93280.to_csv(os.path.join(folder_name,"Modelled estimates of the proportion of households in fuel poverty (%).csv"), index=False)
df93283.to_csv(os.path.join(folder_name,"Life expectancy at birth, (upper age band 90 and over).csv"), index=False)
df93311.to_csv(os.path.join(folder_name,"Under 25s individuals attend specialist contraceptive services rate per 1000 - Females.csv"), index=False)
df93312.to_csv(os.path.join(folder_name,"Under 25s individuals attend specialist contraceptive services rate per 1000 - Males.csv"), index=False)
df93315.to_csv(os.path.join(folder_name,"STEC  (Shiga toxin-producing Escherichia coli) serogroup O157 5-year incidence rateper100,000.csv"), index=False)
df93316.to_csv(os.path.join(folder_name,"STEC (Shiga toxin-producing Escherichia coli) serogroup O157 incidence rateper100,000.csv"), index=False)
df93347.to_csv(os.path.join(folder_name,"Estimated diabetes diagnosis rate.csv"), index=False)
df93350.to_csv(os.path.join(folder_name,"Gender pay gap (by workplace location).csv"), index=False)
df93351.to_csv(os.path.join(folder_name,"Average weekly earnings.csv"), index=False)
df93353.to_csv(os.path.join(folder_name,"Job density.csv"), index=False)
df93355.to_csv(os.path.join(folder_name,"Non-typhoidal Salmonella incidence rateper100,000.csv"), index=False)
df93356.to_csv(os.path.join(folder_name,"Campylobacter incidence rateper100,000.csv"), index=False)
df93357.to_csv(os.path.join(folder_name,"Shigella incidence rateper100,000.csv"), index=False)
df93372.to_csv(os.path.join(folder_name,"% reporting a long term MSK problem who also report depression or anxiety.csv"), index=False)
df93375.to_csv(os.path.join(folder_name,"Average health related quality of life score for adults who reported having a long term MSK problem..csv"), index=False)
df93376.to_csv(os.path.join(folder_name,"% reporting depression or anxiety.csv"), index=False)
df93377.to_csv(os.path.join(folder_name,"Percentage reporting a long-term Musculoskeletal (MSK) problem.csv"), index=False)
df93378.to_csv(os.path.join(folder_name,"Average Attainment 8 score.csv"), index=False)
df93379.to_csv(os.path.join(folder_name,"Giardia incidence rateper100,000.csv"), index=False)
df93380.to_csv(os.path.join(folder_name,"Cryptosporidium incidence rateper100,000.csv"), index=False)
df93382.to_csv(os.path.join(folder_name,"Odds of current smoking (self-reported) among adults aged 18-64 with a routine and manual occupation (APS).csv"), index=False)
df93383.to_csv(os.path.join(folder_name,"Oesophageal cancer registrations.csv"), index=False)
df93439.to_csv(os.path.join(folder_name,"Percentage of adults walking for travel at least three days per week.csv"), index=False)
df93440.to_csv(os.path.join(folder_name,"Percentage of adults cycling for travel at least three days per week.csv"), index=False)
df93453.to_csv(os.path.join(folder_name,"Percentage reporting at least two long-term conditions, at least one of which is MSK related.csv"), index=False)
df93454.to_csv(os.path.join(folder_name,"Smoking prevalence in adults with a long term mental health condition (18+) - current smokers (GPPS).csv"), index=False)
df93455.to_csv(os.path.join(folder_name,"Smoking prevalence in adults with anxiety or depression (18+) - current smokers (GPPS).csv"), index=False)
df93456.to_csv(os.path.join(folder_name,"Listeria incidence rateper100,000.csv"), index=False)
df93463.to_csv(os.path.join(folder_name,"Scarlet fever notification rateper100,000 aged 0-9 yrs.csv"), index=False)
df93465.to_csv(os.path.join(folder_name,"Hospital admissions for alcohol attributable conditions, (Broad definition).csv"), index=False)
df93466.to_csv(os.path.join(folder_name,"Mumps incidence rateper100,000.csv"), index=False)
df93467.to_csv(os.path.join(folder_name,"Mumps 5-year incidence rateper100,000.csv"), index=False)
df93474.to_csv(os.path.join(folder_name,"Percentage of deaths that occur in hospital.csv"), index=False)
df93475.to_csv(os.path.join(folder_name,"Percentage of deaths that occur in care homes.csv"), index=False)
df93476.to_csv(os.path.join(folder_name,"Percentage of deaths that occur at home.csv"), index=False)
df93477.to_csv(os.path.join(folder_name,"Percentage of deaths that occur in other places.csv"), index=False)
df93478.to_csv(os.path.join(folder_name,"Percentage of deaths that occur in hospice.csv"), index=False)
df93480.to_csv(os.path.join(folder_name,"Deaths from causes considered preventable, under 75 years, standardised mortality ratio.csv"), index=False)
df93488.to_csv(os.path.join(folder_name,"Smoking prevalence at age 15 - regular smokers (modelled estimates).csv"), index=False)
df93489.to_csv(os.path.join(folder_name,"Smoking prevalence at age 15 - regular or occasional smokers (modelled estimates).csv"), index=False)
df93491.to_csv(os.path.join(folder_name,"Listeria 5-year incidence rateper100,000.csv"), index=False)
df93495.to_csv(os.path.join(folder_name,"Estimated prevalence of common mental disorders: % of population aged 16 & over.csv"), index=False)
df93496.to_csv(os.path.join(folder_name,"Estimated prevalence of common mental disorders: % of population aged 65 & over.csv"), index=False)
df93497.to_csv(os.path.join(folder_name,"Percentage of deaths with underlying cause Cancer.csv"), index=False)
df93498.to_csv(os.path.join(folder_name,"Percentage of deaths with underlying cause respiratory disease.csv"), index=False)
df93499.to_csv(os.path.join(folder_name,"Percentage of deaths with underlying cause circulatory disease.csv"), index=False)
df93506.to_csv(os.path.join(folder_name,"Percentage of all Deaths.csv"), index=False)
df93507.to_csv(os.path.join(folder_name,"Mortality Rate.csv"), index=False)
df93513.to_csv(os.path.join(folder_name,"Re-offending levels - percentage of offenders who re-offend.csv"), index=False)
df93515.to_csv(os.path.join(folder_name,"Pertussis incidence rateper100,000.csv"), index=False)
df93546.to_csv(os.path.join(folder_name,"Prompt antiretroviral therapy (ART) initiation in people newly diagnosed with HIV.csv"), index=False)
df93550.to_csv(os.path.join(folder_name,"Virological success in adults accessing HIV care.csv"), index=False)
df93551.to_csv(os.path.join(folder_name,"Repeat HIV testing in gay, bisexual and other men who have sex with men.csv"), index=False)
df93553.to_csv(os.path.join(folder_name,"Deprivation score (IMD 2019).csv"), index=False)
df93560.to_csv(os.path.join(folder_name,"Cancer screening coverage: cervical cancer (aged 25 to 49 years old).csv"), index=False)
df93561.to_csv(os.path.join(folder_name,"Cancer screening coverage: cervical cancer (aged 50 to 64 years old).csv"), index=False)
df93563.to_csv(os.path.join(folder_name,"Percentage of 5 year olds with experience of visually obvious dental decay.csv"), index=False)
df93570.to_csv(os.path.join(folder_name,"Percentage of physically active children and young people.csv"), index=False)
df93572.to_csv(os.path.join(folder_name,"Re-offending levels - average number of re-offences per re-offender.csv"), index=False)
df93580.to_csv(os.path.join(folder_name,"Babys first feed breastmilk.csv"), index=False)
df93604.to_csv(os.path.join(folder_name,"Invasive Meningococcal Disease (IMD) confirmed cases rateper100,000.csv"), index=False)
df93644.to_csv(os.path.join(folder_name,"Mortality rate from asthma.csv"), index=False)
df93670.to_csv(os.path.join(folder_name,"Odds of current smoking (self-reported) among adults aged 18+ diagnosed with a long-term mental health condition.csv"), index=False)
df93671.to_csv(os.path.join(folder_name,"Percentage of cancers diagnosed at stages 1 and 2.csv"), index=False)
df93691.to_csv(os.path.join(folder_name,"Population vaccination coverage: Flu (primary school aged children).csv"), index=False)
df93700.to_csv(os.path.join(folder_name,"Children in relative low income families (under 16s).csv"), index=False)
df93701.to_csv(os.path.join(folder_name,"Children in absolute low income families (under 16s).csv"), index=False)
df93720.to_csv(os.path.join(folder_name,"Under 75 mortality rate from liver disease considered preventable (2019 definition).csv"), index=False)
df93721.to_csv(os.path.join(folder_name,"Under 75 mortality rate from causes considered preventable (2019 definition).csv"), index=False)
df93722.to_csv(os.path.join(folder_name,"Under 75 mortality rate from cardiovascular diseases considered preventable (2019 definition).csv"), index=False)
df93723.to_csv(os.path.join(folder_name,"Under 75 mortality rate from cancer considered preventable (2019 definition).csv"), index=False)
df93724.to_csv(os.path.join(folder_name,"Under 75 mortality rate from respiratory disease considered preventable (2019 definition).csv"), index=False)
df93735.to_csv(os.path.join(folder_name,"Homelessness - households in temporary accommodation.csv"), index=False)
df93736.to_csv(os.path.join(folder_name,"Homelessness - households owed a duty under the Homelessness Reduction Act.csv"), index=False)
df93737.to_csv(os.path.join(folder_name,"Homelessness - households owed a duty under the Homelessness Reduction Act (main applicant 16-24 yrs).csv"), index=False)
df93738.to_csv(os.path.join(folder_name,"Homelessness - households owed a duty under the Homelessness Reduction Act (main applicant 55+ yrs).csv"), index=False)
df93739.to_csv(os.path.join(folder_name,"Homelessness - households with dependent children owed a duty under the Homelessness Reduction Act.csv"), index=False)
df93742.to_csv(os.path.join(folder_name,"Odds ratio of reporting a mental health condition among people with and without an MSK condition.csv"), index=False)
df93744.to_csv(os.path.join(folder_name,"Percentage of the total resident population who are 0 to 4 years of age.csv"), index=False)
df93745.to_csv(os.path.join(folder_name,"Percentage of the total resident population who are 5 to 15 years of age.csv"), index=False)
df93746.to_csv(os.path.join(folder_name,"Percentage of the total resident population who are 50 to 64 years of age.csv"), index=False)
df93747.to_csv(os.path.join(folder_name,"Population density, people per square kilometre.csv"), index=False)
df93748.to_csv(os.path.join(folder_name,"Smoking attributable mortality (new method).csv"), index=False)
df93750.to_csv(os.path.join(folder_name,"Smoking attributable deaths from heart disease (new method).csv"), index=False)
df93751.to_csv(os.path.join(folder_name,"Smoking attributable deaths from stroke (new method).csv"), index=False)
df93753.to_csv(os.path.join(folder_name,"Smoking attributable hospital admissions (new method). This indicator uses new set of attributable fractions, and so differ from that originally published..csv"), index=False)
df93754.to_csv(os.path.join(folder_name,"Killed and seriously injured (KSI) casualties on Englands roads.csv"), index=False)
df93758.to_csv(os.path.join(folder_name,"Loneliness: Percentage of adults who feel lonely often per always or some of the time.csv"), index=False)
df93759.to_csv(os.path.join(folder_name,"Fuel poverty (low income, low energy efficiency methodology).csv"), index=False)
df93760.to_csv(os.path.join(folder_name,"Mycoplasma genitalium diagnostic rate per 100,000.csv"), index=False)
df93761.to_csv(os.path.join(folder_name,"Trichomoniasis diagnostic rate per 100,000.csv"), index=False)
df93763.to_csv(os.path.join(folder_name,"Alcohol-related mortality: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv"), index=False)
df93764.to_csv(os.path.join(folder_name,"Admission episodes for alcohol-related conditions (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv"), index=False)
df93765.to_csv(os.path.join(folder_name,"Admission episodes for alcohol-related conditions (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv"), index=False)
df93766.to_csv(os.path.join(folder_name,"Admission episodes for alcohol-related unintentional injuries (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv"), index=False)
df93767.to_csv(os.path.join(folder_name,"Admission episodes for mental and behavioural disorders due to use of alcohol (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv"), index=False)
df93768.to_csv(os.path.join(folder_name,"Admission episodes for intentional self-poisoning by and exposure to alcohol (Narrow): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv"), index=False)
df93769.to_csv(os.path.join(folder_name,"Admission episodes for alcohol-related cardiovascular disease (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv"), index=False)
df93770.to_csv(os.path.join(folder_name,"Admission episodes for mental and behavioural disorders due to use of alcohol (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv"), index=False)
df93771.to_csv(os.path.join(folder_name,"Admission episodes for alcoholic liver disease (Broad): New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv"), index=False)
df93772.to_csv(os.path.join(folder_name,"Admission episodes for alcohol-related conditions (Narrow) - Under 40s: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv"), index=False)
df93773.to_csv(os.path.join(folder_name,"Admission episodes for alcohol-related conditions (Narrow)40 to 64 years: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv"), index=False)
df93774.to_csv(os.path.join(folder_name,"Admission episodes for alcohol-related conditions (Narrow)65+ years: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv"), index=False)
df93786.to_csv(os.path.join(folder_name,"HIV diagnosed prevalence rate per 1,000.csv"), index=False)
df93787.to_csv(os.path.join(folder_name,"New HIV diagnoses among persons first diagnosed in the UK rate per 100,000.csv"), index=False)
df93788.to_csv(os.path.join(folder_name,"Antiretroviral therapy (ART) coverage in people accessing HIV care.csv"), index=False)
df93823.to_csv(os.path.join(folder_name,"Mortality rate from all causes, all ages.csv"), index=False)
df93827.to_csv(os.path.join(folder_name,"Mortality rate for deaths involving COVID-19, all ages.csv"), index=False)
df93840.to_csv(os.path.join(folder_name,"Mortality rate for deaths involving COVID-19, under 75s.csv"), index=False)
df93861.to_csv(os.path.join(folder_name,"Fraction of mortality attributable to particulate air pollution (new method).csv"), index=False)
df93863.to_csv(os.path.join(folder_name,"Acute Lyme disease laboratory confirmed incidence rateper100,000.csv"), index=False)
df93865.to_csv(os.path.join(folder_name,"Average Attainment 8 Score among children eligible for Free School Meals (FSM).csv"), index=False)
df93867.to_csv(os.path.join(folder_name,"Air pollution: fine particulate matter (new method - concentrations of total PM2.5).csv"), index=False)
df93880.to_csv(os.path.join(folder_name,"Potential years of life lost (PYLL) due to alcohol-related conditions.csv"), index=False)
df93881.to_csv(os.path.join(folder_name,"Percentage of adults (aged 18+) classified as obese.csv"), index=False)
df93882.to_csv(os.path.join(folder_name,"The percentage of the population with a physical or mental long term health condition in employment (aged 16 to 64).csv"), index=False)
df93884.to_csv(os.path.join(folder_name,"The percentage of the population who are in receipt of long term support for a learning disability that are in paid employment (aged 18 to 64).csv"), index=False)
df93928.to_csv(os.path.join(folder_name,"Initiation or continuation of PrEP among those with PrEP need.csv"), index=False)
df93929.to_csv(os.path.join(folder_name,"Determining PrEP need.csv"), index=False)

# %%
from google.colab import drive
drive.mount('/content/drive')

# Create a folder in your Google Drive to store the CSVs
# !mkdir '/content/drive/My Drive/FINALHealthIndicators'

# Copy the CSVs from the Colab file system to the folder in your Google Drive
# !cp '/content/Step15FINALHealthIndicators.csv' '/content/drive/My Drive/Step15FINALHealthIndicators'

# Create a zip file containing all of the CSVs
# !zip -r content.zip '/content/Step15FINALHealthIndicators'

# Download the zip file to your local machine
#from google.colab import files
#files.download('/content/Step15FINALHealthIndicators.zip')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/My Drive/FINALHealthIndicators’: File exists
# cp: cannot stat '/content/Step15FINALHealthIndicators.csv': No such file or directory
#   adding: content/Step15FINALHealthIndicators/ (stored 0%)
#   adding: content/Step15FINALHealthIndicators/Mortality rate for deaths involving COVID-19, under 75s.csv (deflated 48%)
#   adding: content/Step15FINALHealthIndicators/Under 75 mortality rate from liver disease considered preventable (2019 definition).csv (deflated 50%)
#   adding: content/Step15FINALHealthIndicators/Admission episodes for alcohol-related conditions (Narrow) - Under 40s: New method.  This indicator uses a new set of attributable fractions, and so differ from that originally published..csv (deflated 47%)
# ...

# %%
import os
import zipfile

# Create the zip file
df93383,	df93439,	df93440,	df93453,	df93454,	df93455,	df93456,	df93463,	df93465,	df93466,	df93467,	df93474,	df93475,	df93476,	df93477,	df93478,	df93480,	df93488,	df93489,	df93491,	df93495,	df93496,	df93497,	df93498,	df93499,	df93506,	df93507,	df93513,	df93515,	df93546,	df93550,	df93551,	df93553,	df93560,	df93561,	df93563,	df93570,	df93572,	df93580,	df93604,	df93644,	df93670,	df93671,	df93691,	df93700,	df93701,	df93720,	df93721,	df93722,	df93723,	df93724,	df93735,	df93736,	df93737,	df93738,	df93739,	df93742,	df93744,	df93745,	df93746,	df93747,	df93748,	df93750,	df93751,	df93753,	df93754,	df93758,	df93759,	df93760,	df93761,	df93763,	df93764,	df93765,	df93766,	df93767,	df93768,	df93769,	df93770,	df93771,	df93772,	df93773,	df93774,	df93786,	df93787,	df93788,	df93823,	df93827,	df93840,	df93861,	df93863,	df93865,	df93867,	df93880,	df93881,	df93882,	df93884,	df93928,	df93929])

# %%
dfGROUPED.head(10000)
# Out:
#                   Area Name  Under 75 mortality rate from all causes  \
# 0                Hartlepool                                   460.80
# 1             Middlesbrough                                   521.04
# 2      Redcar and Cleveland                                   455.82
# 3          Stockton-on-Tees                                   426.80
# 4                Darlington                                   436.92
# ..                      ...                                      ...
# 301                  Dorset                                      NaN
# 302      Buckinghamshire UA                                      NaN
# 303  North Northamptonshire                                      NaN
# 304   West Northamptonshire                                      NaN
# 305           Tower Hamlets                                      NaN
#
#      Stroke: QOF prevalence (all ages)  \
# 0                                  NaN
# 1                                  NaN
# ...

# %% [markdown]
# Something hasn't worked here

# %% [markdown]
# Rename in chronological order to create a loop to merge them together

# %%
df1=df108
df2=df212
df3=df219
df4=df273
df5=df848
df6=df1203
df7=df1204
df8=df1205
df9=df1206
df10=df1208
df11=df1730
df12=df10101
df13=df10301
df14=df11001
df15=df11201
df16=df11202
df17=df11401
df18=df11501
df19=df11601
df20=df20101
df21=df20401
df22=df20601
df23=df20602
df24=df21001
df25=df22001
df26=df22401
df27=df22402
df28=df22403
df29=df30101
df30=df40401
df31=df40501
df32=df40601
df33=df40701
df34=df41001
df35=df41101
df36=df41401
df37=df41402
df38=df41403
df39=df90282
df40=df90284
df41=df90285
df42=df90286
df43=df90287
df44=df90290
df45=df90291
df46=df90292
df47=df90312
df48=df90313
df49=df90314
df50=df90315
df51=df90316
df52=df90317
df53=df90319
df54=df90320
df55=df90321
df56=df90323
df57=df90356
df58=df90360
df59=df90361
df60=df90366
df61=df90371
df62=df90411
df63=df90416
df64=df90443
df65=df90630
df66=df90637
df67=df90656
df68=df90729
df69=df90731
df70=df90739
df71=df90740
df72=df90742
df73=df90759
df74=df90776
df75=df90777
df76=df90790
df77=df90791
df78=df90804
df79=df90832
df80=df90851
df81=df90892
df82=df91046
df83=df91048
df84=df91049
df85=df91050
df86=df91102
df87=df91126
df88=df91133
df89=df91143
df90=df91155
df91=df91156
df92=df91163
df93=df91164
df94=df91165
df95=df91166
df96=df91167
df97=df91195
df98=df91269
df99=df91306
df100=df91307
	df304,	df305,	df306,	df307,	df308,	df309,	df310,	df311,	df312,	df313,	df314,	df315,	df316,	df317,	df318,	df319,	df320,	df321,	df322,	df323,	df324,	df325,	df326,	df327,	df328,	df329,	df330,	df331,	df332,	df333,	df334,	df335,	df336,	df337,	df338,	df339,	df340,	df341,	df342,	df343,	df344,	df345,	df346,	df347,	df348,	df349,	df350,	df351,	df352,	df353,	df354,	df355,	df356,	df357,	df358,	df359,	df360,	df361]

# Merge the DataFrames
df_merged1 = df_list[0]
for i in range(1, len(df_list)):
  df_merged1 = pd.merge(df_merged1, df_list[i], on='Area Name', how='outer')

# %%
df_merged1.head(10000)
# Out:
#                  Area Name  Under 75 mortality rate from all causes  \
# 0               Hartlepool                                   460.80
# 1            Middlesbrough                                   521.04
# 2     Redcar and Cleveland                                   455.82
# 3         Stockton-on-Tees                                   426.80
# 4               Darlington                                   436.92
# ..                     ...                                      ...
# 304  West Northamptonshire                                   357.15
# 305          Tower Hamlets                                   400.16
# 306         Waltham Forest                                   391.61
# 307             Wandsworth                                   334.46
# 308            Westminster                                   282.54
#
#      Stroke: QOF prevalence (all ages)  \
# 0                                 2.22
# 1                                 1.90
# ...

# %%
df_merged1.to_csv(os.path.join(folder_name,"MERGED.csv"), index=False)

# %%
df_merged1.to_csv("MERGED.csv")

# %%
dfdraft= pd.read_csv('MERGED.csv')

# %%
print(dfdraft)
# Out:
#      Unnamed: 0              Area Name  \
# 0             0             Hartlepool
# 1             1          Middlesbrough
# 2             2   Redcar and Cleveland
# 3             3       Stockton-on-Tees
# 4             4             Darlington
# ..          ...                    ...
# 304         304  West Northamptonshire
# 305         305          Tower Hamlets
# 306         306         Waltham Forest
# 307         307             Wandsworth
# 308         308            Westminster
#
#      Under 75 mortality rate from all causes  \
# 0                                     460.80
# 1                                     521.04
# 2                                     455.82
# 3                                     426.80
# 4                                     436.92
# ..                                       ...
# 304                                   357.15
# 305                                   400.16
# 306                                   391.61
# ...

# %% [markdown]
# delete columns with no values

# %%
dfdraft = dfdraft.dropna(axis=1, how='all')

# Save the modified dataframe to a new CSV file
dfdraft.to_csv('ObesityAndHealthIndicators.csv', index=False)

# %%
dfdraft.to_csv(os.path.join(folder_name,"ObesityAndHealthIndicators.csv"), index=False)

# %% [markdown]
# I then converted the csv into an xlsx () and added a region column (see A of the ObesityAndHealthIndicatorsNEW tab), moved the obesity rate column to the front end of the table (see C of the ObesityAndHealthIndicatorsNEW tab) in Excel. I calculated the correlation of each variable with obesity rates in the 'Correlations' tab using the =CORREL function. The 'Correlations Transposed' tab is the one used as the final CSV () for Vega. I shortened names of indicators as per 'Header Cleans' tab for readability and to shorten the length of the drop down box appearing in my Vega correlations chart . Deleted column indicators called 'Value' and '0'.

# %% [markdown]
# Added outlet density in excel, and LAs matched to regions using ONS data (https://www.ons.gov.uk/peoplepopulationandcommunity/populationandmigration/migrationwithintheuk/datasets/userinformationenglandandwaleslocalauthoritytoregionlookup) and saved as 'ObesityAndHealthIndicators.csv' in GitHub

# %%
import pandas as pd
df = pd.read_csv('ObesityAndHealthIndicators.csv')
