# %% [markdown]
# <a href="https://colab.research.google.com/github/jesme00/jesme00.github.io/blob/main/Week4HomeworkScraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup

# %%
import os

# %%
URL = "https://olympics.com/tokyo-2020/olympic-games/en/results/all-sports/medal-standings.htm"

# %%
html = requests.get(URL)

# %%
soup = BeautifulSoup(html.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
Country = soup.find_all("span", class_="styles__CountryName-sc-fehzzg-6 cdgAMA")

# %%
Country
# Out:
# [<span class="styles__CountryName-sc-fehzzg-6 cdgAMA" data-cy="country-name">United States of America</span>,
#  <span class="styles__CountryName-sc-fehzzg-6 cdgAMA" data-cy="country-name">People's Republic of China</span>,
#  <span class="styles__CountryName-sc-fehzzg-6 cdgAMA" data-cy="country-name">Japan</span>,
#  <span class="styles__CountryName-sc-fehzzg-6 cdgAMA" data-cy="country-name">Great Britain</span>,
#  <span class="styles__CountryName-sc-fehzzg-6 cdgAMA" data-cy="country-name">ROC</span>,
#  <span class="styles__CountryName-sc-fehzzg-6 cdgAMA" data-cy="country-name">Australia</span>,
#  <span class="styles__CountryName-sc-fehzzg-6 cdgAMA" data-cy="country-name">Netherlands</span>,
#  <span class="styles__CountryName-sc-fehzzg-6 cdgAMA" data-cy="country-name">France</span>,
#  <span class="styles__CountryName-sc-fehzzg-6 cdgAMA" data-cy="country-name">Germany</span>,
#  <span class="styles__CountryName-sc-fehzzg-6 cdgAMA" data-cy="country-name">Italy</span>,
# ...

# %%
Country[0].text
# Out:
# 'United States of America'

# %%
Country[1].text
# Out:
# "People's Republic of China"

# %%
Country[2].text
# Out:
# 'Japan'

# %%
Country[3].text
# Out:
# 'Great Britain'

# %%
Medals = soup.find_all("span", class_="Medalstyles__Medal-sc-1tu6huk-1 hUeeZW")

# %%
Medals
# Out:
# [<span class="Medalstyles__Medal-sc-1tu6huk-1 hUeeZW" data-cy="medal-main">113</span>,
#  <span class="Medalstyles__Medal-sc-1tu6huk-1 hUeeZW" data-cy="medal-main">89</span>,
#  <span class="Medalstyles__Medal-sc-1tu6huk-1 hUeeZW" data-cy="medal-main">58</span>,
#  <span class="Medalstyles__Medal-sc-1tu6huk-1 hUeeZW" data-cy="medal-main">64</span>,
#  <span class="Medalstyles__Medal-sc-1tu6huk-1 hUeeZW" data-cy="medal-main">71</span>,
#  <span class="Medalstyles__Medal-sc-1tu6huk-1 hUeeZW" data-cy="medal-main">46</span>,
#  <span class="Medalstyles__Medal-sc-1tu6huk-1 hUeeZW" data-cy="medal-main">36</span>,
#  <span class="Medalstyles__Medal-sc-1tu6huk-1 hUeeZW" data-cy="medal-main">33</span>,
#  <span class="Medalstyles__Medal-sc-1tu6huk-1 hUeeZW" data-cy="medal-main">37</span>,
#  <span class="Medalstyles__Medal-sc-1tu6huk-1 hUeeZW" data-cy="medal-main">40</span>,
#  <span class="Medalstyles__Medal-sc-1tu6huk-1 hUeeZW" data-cy="medal-main">24</span>,
# ...

# %%
Medals[0].text
# Out:
# '113'

# %%
Medals[1].text
# Out:
# '89'

# %%
Medals[2].text
# Out:
# '58'

# %%
Medals[3].text
# Out:
# '64'

# %%
results = [Country[0].text, Medals[0].text],[Country[1].text, Medals[1].text],[Country[2].text, Medals[2].text],[Country[3].text, Medals[3].text],[Country[4].text, Medals[4].text],[Country[5].text, Medals[5].text],[Country[6].text, Medals[6].text],[Country[7].text, Medals[7].text],[Country[8].text, Medals[8].text],[Country[9].text, Medals[9].text],[Country[10].text, Medals[10].text]
results
# Out:
# (['United States of America', '113'],
#  ["People's Republic of China", '89'],
#  ['Japan', '58'],
#  ['Great Britain', '64'],
#  ['ROC', '71'],
#  ['Australia', '46'],
#  ['Netherlands', '36'],
#  ['France', '33'],
#  ['Germany', '37'],
#  ['Italy', '40'],
#  ['Canada', '24'])

# %%
col_names = ["Country", "Medals"]

# %%
from tabulate import tabulate

# %%
print(tabulate(results, headers=col_names))
# Out:
# Country                       Medals
# --------------------------  --------
# United States of America         113
# People's Republic of China        89
# Japan                             58
# Great Britain                     64
# ROC                               71
# Australia                         46
# Netherlands                       36
# France                            33
# Germany                           37
# Italy                             40
# Canada                            24
