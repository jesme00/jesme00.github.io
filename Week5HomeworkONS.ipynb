# %% [markdown]
# <a href="https://colab.research.google.com/github/jesme00/jesme00.github.io/blob/main/Week5HomeworkONS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url_base = "https://api.ons.gov.uk/timeseries/{}/dataset/pusf/data"

ONSSeries = ['gzsj','gtao','aazk','j5ii','cprn','anls','anby','anng','ansp','cpmz']
for i in ONSSeries:  
   URL = url_base.format(i)
   print(URL)
# Out:
# https://api.ons.gov.uk/timeseries/gzsj/dataset/pusf/data
# https://api.ons.gov.uk/timeseries/gtao/dataset/pusf/data
# https://api.ons.gov.uk/timeseries/aazk/dataset/pusf/data
# https://api.ons.gov.uk/timeseries/j5ii/dataset/pusf/data
# https://api.ons.gov.uk/timeseries/cprn/dataset/pusf/data
# https://api.ons.gov.uk/timeseries/anls/dataset/pusf/data
# https://api.ons.gov.uk/timeseries/anby/dataset/pusf/data
# https://api.ons.gov.uk/timeseries/anng/dataset/pusf/data
# https://api.ons.gov.uk/timeseries/ansp/dataset/pusf/data
# https://api.ons.gov.uk/timeseries/cpmz/dataset/pusf/data

# %%
import requests
import json
from google.colab import files
import os

# %%
print(requests.__version__)
print(json.__version__)
# Out:
# 2.23.0
# 2.0.9

# %%
url = "https://api.ons.gov.uk/timeseries/cpoa/dataset/pusf/data"
data = requests.get(url).json()
data
# Out:
# {'description': {'cdid': 'CPOA',
#   'contact': {'email': 'public.sector.inquiries@ons.gov.uk',
#    'name': 'Fraser Munro',
#    'telephone': '+44 1633 456402'},
#   'datasetId': 'PUSF',
#   'datasetUri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/datasets/publicsectorfinances',
#   'date': '2022 SEP',
#   'nextRelease': '22 November 2022',
#   'number': '85.1',
#   'preUnit': '',
#   'releaseDate': '2022-10-20T23:00:00.000Z',
#   'sampleSize': '0',
#   'source': '',
#   'title': 'Public Sector: PSND (ex PS banks ex BoE) as a % GDP: NSA',
#   'unit': ''},
#  'months': [{'date': '1997 APR',
#    'label': '1997 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '37.2',
#    'year': '1997'},
#   {'date': '1997 MAY',
#    'label': '1997 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '37.6',
#    'year': '1997'},
#   {'date': '1997 JUN',
#    'label': '1997 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '38.3',
#    'year': '1997'},
#   {'date': '1997 JUL',
#    'label': '1997 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '37.8',
#    'year': '1997'},
#   {'date': '1997 AUG',
#    'label': '1997 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '37.9',
#    'year': '1997'},
#   {'date': '1997 SEP',
#    'label': '1997 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '37.9',
#    'year': '1997'},
#   {'date': '1997 OCT',
#    'label': '1997 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '37.2',
#    'year': '1997'},
#   {'date': '1997 NOV',
#    'label': '1997 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '37.5',
#    'year': '1997'},
#   {'date': '1997 DEC',
#    'label': '1997 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '37.5',
#    'year': '1997'},
#   {'date': '1998 JAN',
#    'label': '1998 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '36.4',
#    'year': '1998'},
#   {'date': '1998 FEB',
#    'label': '1998 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '36.1',
#    'year': '1998'},
#   {'date': '1998 MAR',
#    'label': '1998 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '36.6',
#    'year': '1998'},
#   {'date': '1998 APR',
#    'label': '1998 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '36.1',
#    'year': '1998'},
#   {'date': '1998 MAY',
#    'label': '1998 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '36.3',
#    'year': '1998'},
#   {'date': '1998 JUN',
#    'label': '1998 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '36.8',
#    'year': '1998'},
#   {'date': '1998 JUL',
#    'label': '1998 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '36.3',
#    'year': '1998'},
#   {'date': '1998 AUG',
#    'label': '1998 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '36.3',
#    'year': '1998'},
#   {'date': '1998 SEP',
#    'label': '1998 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '36.3',
#    'year': '1998'},
#   {'date': '1998 OCT',
#    'label': '1998 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '35.5',
#    'year': '1998'},
#   {'date': '1998 NOV',
#    'label': '1998 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '35.6',
#    'year': '1998'},
#   {'date': '1998 DEC',
#    'label': '1998 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.8',
#    'year': '1998'},
#   {'date': '1999 JAN',
#    'label': '1999 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '34.6',
#    'year': '1999'},
#   {'date': '1999 FEB',
#    'label': '1999 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '34.6',
#    'year': '1999'},
#   {'date': '1999 MAR',
#    'label': '1999 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.2',
#    'year': '1999'},
#   {'date': '1999 APR',
#    'label': '1999 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.8',
#    'year': '1999'},
#   {'date': '1999 MAY',
#    'label': '1999 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '34.9',
#    'year': '1999'},
#   {'date': '1999 JUN',
#    'label': '1999 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '35.3',
#    'year': '1999'},
#   {'date': '1999 JUL',
#    'label': '1999 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.5',
#    'year': '1999'},
#   {'date': '1999 AUG',
#    'label': '1999 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.3',
#    'year': '1999'},
#   {'date': '1999 SEP',
#    'label': '1999 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.3',
#    'year': '1999'},
#   {'date': '1999 OCT',
#    'label': '1999 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '33.3',
#    'year': '1999'},
#   {'date': '1999 NOV',
#    'label': '1999 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '33.2',
#    'year': '1999'},
#   {'date': '1999 DEC',
#    'label': '1999 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.4',
#    'year': '1999'},
#   {'date': '2000 JAN',
#    'label': '2000 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '32.6',
#    'year': '2000'},
#   {'date': '2000 FEB',
#    'label': '2000 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '32.2',
#    'year': '2000'},
#   {'date': '2000 MAR',
#    'label': '2000 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '32.6',
#    'year': '2000'},
#   {'date': '2000 APR',
#    'label': '2000 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '31.8',
#    'year': '2000'},
#   {'date': '2000 MAY',
#    'label': '2000 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '30.6',
#    'year': '2000'},
#   {'date': '2000 JUN',
#    'label': '2000 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '31.1',
#    'year': '2000'},
#   {'date': '2000 JUL',
#    'label': '2000 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '30.3',
#    'year': '2000'},
#   {'date': '2000 AUG',
#    'label': '2000 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '30.2',
#    'year': '2000'},
#   {'date': '2000 SEP',
#    'label': '2000 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '29.4',
#    'year': '2000'},
#   {'date': '2000 OCT',
#    'label': '2000 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '28.7',
#    'year': '2000'},
#   {'date': '2000 NOV',
#    'label': '2000 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '28.8',
#    'year': '2000'},
#   {'date': '2000 DEC',
#    'label': '2000 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '29.7',
#    'year': '2000'},
#   {'date': '2001 JAN',
#    'label': '2001 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '28.2',
#    'year': '2001'},
#   {'date': '2001 FEB',
#    'label': '2001 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '27.9',
#    'year': '2001'},
#   {'date': '2001 MAR',
#    'label': '2001 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '28.4',
#    'year': '2001'},
#   {'date': '2001 APR',
#    'label': '2001 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '28.0',
#    'year': '2001'},
#   {'date': '2001 MAY',
#    'label': '2001 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '28.3',
#    'year': '2001'},
#   {'date': '2001 JUN',
#    'label': '2001 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '28.9',
#    'year': '2001'},
#   {'date': '2001 JUL',
#    'label': '2001 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '28.3',
#    'year': '2001'},
#   {'date': '2001 AUG',
#    'label': '2001 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '28.2',
#    'year': '2001'},
#   {'date': '2001 SEP',
#    'label': '2001 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '28.3',
#    'year': '2001'},
#   {'date': '2001 OCT',
#    'label': '2001 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '27.7',
#    'year': '2001'},
#   {'date': '2001 NOV',
#    'label': '2001 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '28.2',
#    'year': '2001'},
#   {'date': '2001 DEC',
#    'label': '2001 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '28.9',
#    'year': '2001'},
#   {'date': '2002 JAN',
#    'label': '2002 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '28.0',
#    'year': '2002'},
#   {'date': '2002 FEB',
#    'label': '2002 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '27.7',
#    'year': '2002'},
#   {'date': '2002 MAR',
#    'label': '2002 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '28.2',
#    'year': '2002'},
#   {'date': '2002 APR',
#    'label': '2002 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '27.9',
#    'year': '2002'},
#   {'date': '2002 MAY',
#    'label': '2002 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '28.1',
#    'year': '2002'},
#   {'date': '2002 JUN',
#    'label': '2002 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '28.6',
#    'year': '2002'},
#   {'date': '2002 JUL',
#    'label': '2002 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '28.1',
#    'year': '2002'},
#   {'date': '2002 AUG',
#    'label': '2002 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '28.2',
#    'year': '2002'},
#   {'date': '2002 SEP',
#    'label': '2002 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '28.5',
#    'year': '2002'},
#   {'date': '2002 OCT',
#    'label': '2002 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '28.8',
#    'year': '2002'},
#   {'date': '2002 NOV',
#    'label': '2002 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '29.3',
#    'year': '2002'},
#   {'date': '2002 DEC',
#    'label': '2002 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '30.2',
#    'year': '2002'},
#   {'date': '2003 JAN',
#    'label': '2003 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '29.2',
#    'year': '2003'},
#   {'date': '2003 FEB',
#    'label': '2003 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '29.0',
#    'year': '2003'},
#   {'date': '2003 MAR',
#    'label': '2003 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '29.8',
#    'year': '2003'},
#   {'date': '2003 APR',
#    'label': '2003 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '29.1',
#    'year': '2003'},
#   {'date': '2003 MAY',
#    'label': '2003 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '29.4',
#    'year': '2003'},
#   {'date': '2003 JUN',
#    'label': '2003 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '29.9',
#    'year': '2003'},
#   {'date': '2003 JUL',
#    'label': '2003 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '29.4',
#    'year': '2003'},
#   {'date': '2003 AUG',
#    'label': '2003 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '29.6',
#    'year': '2003'},
#   {'date': '2003 SEP',
#    'label': '2003 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '30.2',
#    'year': '2003'},
#   {'date': '2003 OCT',
#    'label': '2003 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '30.0',
#    'year': '2003'},
#   {'date': '2003 NOV',
#    'label': '2003 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '30.5',
#    'year': '2003'},
#   {'date': '2003 DEC',
#    'label': '2003 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '31.4',
#    'year': '2003'},
#   {'date': '2004 JAN',
#    'label': '2004 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '30.1',
#    'year': '2004'},
#   {'date': '2004 FEB',
#    'label': '2004 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '30.1',
#    'year': '2004'},
#   {'date': '2004 MAR',
#    'label': '2004 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '31.0',
#    'year': '2004'},
#   {'date': '2004 APR',
#    'label': '2004 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '31.6',
#    'year': '2004'},
#   {'date': '2004 MAY',
#    'label': '2004 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '31.8',
#    'year': '2004'},
#   {'date': '2004 JUN',
#    'label': '2004 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '32.6',
#    'year': '2004'},
#   {'date': '2004 JUL',
#    'label': '2004 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '32.1',
#    'year': '2004'},
#   {'date': '2004 AUG',
#    'label': '2004 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '32.1',
#    'year': '2004'},
#   {'date': '2004 SEP',
#    'label': '2004 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '32.7',
#    'year': '2004'},
#   {'date': '2004 OCT',
#    'label': '2004 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '32.4',
#    'year': '2004'},
#   {'date': '2004 NOV',
#    'label': '2004 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '33.2',
#    'year': '2004'},
#   {'date': '2004 DEC',
#    'label': '2004 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '34.2',
#    'year': '2004'},
#   {'date': '2005 JAN',
#    'label': '2005 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '32.7',
#    'year': '2005'},
#   {'date': '2005 FEB',
#    'label': '2005 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '32.6',
#    'year': '2005'},
#   {'date': '2005 MAR',
#    'label': '2005 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '33.5',
#    'year': '2005'},
#   {'date': '2005 APR',
#    'label': '2005 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '33.1',
#    'year': '2005'},
#   {'date': '2005 MAY',
#    'label': '2005 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '33.3',
#    'year': '2005'},
#   {'date': '2005 JUN',
#    'label': '2005 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '33.9',
#    'year': '2005'},
#   {'date': '2005 JUL',
#    'label': '2005 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '33.3',
#    'year': '2005'},
#   {'date': '2005 AUG',
#    'label': '2005 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '33.5',
#    'year': '2005'},
#   {'date': '2005 SEP',
#    'label': '2005 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '34.1',
#    'year': '2005'},
#   {'date': '2005 OCT',
#    'label': '2005 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '33.7',
#    'year': '2005'},
#   {'date': '2005 NOV',
#    'label': '2005 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.2',
#    'year': '2005'},
#   {'date': '2005 DEC',
#    'label': '2005 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.2',
#    'year': '2005'},
#   {'date': '2006 JAN',
#    'label': '2006 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '33.7',
#    'year': '2006'},
#   {'date': '2006 FEB',
#    'label': '2006 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '33.7',
#    'year': '2006'},
#   {'date': '2006 MAR',
#    'label': '2006 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.4',
#    'year': '2006'},
#   {'date': '2006 APR',
#    'label': '2006 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.2',
#    'year': '2006'},
#   {'date': '2006 MAY',
#    'label': '2006 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.7',
#    'year': '2006'},
#   {'date': '2006 JUN',
#    'label': '2006 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '35.4',
#    'year': '2006'},
#   {'date': '2006 JUL',
#    'label': '2006 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.5',
#    'year': '2006'},
#   {'date': '2006 AUG',
#    'label': '2006 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.7',
#    'year': '2006'},
#   {'date': '2006 SEP',
#    'label': '2006 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.4',
#    'year': '2006'},
#   {'date': '2006 OCT',
#    'label': '2006 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.7',
#    'year': '2006'},
#   {'date': '2006 NOV',
#    'label': '2006 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.1',
#    'year': '2006'},
#   {'date': '2006 DEC',
#    'label': '2006 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.9',
#    'year': '2006'},
#   {'date': '2007 JAN',
#    'label': '2007 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.5',
#    'year': '2007'},
#   {'date': '2007 FEB',
#    'label': '2007 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.3',
#    'year': '2007'},
#   {'date': '2007 MAR',
#    'label': '2007 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.2',
#    'year': '2007'},
#   {'date': '2007 APR',
#    'label': '2007 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.8',
#    'year': '2007'},
#   {'date': '2007 MAY',
#    'label': '2007 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.2',
#    'year': '2007'},
#   {'date': '2007 JUN',
#    'label': '2007 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.8',
#    'year': '2007'},
#   {'date': '2007 JUL',
#    'label': '2007 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.9',
#    'year': '2007'},
#   {'date': '2007 AUG',
#    'label': '2007 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.0',
#    'year': '2007'},
#   {'date': '2007 SEP',
#    'label': '2007 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.4',
#    'year': '2007'},
#   {'date': '2007 OCT',
#    'label': '2007 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.0',
#    'year': '2007'},
#   {'date': '2007 NOV',
#    'label': '2007 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.5',
#    'year': '2007'},
#   {'date': '2007 DEC',
#    'label': '2007 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '36.4',
#    'year': '2007'},
#   {'date': '2008 JAN',
#    'label': '2008 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.9',
#    'year': '2008'},
#   {'date': '2008 FEB',
#    'label': '2008 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.2',
#    'year': '2008'},
#   {'date': '2008 MAR',
#    'label': '2008 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.8',
#    'year': '2008'},
#   {'date': '2008 APR',
#    'label': '2008 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.9',
#    'year': '2008'},
#   {'date': '2008 MAY',
#    'label': '2008 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '36.6',
#    'year': '2008'},
#   {'date': '2008 JUN',
#    'label': '2008 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '37.8',
#    'year': '2008'},
#   {'date': '2008 JUL',
#    'label': '2008 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '39.9',
#    'year': '2008'},
#   {'date': '2008 AUG',
#    'label': '2008 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '40.7',
#    'year': '2008'},
#   {'date': '2008 SEP',
#    'label': '2008 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '43.2',
#    'year': '2008'},
#   {'date': '2008 OCT',
#    'label': '2008 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '43.9',
#    'year': '2008'},
#   {'date': '2008 NOV',
#    'label': '2008 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '44.8',
#    'year': '2008'},
#   {'date': '2008 DEC',
#    'label': '2008 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '48.0',
#    'year': '2008'},
#   {'date': '2009 JAN',
#    'label': '2009 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '48.3',
#    'year': '2009'},
#   {'date': '2009 FEB',
#    'label': '2009 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '48.9',
#    'year': '2009'},
#   {'date': '2009 MAR',
#    'label': '2009 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '50.5',
#    'year': '2009'},
#   {'date': '2009 APR',
#    'label': '2009 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '51.3',
#    'year': '2009'},
#   {'date': '2009 MAY',
#    'label': '2009 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '52.6',
#    'year': '2009'},
#   {'date': '2009 JUN',
#    'label': '2009 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '54.1',
#    'year': '2009'},
#   {'date': '2009 JUL',
#    'label': '2009 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '54.2',
#    'year': '2009'},
#   {'date': '2009 AUG',
#    'label': '2009 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '54.2',
#    'year': '2009'},
#   {'date': '2009 SEP',
#    'label': '2009 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '55.3',
#    'year': '2009'},
#   {'date': '2009 OCT',
#    'label': '2009 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '55.6',
#    'year': '2009'},
#   {'date': '2009 NOV',
#    'label': '2009 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '56.3',
#    'year': '2009'},
#   {'date': '2009 DEC',
#    'label': '2009 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '59.8',
#    'year': '2009'},
#   {'date': '2010 JAN',
#    'label': '2010 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '61.9',
#    'year': '2010'},
#   {'date': '2010 FEB',
#    'label': '2010 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '62.1',
#    'year': '2010'},
#   {'date': '2010 MAR',
#    'label': '2010 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '63.7',
#    'year': '2010'},
#   {'date': '2010 APR',
#    'label': '2010 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '63.8',
#    'year': '2010'},
#   {'date': '2010 MAY',
#    'label': '2010 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '64.4',
#    'year': '2010'},
#   {'date': '2010 JUN',
#    'label': '2010 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '65.6',
#    'year': '2010'},
#   {'date': '2010 JUL',
#    'label': '2010 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '65.6',
#    'year': '2010'},
#   {'date': '2010 AUG',
#    'label': '2010 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '66.0',
#    'year': '2010'},
#   {'date': '2010 SEP',
#    'label': '2010 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '67.4',
#    'year': '2010'},
#   {'date': '2010 OCT',
#    'label': '2010 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '67.4',
#    'year': '2010'},
#   {'date': '2010 NOV',
#    'label': '2010 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '68.3',
#    'year': '2010'},
#   {'date': '2010 DEC',
#    'label': '2010 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '69.8',
#    'year': '2010'},
#   {'date': '2011 JAN',
#    'label': '2011 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '68.8',
#    'year': '2011'},
#   {'date': '2011 FEB',
#    'label': '2011 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '69.1',
#    'year': '2011'},
#   {'date': '2011 MAR',
#    'label': '2011 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '70.5',
#    'year': '2011'},
#   {'date': '2011 APR',
#    'label': '2011 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '70.6',
#    'year': '2011'},
#   {'date': '2011 MAY',
#    'label': '2011 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '71.0',
#    'year': '2011'},
#   {'date': '2011 JUN',
#    'label': '2011 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '72.1',
#    'year': '2011'},
#   {'date': '2011 JUL',
#    'label': '2011 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '71.6',
#    'year': '2011'},
#   {'date': '2011 AUG',
#    'label': '2011 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '72.4',
#    'year': '2011'},
#   {'date': '2011 SEP',
#    'label': '2011 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '73.0',
#    'year': '2011'},
#   {'date': '2011 OCT',
#    'label': '2011 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '72.7',
#    'year': '2011'},
#   {'date': '2011 NOV',
#    'label': '2011 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '73.1',
#    'year': '2011'},
#   {'date': '2011 DEC',
#    'label': '2011 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '74.4',
#    'year': '2011'},
#   {'date': '2012 JAN',
#    'label': '2012 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '73.3',
#    'year': '2012'},
#   {'date': '2012 FEB',
#    'label': '2012 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '73.6',
#    'year': '2012'},
#   {'date': '2012 MAR',
#    'label': '2012 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '74.6',
#    'year': '2012'},
#   {'date': '2012 APR',
#    'label': '2012 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '73.4',
#    'year': '2012'},
#   {'date': '2012 MAY',
#    'label': '2012 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '73.6',
#    'year': '2012'},
#   {'date': '2012 JUN',
#    'label': '2012 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '74.6',
#    'year': '2012'},
#   {'date': '2012 JUL',
#    'label': '2012 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '74.0',
#    'year': '2012'},
#   {'date': '2012 AUG',
#    'label': '2012 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '74.2',
#    'year': '2012'},
#   {'date': '2012 SEP',
#    'label': '2012 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '75.1',
#    'year': '2012'},
#   {'date': '2012 OCT',
#    'label': '2012 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '75.2',
#    'year': '2012'},
#   {'date': '2012 NOV',
#    'label': '2012 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '75.7',
#    'year': '2012'},
#   {'date': '2012 DEC',
#    'label': '2012 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '76.8',
#    'year': '2012'},
#   {'date': '2013 JAN',
#    'label': '2013 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '75.3',
#    'year': '2013'},
#   {'date': '2013 FEB',
#    'label': '2013 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '75.1',
#    'year': '2013'},
#   {'date': '2013 MAR',
#    'label': '2013 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '76.2',
#    'year': '2013'},
#   {'date': '2013 APR',
#    'label': '2013 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '75.9',
#    'year': '2013'},
#   {'date': '2013 MAY',
#    'label': '2013 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '76.2',
#    'year': '2013'},
#   {'date': '2013 JUN',
#    'label': '2013 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '76.6',
#    'year': '2013'},
#   {'date': '2013 JUL',
#    'label': '2013 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '75.8',
#    'year': '2013'},
#   {'date': '2013 AUG',
#    'label': '2013 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '75.6',
#    'year': '2013'},
#   {'date': '2013 SEP',
#    'label': '2013 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '76.2',
#    'year': '2013'},
#   {'date': '2013 OCT',
#    'label': '2013 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '75.6',
#    'year': '2013'},
#   {'date': '2013 NOV',
#    'label': '2013 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '76.2',
#    'year': '2013'},
#   {'date': '2013 DEC',
#    'label': '2013 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '77.2',
#    'year': '2013'},
#   {'date': '2014 JAN',
#    'label': '2014 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '76.2',
#    'year': '2014'},
#   {'date': '2014 FEB',
#    'label': '2014 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '76.2',
#    'year': '2014'},
#   {'date': '2014 MAR',
#    'label': '2014 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '76.9',
#    'year': '2014'},
#   {'date': '2014 APR',
#    'label': '2014 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '76.8',
#    'year': '2014'},
#   {'date': '2014 MAY',
#    'label': '2014 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '77.3',
#    'year': '2014'},
#   {'date': '2014 JUN',
#    'label': '2014 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.1',
#    'year': '2014'},
#   {'date': '2014 JUL',
#    'label': '2014 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '77.7',
#    'year': '2014'},
#   {'date': '2014 AUG',
#    'label': '2014 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '77.7',
#    'year': '2014'},
#   {'date': '2014 SEP',
#    'label': '2014 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.6',
#    'year': '2014'},
#   {'date': '2014 OCT',
#    'label': '2014 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.4',
#    'year': '2014'},
#   {'date': '2014 NOV',
#    'label': '2014 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.6',
#    'year': '2014'},
#   {'date': '2014 DEC',
#    'label': '2014 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '79.7',
#    'year': '2014'},
#   {'date': '2015 JAN',
#    'label': '2015 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.3',
#    'year': '2015'},
#   {'date': '2015 FEB',
#    'label': '2015 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.3',
#    'year': '2015'},
#   {'date': '2015 MAR',
#    'label': '2015 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '79.1',
#    'year': '2015'},
#   {'date': '2015 APR',
#    'label': '2015 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.6',
#    'year': '2015'},
#   {'date': '2015 MAY',
#    'label': '2015 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '79.0',
#    'year': '2015'},
#   {'date': '2015 JUN',
#    'label': '2015 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '79.7',
#    'year': '2015'},
#   {'date': '2015 JUL',
#    'label': '2015 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '79.0',
#    'year': '2015'},
#   {'date': '2015 AUG',
#    'label': '2015 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.8',
#    'year': '2015'},
#   {'date': '2015 SEP',
#    'label': '2015 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '79.5',
#    'year': '2015'},
#   {'date': '2015 OCT',
#    'label': '2015 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '79.2',
#    'year': '2015'},
#   {'date': '2015 NOV',
#    'label': '2015 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '79.3',
#    'year': '2015'},
#   {'date': '2015 DEC',
#    'label': '2015 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '79.6',
#    'year': '2015'},
#   {'date': '2016 JAN',
#    'label': '2016 JAN',
#    'month': 'January',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.3',
#    'year': '2016'},
#   {'date': '2016 FEB',
#    'label': '2016 FEB',
#    'month': 'February',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '77.9',
#    'year': '2016'},
#   {'date': '2016 MAR',
#    'label': '2016 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.6',
#    'year': '2016'},
#   {'date': '2016 APR',
#    'label': '2016 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.3',
#    'year': '2016'},
#   {'date': '2016 MAY',
#    'label': '2016 MAY',
#    'month': 'May',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.3',
#    'year': '2016'},
#   {'date': '2016 JUN',
#    'label': '2016 JUN',
#    'month': 'June',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.6',
#    'year': '2016'},
#   {'date': '2016 JUL',
#    'label': '2016 JUL',
#    'month': 'July',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '77.7',
#    'year': '2016'},
#   {'date': '2016 AUG',
#    'label': '2016 AUG',
#    'month': 'August',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '77.6',
#    'year': '2016'},
#   {'date': '2016 SEP',
#    'label': '2016 SEP',
#    'month': 'September',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.2',
#    'year': '2016'},
#   {'date': '2016 OCT',
#    'label': '2016 OCT',
#    'month': 'October',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '77.6',
#    'year': '2016'},
#   {'date': '2016 NOV',
#    'label': '2016 NOV',
#    'month': 'November',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '77.9',
#    'year': '2016'},
#   {'date': '2016 DEC',
#    'label': '2016 DEC',
#    'month': 'December',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.6',
# ...
#   {'correctionNotice': '',
#    'label': 'v53',
#    'updateDate': '2021-02-19T07:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v53'},
#   {'correctionNotice': '',
#    'label': 'v53',
#    'updateDate': '2021-02-19T07:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v53'},
#   {'correctionNotice': '',
#    'label': 'v54',
#    'updateDate': '2021-03-19T07:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v54'},
#   {'correctionNotice': '',
#    'label': 'v55',
#    'updateDate': '2021-04-23T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v55'},
#   {'correctionNotice': '',
#    'label': 'v56',
#    'updateDate': '2021-05-25T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v56'},
#   {'correctionNotice': '',
#    'label': 'v57',
#    'updateDate': '2021-06-22T05:20:55.173Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v57'},
#   {'correctionNotice': '',
#    'label': 'v58',
#    'updateDate': '2021-07-21T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v58'},
#   {'correctionNotice': '',
#    'label': 'v59',
#    'updateDate': '2021-08-20T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v59'},
#   {'correctionNotice': '',
#    'label': 'v59',
#    'updateDate': '2021-08-20T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v59'},
#   {'correctionNotice': '',
#    'label': 'v60',
#    'updateDate': '2021-09-21T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v60'},
#   {'correctionNotice': 'Following publication on 21 September 2021, an error has been found in the Public Sector Finances (PSF): August 2021 release. The error affects data for the period April 2020 to August 2021 inclusive.\n\nPublic Sector Net Borrowing (excluding Public Sector Banks – PSNB ex) was overstated by £4.6 billion in the financial year ending March 2021 and £2.5 billion in the financial year-to-August 2021. PSNB is now estimated to have been £320.5 billion in the financial year ending March 2021 and £91.3 billion in the financial year-to-August 2021.\n\nThis error was the result of provisional data for the Public Sector Funded Pension Schemes being used in the estimation of the published dataset. \n\nIn September 2021, we changed the discount rate used for future pension liabilities from 5% to 4%, taking on a change in international statistical standards. However, in the provisional dataset, the data for April 2020 onwards for these public sector schemes was estimated using the 5% discount rate. In the corrected version, this had been updated, consistent with the 4% rate. \n\nCorrecting this error has affected Public Sector Funded Pension Schemes’ net borrowing and so Public Sector Net Borrowing. There has been no impact on net cash requirement or net debt as a result of this correction.\n\nONS apologises for any inconvenience caused by this error.\n',
#    'label': 'v61',
#    'updateDate': '2021-10-05T11:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v61'},
#   {'correctionNotice': '',
#    'label': 'v62',
#    'updateDate': '2021-10-21T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v62'},
#   {'correctionNotice': '',
#    'label': 'v63',
#    'updateDate': '2021-11-19T07:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v63'},
#   {'correctionNotice': '',
#    'label': 'v64',
#    'updateDate': '2021-12-21T07:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v64'},
#   {'correctionNotice': '',
#    'label': 'v64',
#    'updateDate': '2021-12-21T07:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v64'},
#   {'correctionNotice': '',
#    'label': 'v65',
#    'updateDate': '2022-01-25T07:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v65'},
#   {'correctionNotice': '',
#    'label': 'v65',
#    'updateDate': '2022-01-25T07:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v65'},
#   {'correctionNotice': '',
#    'label': 'v65',
#    'updateDate': '2022-01-25T07:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v65'},
#   {'correctionNotice': '',
#    'label': 'v66',
#    'updateDate': '2022-02-22T07:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v66'},
#   {'correctionNotice': '',
#    'label': 'v67',
#    'updateDate': '2022-03-22T07:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v67'},
#   {'correctionNotice': '',
#    'label': 'v68',
#    'updateDate': '2022-04-26T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v68'},
#   {'correctionNotice': '',
#    'label': 'v69',
#    'updateDate': '2022-05-24T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v69'},
#   {'correctionNotice': '',
#    'label': 'v70',
#    'updateDate': '2022-06-23T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v70'},
#   {'correctionNotice': '',
#    'label': 'v71',
#    'updateDate': '2022-07-21T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v71'},
#   {'correctionNotice': '',
#    'label': 'v72',
#    'updateDate': '2022-08-19T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v72'},
#   {'correctionNotice': '',
#    'label': 'v73',
#    'updateDate': '2022-09-21T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v73'},
#   {'correctionNotice': '',
#    'label': 'v73',
#    'updateDate': '2022-09-21T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v73'},
#   {'correctionNotice': '',
#    'label': 'v73',
#    'updateDate': '2022-09-21T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v73'},
#   {'correctionNotice': '',
#    'label': 'v74',
#    'updateDate': '2022-10-21T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v74'},
#   {'correctionNotice': '',
#    'label': 'v74',
#    'updateDate': '2022-10-21T06:00:00.000Z',
#    'uri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/timeseries/cpoa/pusf/previous/v74'}],
#  'years': [{'date': '1975',
#    'label': '1975',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1975'},
#   {'date': '1976',
#    'label': '1976',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1976'},
#   {'date': '1977',
#    'label': '1977',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1977'},
#   {'date': '1978',
#    'label': '1978',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1978'},
#   {'date': '1979',
#    'label': '1979',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1979'},
#   {'date': '1980',
#    'label': '1980',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1980'},
#   {'date': '1981',
#    'label': '1981',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1981'},
#   {'date': '1982',
#    'label': '1982',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1982'},
#   {'date': '1983',
#    'label': '1983',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1983'},
#   {'date': '1984',
#    'label': '1984',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1984'},
#   {'date': '1985',
#    'label': '1985',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1985'},
#   {'date': '1986',
#    'label': '1986',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1986'},
#   {'date': '1987',
#    'label': '1987',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1987'},
#   {'date': '1988',
#    'label': '1988',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1988'},
#   {'date': '1989',
#    'label': '1989',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1989'},
#   {'date': '1990',
#    'label': '1990',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1990'},
#   {'date': '1991',
#    'label': '1991',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1991'},
#   {'date': '1992',
#    'label': '1992',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1992'},
#   {'date': '1993',
#    'label': '1993',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1993'},
#   {'date': '1994',
#    'label': '1994',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1994'},
#   {'date': '1995',
#    'label': '1995',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1995'},
#   {'date': '1996',
#    'label': '1996',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2016-12-21T00:00:00.000Z',
#    'value': '',
#    'year': '1996'},
#   {'date': '1997',
#    'label': '1997',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '37.5',
#    'year': '1997'},
#   {'date': '1998',
#    'label': '1998',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.8',
#    'year': '1998'},
#   {'date': '1999',
#    'label': '1999',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '34.4',
#    'year': '1999'},
#   {'date': '2000',
#    'label': '2000',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '29.7',
#    'year': '2000'},
#   {'date': '2001',
#    'label': '2001',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '28.9',
#    'year': '2001'},
#   {'date': '2002',
#    'label': '2002',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '30.2',
#    'year': '2002'},
#   {'date': '2003',
#    'label': '2003',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '31.4',
#    'year': '2003'},
#   {'date': '2004',
#    'label': '2004',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '34.2',
#    'year': '2004'},
#   {'date': '2005',
#    'label': '2005',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.2',
#    'year': '2005'},
#   {'date': '2006',
#    'label': '2006',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '35.9',
#    'year': '2006'},
#   {'date': '2007',
#    'label': '2007',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '36.4',
#    'year': '2007'},
#   {'date': '2008',
#    'label': '2008',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '48.0',
#    'year': '2008'},
#   {'date': '2009',
#    'label': '2009',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '59.8',
#    'year': '2009'},
#   {'date': '2010',
#    'label': '2010',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-09-20T23:00:00.000Z',
#    'value': '69.8',
#    'year': '2010'},
#   {'date': '2011',
#    'label': '2011',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '74.4',
#    'year': '2011'},
#   {'date': '2012',
#    'label': '2012',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '76.8',
#    'year': '2012'},
#   {'date': '2013',
#    'label': '2013',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '77.2',
#    'year': '2013'},
#   {'date': '2014',
#    'label': '2014',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '79.7',
#    'year': '2014'},
#   {'date': '2015',
#    'label': '2015',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '79.6',
#    'year': '2015'},
#   {'date': '2016',
#    'label': '2016',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '78.6',
#    'year': '2016'},
#   {'date': '2017',
#    'label': '2017',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '74.3',
#    'year': '2017'},
#   {'date': '2018',
#    'label': '2018',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '73.3',
#    'year': '2018'},
#   {'date': '2019',
#    'label': '2019',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '76.1',
#    'year': '2019'},
#   {'date': '2020',
#    'label': '2020',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '88.0',
#    'year': '2020'},
#   {'date': '2021',
#    'label': '2021',
#    'month': '',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2022-10-20T23:00:00.000Z',
#    'value': '85.6',
#    'year': '2021'}]}

# %%
fileName = "W5Homework_ONS-cpoa.json"
print(fileName)
with open(fileName, 'w', encoding='utf-8') as f:
  json.dump(data, f, ensure_ascii=False, indent=4)

files.download('W5Homework_ONS-cpoa.json')
# Out:
# W5Homework_ONS-cpoa.json

# %%
url_base = "https://api.ons.gov.uk/timeseries/{}/dataset/pusf/data"
# // Set the base fileName:
file_base = "W5Homework_ONS-{}.json"

ONSSeries = ['gzsj','gtao','aazk','j5ii','cprn','anls','anby','anng','ansp','cpmz']
# // Begin a loop, dealing with each series, one by one:
for i in ONSSeries:  

   # // In what follows below I print the iteration of the loop we are on:
   # // This is not necessary but can be helpful, esp with long loops: 
   print("------Iteration Starts--------")
   print(i) 
   # // Build the URL for this iteration of the loop, and check what we are getting:
   URL = url_base.format(i)
   print(URL)

     
   # // Request the html from the URL:
   data = requests.get(URL).json()
   print(data)

   # // Set the filename, and check what we are getting:
   fileName = file_base.format(i)
   print(fileName)
   
   # // Add some white space to our output. (This is purely so we can see what is happening below clearly)
   print("------Iteration Ends--------")

   # /// Save the file:
   with open(fileName, 'w', encoding='utf-8') as f:
     json.dump(data, f, ensure_ascii=False, indent=4)

   # /// Download the file to local machine:
   files.download(fileName)
# Out:
# ------Iteration Starts--------
# gzsj
# https://api.ons.gov.uk/timeseries/gzsj/dataset/pusf/data
# {'description': {'cdid': 'GZSJ', 'contact': {'email': 'public.sector.inquiries@ons.gov.uk', 'name': 'Fraser Munro', 'telephone': '+44 1633 456402'}, 'datasetId': 'PUSF', 'datasetUri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/datasets/publicsectorfinances', 'date': '2022 SEP', 'nextRelease': '22 November 2022', 'number': '25707', 'preUnit': '£', 'releaseDate': '2022-10-20T23:00:00.000Z', 'sampleSize': '0', 'source': '', 'title': 'CG: Current expenditure: Net social benefits payable: £m CPNSA', 'unit': 'm'}, 'months': [{'date': '1993 JAN', 'label': '1993 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 FEB', 'label': '1993 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 MAR', 'label': '1993 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 APR', 'label': '1993 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 MAY', 'label': '1993 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 JUN', 'label': '1993 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 JUL', 'label': '1993 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 AUG', 'label': '1993 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 SEP', 'label': '1993 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 OCT', 'label': '1993 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 NOV', 'label': '1993 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 DEC', 'label': '1993 DEC', 'month': 'December', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1994 JAN', 'label': '1994 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 FEB', 'label': '1994 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 MAR', 'label': '1994 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 APR', 'label': '1994 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 MAY', 'label': '1994 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 JUN', 'label': '1994 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 JUL', 'label': '1994 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 AUG', 'label': '1994 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, { ...
# W5Homework_ONS-gzsj.json
# ------Iteration Ends--------
# ------Iteration Starts--------
# gtao
# https://api.ons.gov.uk/timeseries/gtao/dataset/pusf/data
# {'description': {'cdid': 'GTAO', 'contact': {'email': 'public.sector.inquiries@ons.gov.uk', 'name': 'Fraser Munro', 'telephone': '+44 1633 456402'}, 'datasetId': 'PUSF', 'datasetUri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/datasets/publicsectorfinances', 'date': '2022 SEP', 'nextRelease': '22 November 2022', 'number': '679', 'preUnit': '', 'releaseDate': '2022-10-20T23:00:00.000Z', 'sampleSize': '0', 'source': '', 'title': 'CG: Current receipts: Taxes on production: Tobacco: £m CPNSA', 'unit': ''}, 'months': [{'date': '1993 JAN', 'label': '1993 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 FEB', 'label': '1993 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 MAR', 'label': '1993 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 APR', 'label': '1993 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 MAY', 'label': '1993 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 JUN', 'label': '1993 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 JUL', 'label': '1993 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 AUG', 'label': '1993 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 SEP', 'label': '1993 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 OCT', 'label': '1993 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 NOV', 'label': '1993 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 DEC', 'label': '1993 DEC', 'month': 'December', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1994 JAN', 'label': '1994 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 FEB', 'label': '1994 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 MAR', 'label': '1994 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 APR', 'label': '1994 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 MAY', 'label': '1994 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 JUN', 'label': '1994 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 JUL', 'label': '1994 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 AUG', 'label': '1994 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date' ...
# W5Homework_ONS-gtao.json
# ------Iteration Ends--------
# ------Iteration Starts--------
# aazk
# https://api.ons.gov.uk/timeseries/aazk/dataset/pusf/data
# {'description': {'cdid': 'AAZK', 'contact': {'email': 'public.sector.inquiries@ons.gov.uk', 'name': 'Fraser Munro', 'telephone': '+44 1633 456402'}, 'datasetId': 'PUSF', 'datasetUri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/datasets/publicsectorfinances', 'date': '2022 SEP', 'nextRelease': '22 November 2022', 'number': '899', 'preUnit': '£', 'releaseDate': '2022-10-20T23:00:00.000Z', 'sampleSize': '0', 'source': '', 'title': 'LG: Other: Contribution to PS net cash requirement: £m CPNSA', 'unit': 'm'}, 'months': [{'date': '1979 JAN', 'label': '1979 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '256', 'year': '1979'}, {'date': '1979 FEB', 'label': '1979 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '233', 'year': '1979'}, {'date': '1979 MAR', 'label': '1979 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '590', 'year': '1979'}, {'date': '1979 APR', 'label': '1979 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '165', 'year': '1979'}, {'date': '1979 MAY', 'label': '1979 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '-224', 'year': '1979'}, {'date': '1979 JUN', 'label': '1979 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '-279', 'year': '1979'}, {'date': '1979 JUL', 'label': '1979 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '230', 'year': '1979'}, {'date': '1979 AUG', 'label': '1979 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '257', 'year': '1979'}, {'date': '1979 SEP', 'label': '1979 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '260', 'year': '1979'}, {'date': '1979 OCT', 'label': '1979 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '334', 'year': '1979'}, {'date': '1979 NOV', 'label': '1979 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '-215', 'year': '1979'}, {'date': '1979 DEC', 'label': '1979 DEC', 'month': 'December', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '213', 'year': '1979'}, {'date': '1980 JAN', 'label': '1980 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '188', 'year': '1980'}, {'date': '1980 FEB', 'label': '1980 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '386', 'year': '1980'}, {'date': '1980 MAR', 'label': '1980 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '837', 'year': '1980'}, {'date': '1980 APR', 'label': '1980 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '544', 'year': '1980'}, {'date': '1980 MAY', 'label': '1980 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '-65', 'year': '1980'}, {'date': '1980 JUN', 'label': '1980 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '-75', 'year': '1980'}, {'date': '1980 JUL', 'label': '1980 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '-263', 'year': '1980'}, {'date': '1980 AUG', 'label': '1980 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2 ...
# W5Homework_ONS-aazk.json
# ------Iteration Ends--------
# ------Iteration Starts--------
# j5ii
# https://api.ons.gov.uk/timeseries/j5ii/dataset/pusf/data
# {'description': {'cdid': 'J5II', 'contact': {'email': 'public.sector.inquiries@ons.gov.uk', 'name': 'Fraser Munro', 'telephone': '+44 1633 456402'}, 'datasetId': 'PUSF', 'datasetUri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/datasets/publicsectorfinances', 'date': '2022 SEP', 'nextRelease': '22 November 2022', 'number': '-20012', 'preUnit': '£', 'releaseDate': '2022-10-20T23:00:00.000Z', 'sampleSize': '0', 'source': '', 'title': 'PS: Net Borrowing (excluding public sector banks): £m: CPNSA', 'unit': 'm'}, 'months': [{'date': '1993 JAN', 'label': '1993 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 FEB', 'label': '1993 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 MAR', 'label': '1993 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 APR', 'label': '1993 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 MAY', 'label': '1993 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 JUN', 'label': '1993 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 JUL', 'label': '1993 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 AUG', 'label': '1993 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 SEP', 'label': '1993 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 OCT', 'label': '1993 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 NOV', 'label': '1993 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1993 DEC', 'label': '1993 DEC', 'month': 'December', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1993'}, {'date': '1994 JAN', 'label': '1994 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 FEB', 'label': '1994 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 MAR', 'label': '1994 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 APR', 'label': '1994 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 MAY', 'label': '1994 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 JUN', 'label': '1994 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 JUL', 'label': '1994 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {'date': '1994 AUG', 'label': '1994 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2015-10-20T23:00:00.000Z', 'value': '', 'year': '1994'}, {' ...
# W5Homework_ONS-j5ii.json
# ------Iteration Ends--------
# ------Iteration Starts--------
# cprn
# https://api.ons.gov.uk/timeseries/cprn/dataset/pusf/data
# {'description': {'cdid': 'CPRN', 'contact': {'email': 'public.sector.inquiries@ons.gov.uk', 'name': 'Fraser Munro', 'telephone': '+44 1633 456402'}, 'datasetId': 'PUSF', 'datasetUri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/datasets/publicsectorfinances', 'date': '2022 SEP', 'nextRelease': '22 November 2022', 'number': '6801', 'preUnit': '', 'releaseDate': '2022-10-20T23:00:00.000Z', 'sampleSize': '0', 'source': '', 'title': 'CG: Receipts: Corporation tax: Accrued: Gross of tax credits: £m:NSA', 'unit': ''}, 'months': [{'date': '1966 SEP', 'label': '1966 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1966'}, {'date': '1966 OCT', 'label': '1966 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1966'}, {'date': '1966 NOV', 'label': '1966 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1966'}, {'date': '1966 DEC', 'label': '1966 DEC', 'month': 'December', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1966'}, {'date': '1967 JAN', 'label': '1967 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1967'}, {'date': '1967 FEB', 'label': '1967 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1967'}, {'date': '1967 MAR', 'label': '1967 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1967'}, {'date': '1967 APR', 'label': '1967 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1967'}, {'date': '1967 MAY', 'label': '1967 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1967'}, {'date': '1967 JUN', 'label': '1967 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1967'}, {'date': '1967 JUL', 'label': '1967 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1967'}, {'date': '1967 AUG', 'label': '1967 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1967'}, {'date': '1967 SEP', 'label': '1967 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1967'}, {'date': '1967 OCT', 'label': '1967 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1967'}, {'date': '1967 NOV', 'label': '1967 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1967'}, {'date': '1967 DEC', 'label': '1967 DEC', 'month': 'December', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1967'}, {'date': '1968 JAN', 'label': '1968 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1968'}, {'date': '1968 FEB', 'label': '1968 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1968'}, {'date': '1968 MAR', 'label': '1968 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '', 'year': '1968'}, {'date': '1968 APR', 'label': '1968 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2017-02-21T00:00:00.000Z', 'value': '',  ...
# W5Homework_ONS-cprn.json
# ------Iteration Ends--------
# ------Iteration Starts--------
# anls
# https://api.ons.gov.uk/timeseries/anls/dataset/pusf/data
# {'description': {'cdid': 'ANLS', 'contact': {'email': 'public.sector.inquiries@ons.gov.uk', 'name': 'Fraser Munro', 'telephone': '+44 1633 456402'}, 'datasetId': 'PUSF', 'datasetUri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/datasets/publicsectorfinances', 'date': '2022 SEP', 'nextRelease': '22 November 2022', 'number': '45', 'preUnit': '£', 'releaseDate': '2022-10-20T23:00:00.000Z', 'sampleSize': '0', 'source': '', 'title': 'PC: Total current expenditure: £m CPNSA', 'unit': 'm'}, 'months': [{'date': '1997 APR', 'label': '1997 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '3', 'year': '1997'}, {'date': '1997 MAY', 'label': '1997 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '3', 'year': '1997'}, {'date': '1997 JUN', 'label': '1997 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '2', 'year': '1997'}, {'date': '1997 JUL', 'label': '1997 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '3', 'year': '1997'}, {'date': '1997 AUG', 'label': '1997 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '3', 'year': '1997'}, {'date': '1997 SEP', 'label': '1997 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '3', 'year': '1997'}, {'date': '1997 OCT', 'label': '1997 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '3', 'year': '1997'}, {'date': '1997 NOV', 'label': '1997 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '3', 'year': '1997'}, {'date': '1997 DEC', 'label': '1997 DEC', 'month': 'December', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '2', 'year': '1997'}, {'date': '1998 JAN', 'label': '1998 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '3', 'year': '1998'}, {'date': '1998 FEB', 'label': '1998 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '3', 'year': '1998'}, {'date': '1998 MAR', 'label': '1998 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '2', 'year': '1998'}, {'date': '1998 APR', 'label': '1998 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '3', 'year': '1998'}, {'date': '1998 MAY', 'label': '1998 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '3', 'year': '1998'}, {'date': '1998 JUN', 'label': '1998 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '2', 'year': '1998'}, {'date': '1998 JUL', 'label': '1998 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '4', 'year': '1998'}, {'date': '1998 AUG', 'label': '1998 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '4', 'year': '1998'}, {'date': '1998 SEP', 'label': '1998 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '3', 'year': '1998'}, {'date': '1998 OCT', 'label': '1998 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '3', 'year': '1998'}, {'date': '1998 NOV', 'label': '1998 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '3', 'year': '1998'}, {'d ...
# W5Homework_ONS-anls.json
# ------Iteration Ends--------
# ------Iteration Starts--------
# anby
# https://api.ons.gov.uk/timeseries/anby/dataset/pusf/data
# {'description': {'cdid': 'ANBY', 'contact': {'email': 'public.sector.inquiries@ons.gov.uk', 'name': 'Fraser Munro', 'telephone': '+44 1633 456402'}, 'datasetId': 'PUSF', 'datasetUri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/datasets/publicsectorfinances', 'date': '2022 SEP', 'nextRelease': '22 November 2022', 'number': '75955', 'preUnit': '£', 'releaseDate': '2022-10-20T23:00:00.000Z', 'sampleSize': '0', 'source': '', 'title': 'GG: Total current receipts: £m CPNSA', 'unit': 'm'}, 'months': [{'date': '1997 APR', 'label': '1997 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '23259', 'year': '1997'}, {'date': '1997 MAY', 'label': '1997 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '23211', 'year': '1997'}, {'date': '1997 JUN', 'label': '1997 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '22995', 'year': '1997'}, {'date': '1997 JUL', 'label': '1997 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '26710', 'year': '1997'}, {'date': '1997 AUG', 'label': '1997 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '24454', 'year': '1997'}, {'date': '1997 SEP', 'label': '1997 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '25365', 'year': '1997'}, {'date': '1997 OCT', 'label': '1997 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '28250', 'year': '1997'}, {'date': '1997 NOV', 'label': '1997 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '29053', 'year': '1997'}, {'date': '1997 DEC', 'label': '1997 DEC', 'month': 'December', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '28430', 'year': '1997'}, {'date': '1998 JAN', 'label': '1998 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '36555', 'year': '1998'}, {'date': '1998 FEB', 'label': '1998 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '28590', 'year': '1998'}, {'date': '1998 MAR', 'label': '1998 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '26527', 'year': '1998'}, {'date': '1998 APR', 'label': '1998 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '26076', 'year': '1998'}, {'date': '1998 MAY', 'label': '1998 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '23541', 'year': '1998'}, {'date': '1998 JUN', 'label': '1998 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '24231', 'year': '1998'}, {'date': '1998 JUL', 'label': '1998 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '31139', 'year': '1998'}, {'date': '1998 AUG', 'label': '1998 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '25923', 'year': '1998'}, {'date': '1998 SEP', 'label': '1998 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '26403', 'year': '1998'}, {'date': '1998 OCT', 'label': '1998 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '35411', 'year': '1998'}, {'date': '1998 NOV', 'label': '1998 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF',  ...
# W5Homework_ONS-anby.json
# ------Iteration Ends--------
# ------Iteration Starts--------
# anng
# https://api.ons.gov.uk/timeseries/anng/dataset/pusf/data
# {'description': {'cdid': 'ANNG', 'contact': {'email': 'public.sector.inquiries@ons.gov.uk', 'name': 'Fraser Munro', 'telephone': '+44 1633 456402'}, 'datasetId': 'PUSF', 'datasetUri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/datasets/publicsectorfinances', 'date': '2022 SEP', 'nextRelease': '22 November 2022', 'number': '221', 'preUnit': '£', 'releaseDate': '2022-10-20T23:00:00.000Z', 'sampleSize': '0', 'source': '', 'title': 'PC: Capital grants (net) within public sector (D92&D99): £m CPNSA', 'unit': 'm'}, 'months': [{'date': '1997 APR', 'label': '1997 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '150', 'year': '1997'}, {'date': '1997 MAY', 'label': '1997 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '150', 'year': '1997'}, {'date': '1997 JUN', 'label': '1997 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '153', 'year': '1997'}, {'date': '1997 JUL', 'label': '1997 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '52', 'year': '1997'}, {'date': '1997 AUG', 'label': '1997 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '52', 'year': '1997'}, {'date': '1997 SEP', 'label': '1997 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '58', 'year': '1997'}, {'date': '1997 OCT', 'label': '1997 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '131', 'year': '1997'}, {'date': '1997 NOV', 'label': '1997 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '131', 'year': '1997'}, {'date': '1997 DEC', 'label': '1997 DEC', 'month': 'December', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '134', 'year': '1997'}, {'date': '1998 JAN', 'label': '1998 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '189', 'year': '1998'}, {'date': '1998 FEB', 'label': '1998 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '189', 'year': '1998'}, {'date': '1998 MAR', 'label': '1998 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '189', 'year': '1998'}, {'date': '1998 APR', 'label': '1998 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '103', 'year': '1998'}, {'date': '1998 MAY', 'label': '1998 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '101', 'year': '1998'}, {'date': '1998 JUN', 'label': '1998 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '102', 'year': '1998'}, {'date': '1998 JUL', 'label': '1998 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '26', 'year': '1998'}, {'date': '1998 AUG', 'label': '1998 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '25', 'year': '1998'}, {'date': '1998 SEP', 'label': '1998 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '25', 'year': '1998'}, {'date': '1998 OCT', 'label': '1998 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2020-03-20T00:00:00.000Z', 'value': '58', 'year': '1998'}, {'date': '1998 NOV', 'label': '1998 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '202 ...
# W5Homework_ONS-anng.json
# ------Iteration Ends--------
# ------Iteration Starts--------
# ansp
# https://api.ons.gov.uk/timeseries/ansp/dataset/pusf/data
# {'description': {'cdid': 'ANSP', 'contact': {'email': 'public.sector.inquiries@ons.gov.uk', 'name': 'Fraser Munro', 'telephone': '+44 1633 456402'}, 'datasetId': 'PUSF', 'datasetUri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/datasets/publicsectorfinances', 'date': '2022 SEP', 'nextRelease': '22 November 2022', 'number': '-7101', 'preUnit': '£', 'releaseDate': '2022-10-20T23:00:00.000Z', 'sampleSize': '0', 'source': '', 'title': 'PS: Saving, gross plus capital taxes: £m CPNSA', 'unit': 'm'}, 'months': [{'date': '1997 APR', 'label': '1997 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '-1134', 'year': '1997'}, {'date': '1997 MAY', 'label': '1997 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '-1320', 'year': '1997'}, {'date': '1997 JUN', 'label': '1997 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '-3236', 'year': '1997'}, {'date': '1997 JUL', 'label': '1997 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '1317', 'year': '1997'}, {'date': '1997 AUG', 'label': '1997 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '-895', 'year': '1997'}, {'date': '1997 SEP', 'label': '1997 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '-249', 'year': '1997'}, {'date': '1997 OCT', 'label': '1997 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '3550', 'year': '1997'}, {'date': '1997 NOV', 'label': '1997 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '3868', 'year': '1997'}, {'date': '1997 DEC', 'label': '1997 DEC', 'month': 'December', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '1147', 'year': '1997'}, {'date': '1998 JAN', 'label': '1998 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '10281', 'year': '1998'}, {'date': '1998 FEB', 'label': '1998 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '2734', 'year': '1998'}, {'date': '1998 MAR', 'label': '1998 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '545', 'year': '1998'}, {'date': '1998 APR', 'label': '1998 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '-24', 'year': '1998'}, {'date': '1998 MAY', 'label': '1998 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '-2066', 'year': '1998'}, {'date': '1998 JUN', 'label': '1998 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '-1492', 'year': '1998'}, {'date': '1998 JUL', 'label': '1998 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '4771', 'year': '1998'}, {'date': '1998 AUG', 'label': '1998 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '48', 'year': '1998'}, {'date': '1998 SEP', 'label': '1998 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '505', 'year': '1998'}, {'date': '1998 OCT', 'label': '1998 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-09-20T23:00:00.000Z', 'value': '8706', 'year': '1998'}, {'date': '1998 NOV', 'label': '1998 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF', 'updateD ...
# W5Homework_ONS-ansp.json
# ------Iteration Ends--------
# ------Iteration Starts--------
# cpmz
# https://api.ons.gov.uk/timeseries/cpmz/dataset/pusf/data
# {'description': {'cdid': 'CPMZ', 'contact': {'email': 'public.sector.inquiries@ons.gov.uk', 'name': 'Fraser Munro', 'telephone': '+44 1633 456402'}, 'datasetId': 'PUSF', 'datasetUri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/datasets/publicsectorfinances', 'date': '2022 SEP', 'nextRelease': '22 November 2022', 'number': '352895', 'preUnit': '', 'releaseDate': '2022-10-20T23:00:00.000Z', 'sampleSize': '0', 'source': '', 'title': 'Pub Sect: Assets:Loan assets (AF.4) :NSA:£m', 'unit': ''}, 'months': [{'date': '2000 JAN', 'label': '2000 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2018-04-23T23:00:00.000Z', 'value': '0', 'year': '2000'}, {'date': '2000 FEB', 'label': '2000 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2018-04-23T23:00:00.000Z', 'value': '0', 'year': '2000'}, {'date': '2000 MAR', 'label': '2000 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '17459', 'year': '2000'}, {'date': '2000 APR', 'label': '2000 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '17823', 'year': '2000'}, {'date': '2000 MAY', 'label': '2000 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '18187', 'year': '2000'}, {'date': '2000 JUN', 'label': '2000 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '18561', 'year': '2000'}, {'date': '2000 JUL', 'label': '2000 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '18948', 'year': '2000'}, {'date': '2000 AUG', 'label': '2000 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '19336', 'year': '2000'}, {'date': '2000 SEP', 'label': '2000 SEP', 'month': 'September', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '19982', 'year': '2000'}, {'date': '2000 OCT', 'label': '2000 OCT', 'month': 'October', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '20321', 'year': '2000'}, {'date': '2000 NOV', 'label': '2000 NOV', 'month': 'November', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '20661', 'year': '2000'}, {'date': '2000 DEC', 'label': '2000 DEC', 'month': 'December', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '20249', 'year': '2000'}, {'date': '2001 JAN', 'label': '2001 JAN', 'month': 'January', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '20558', 'year': '2001'}, {'date': '2001 FEB', 'label': '2001 FEB', 'month': 'February', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '20867', 'year': '2001'}, {'date': '2001 MAR', 'label': '2001 MAR', 'month': 'March', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '21665', 'year': '2001'}, {'date': '2001 APR', 'label': '2001 APR', 'month': 'April', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '21931', 'year': '2001'}, {'date': '2001 MAY', 'label': '2001 MAY', 'month': 'May', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '22198', 'year': '2001'}, {'date': '2001 JUN', 'label': '2001 JUN', 'month': 'June', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '22525', 'year': '2001'}, {'date': '2001 JUL', 'label': '2001 JUL', 'month': 'July', 'quarter': '', 'sourceDataset': 'PUSF', 'updateDate': '2022-10-20T23:00:00.000Z', 'value': '22752', 'year': '2001'}, {'date': '2001 AUG', 'label': '2001 AUG', 'month': 'August', 'quarter': '', 'sourceDataset': 'PUSF', 'updat ...
# W5Homework_ONS-cpmz.json
# ------Iteration Ends--------
